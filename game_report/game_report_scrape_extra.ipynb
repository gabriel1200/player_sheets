# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import requests
import os
import time
from datetime import datetime
import glob

def format_date_to_url(date):
    # Convert date from YYYYMMDD to datetime object
    date_obj = datetime.strptime(str(date), '%Y%m%d')
    
    # Format the date as MM%2FDD%2FYYYY
    formatted_date = date_obj.strftime('%m%%2F%d%%2F%Y')
    
    return formatted_date

def pull_data(url):
    headers = {
        "Host": "stats.nba.com",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
        "Accept": "application/json, text/plain, */*",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
        "Referer": "https://stats.nba.com/",
        "Origin": "https://stats.nba.com",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
    }

    json = requests.get(url, headers=headers).json()

    if len(json["resultSets"]) == 1:
        data = json["resultSets"][0]["rowSet"]
        columns = json["resultSets"][0]["headers"]
        df = pd.DataFrame.from_records(data, columns=columns)
    else:
        data = json["resultSets"]["rowSet"]
        columns = json["resultSets"]["headers"][1]['columnNames']
        df = pd.DataFrame.from_records(data, columns=columns)

    time.sleep(.1)  # Respect rate limits
    return df

def pull_additional_data(date_num, season, stype='Regular%20Season'):
    """
    Pull additional data from new endpoints for a specific date
    """
    date = format_date_to_url(date_num)
    
    additional_data_frames = []
    year=int(season.split('-')[0])+1
    
    # Get data from your additional links
    # Link 1: Overall defense stats
    ps=False
    if stype=='Playoffs':
        ps=True
    passed=True
    url1 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Overall&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df1 = pull_data(url1)
        df1.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df1.rename(columns={col: f'overall_def_{col}' for col in df1.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df1)
        print(f"Successfully pulled Overall defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling Overall defense data for {date_num}: {str(e)}")
    
    # Link 2: 3-pointers defense stats
    url2 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=3%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df2 = pull_data(url2)
        df2.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df2.rename(columns={col: f'three_pt_def_{col}' for col in df2.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df2)
        print(f"Successfully pulled 3PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 3PT defense data for {date_num}: {str(e)}")
    
    # Link 3: 2-pointers defense stats
    url3 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=2%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df3 = pull_data(url3)
        df3.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df3.rename(columns={col: f'two_pt_def_{col}' for col in df3.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df3)
        print(f"Successfully pulled 2PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 2PT defense data for {date_num}: {str(e)}")
    
    # Link 4: Less than 6ft defense stats
    url4 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%206Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df4 = pull_data(url4)
        df4.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df4.rename(columns={col: f'less_6ft_def_{col}' for col in df4.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df4)
        print(f"Successfully pulled <6ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <6ft defense data for {date_num}: {str(e)}")
    
    # Link 5: Less than 10ft defense stats
    url5 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%2010Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df5 = pull_data(url5)
        df5.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df5.rename(columns={col: f'less_10ft_def_{col}' for col in df5.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df5)
        print(f"Successfully pulled <10ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <10ft defense data for {date_num}: {str(e)}")
    
    # Link 6: Less than 15ft defense stats
    url6 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Greater%20Than%2015Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df6 = pull_data(url6)
        df6.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df6.rename(columns={col: f'more_15ft_def_{col}' for col in df6.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df6)
        print(f"Successfully pulled >15ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <15ft defense data for {date_num}: {str(e)}")
    
    # Link 7: Hustle stats
    if year>=2016:
        url7 = f'https://stats.nba.com/stats/leaguehustlestatsplayer?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season={season}&SeasonSegment=&SeasonType={stype}&TeamID=0&VsConference=&VsDivision=&Weight='
        try:
            df7 = pull_data(url7)
            df7.rename(columns={col: f'hustle_{col}' for col in df7.columns if col != 'PLAYER_ID'}, inplace=True)
            additional_data_frames.append(df7)
            print(f"Successfully pulled hustle stats for {date_num}")
        except Exception as e:
            passed=False
            print(f"Error pulling hustle stats for {date_num}: {str(e)}")
    
    # Link 8: Post touch stats
    url8 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PostTouch&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df8 = pull_data(url8)
        df8.rename(columns={col: f'post_touch_{col}' for col in df8.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df8)
        print(f"Successfully pulled post touch stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling post touch stats for {date_num}: {str(e)}")
    
    # Link 9: Speed distance stats
    url9 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=SpeedDistance&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df9 = pull_data(url9)
        df9.rename(columns={col: f'speed_distance_{col}' for col in df9.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df9)
        print(f"Successfully pulled speed distance stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling speed distance stats for {date_num}: {str(e)}")
    
    # Merge all the additional data frames on PLAYER_ID
    result_df = additional_data_frames[0]
    for df in additional_data_frames[1:]:
        result_df = result_df.merge(df, on='PLAYER_ID', how='outer')
    
    # Add date and season information
    result_df['date'] = date_num
    result_df['season'] = season.replace('-', '_')
    
    return result_df,passed

def update_game_files(start_year, end_year, stype='Regular%20Season'):
    """
    Update existing game files with additional data for a range of seasons
    """
    # Get all dates for which we have existing data
    for year in range(start_year, end_year):
        season = f"{year-1}-{str(year)[-2:]}"
        
        # Create a directory for additional data if it doesn't exist
        additional_data_dir = f'additional_data/{year}'
        if not os.path.exists(additional_data_dir):
            os.makedirs(additional_data_dir, exist_ok=True)
        
        # Get list of game files we already have
        game_files = glob.glob(f'{year}/*.csv')
        
        # Extract unique dates from existing files
        existing_dates = set()
        date_to_games = {}
        
        # Read the date information from existing files
        for game_file in game_files:
            try:
                game_id = os.path.basename(game_file).replace('.csv', '')
                game_df = pd.read_csv(game_file)
                
                if 'date' in game_df.columns:
                    date = game_df['date'].iloc[0]
                    existing_dates.add(date)
                    
                    if date not in date_to_games:
                        date_to_games[date] = []
                    date_to_games[date].append(game_id)
            except Exception as e:
                print(f"Error reading file {game_file}: {str(e)}")
        
        # Process each date to get additional data
        date_dict={
                2014: 20140419,
                2015: 20150418,
                2016: 20160416,
                2017: 20170415,
                2018: 20180414,
                2019: 20190413,
                2020: 20200817,  # Delayed due to COVID-19
                2021: 20210522,
                2022: 20220416,
                2023: 20230415,
                2024: 20240420,
                2025: 20250420
            }
        year=int(season.split('-')[0])
        year+=1
        cutoff= date_dict[year]
  
        for date in sorted(existing_dates):
            additional_data_file = f'{additional_data_dir}/{date}_additional.csv'
            
            # Skip if we already have the additional data file
            if os.path.exists(additional_data_file):
                print(f"Additional data file already exists for date {date}. Skipping.")
                continue
            
            print(f"Processing date: {date}")


            
            try:
                # Pull additional data

                if date>=cutoff:
                    season_type='Playoffs'
                else:
                    season_type='Regular%20Season'
                additional_df,passed = pull_additional_data(date, season, season_type)
                
                # Save the additional data for this date
                if passed:
                    additional_df.to_csv(additional_data_file, index=False)
                    print(f"Saved additional data for date {date}")
                    
                    # Now update each game file for this date with the additional data
                    game_ids = date_to_games.get(date, [])
                    
                    for game_id in game_ids:
                        game_file = f'{year}/{game_id}.csv'
                        
                        try:
                            # Read the existing game data
                            game_df = pd.read_csv(game_file)
                            
                            # Merge with additional data
                            updated_df = game_df.merge(additional_df, on=['PLAYER_ID', 'date'], how='left')
                            
                            # Save the updated game file
                            updated_df.to_csv(f'{year}/{game_id}_updated.csv', index=False)
                            print(f"Updated game file: {game_id}")
                        except Exception as e:
                            print(f"Error updating game file {game_id}: {str(e)}")
                    
            except Exception as e:
                print(f"Error processing additional data for date {date}: {str(e)}")

def update_all_games_file(year):
    """
    Update the consolidated 'all_games' file with additional data
    """
    # Get all updated game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    if not updated_game_files:
        print(f"No updated game files found for year {year}")
        return
    
    # Combine all updated game files
    all_updated_games = []
    
    for game_file in updated_game_files:
        try:
            game_df = pd.read_csv(game_file)
            all_updated_games.append(game_df)
        except Exception as e:
            print(f"Error reading updated game file {game_file}: {str(e)}")
    
    if all_updated_games:
        # Concatenate all game data
        all_games_df = pd.concat(all_updated_games, ignore_index=True)
        
        # Save as CSV and parquet
        all_games_df.to_csv(f'all_games/all_{year}_updated.csv', index=False)
        all_games_df.to_parquet(f'all_games/all_{year}_updated.parquet', index=False)
        print(f"Updated consolidated files for year {year}")
    else:
        print(f"No valid updated game files to concatenate for year {year}")

def cleanup_and_rename(year):
    """
    After successful update, rename updated files to replace originals
    """
    # Rename individual game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    for game_file in updated_game_files:
        original_file = game_file.replace('_updated.csv', '.csv')
        os.rename(game_file, original_file)
        print(f"Replaced {original_file} with updated version")
    
    # Rename consolidated files
    if os.path.exists(f'all_games/all_{year}_updated.csv'):
        os.rename(f'all_games/all_{year}_updated.csv', f'all_games/all_{year}.csv')
        print(f"Replaced all_games/all_{year}.csv with updated version")
    
    if os.path.exists(f'all_games/all_{year}_updated.parquet'):
        os.rename(f'all_games/all_{year}_updated.parquet', f'all_games/all_{year}.parquet')
        print(f"Replaced all_games/all_{year}.parquet with updated version")

def main():
    # Define year range
    start_year = 2014
    end_year = 2026
    
    # Update game files with additional data
    update_game_files(start_year, end_year)
    
    # Update consolidated files
    for year in range(start_year, end_year):
        update_all_games_file(year)
    
    # Clean up and rename files
    for year in range(start_year, end_year):
        cleanup_and_rename(year)

if __name__ == "__main__":
    main()
# Out:
# Additional data file already exists for date 20131029. Skipping.
# Additional data file already exists for date 20131030. Skipping.
# Additional data file already exists for date 20131031. Skipping.
# Additional data file already exists for date 20131101. Skipping.
# Additional data file already exists for date 20131102. Skipping.
# Additional data file already exists for date 20131103. Skipping.
# Additional data file already exists for date 20131104. Skipping.
# Additional data file already exists for date 20131105. Skipping.
# Additional data file already exists for date 20131106. Skipping.
# Additional data file already exists for date 20131107. Skipping.
# Additional data file already exists for date 20131108. Skipping.
# Additional data file already exists for date 20131109. Skipping.
# Additional data file already exists for date 20131110. Skipping.
# Additional data file already exists for date 20131111. Skipping.
# Additional data file already exists for date 20131112. Skipping.
# Additional data file already exists for date 20131113. Skipping.
# Additional data file already exists for date 20131114. Skipping.
# Additional data file already exists for date 20131115. Skipping.
# Additional data file already exists for date 20131116. Skipping.
# Additional data file already exists for date 20131117. Skipping.
# Additional data file already exists for date 20131118. Skipping.
# Additional data file already exists for date 20131119. Skipping.
# Additional data file already exists for date 20131120. Skipping.
# Additional data file already exists for date 20131121. Skipping.
# Additional data file already exists for date 20131122. Skipping.
# Additional data file already exists for date 20131123. Skipping.
# Additional data file already exists for date 20131124. Skipping.
# Additional data file already exists for date 20131125. Skipping.
# Additional data file already exists for date 20131126. Skipping.
# Additional data file already exists for date 20131127. Skipping.
# Additional data file already exists for date 20131129. Skipping.
# Additional data file already exists for date 20131130. Skipping.
# Additional data file already exists for date 20131201. Skipping.
# Additional data file already exists for date 20131202. Skipping.
# Additional data file already exists for date 20131203. Skipping.
# Additional data file already exists for date 20131204. Skipping.
# Additional data file already exists for date 20131205. Skipping.
# Additional data file already exists for date 20131206. Skipping.
# Additional data file already exists for date 20131207. Skipping.
# Additional data file already exists for date 20131208. Skipping.
# Additional data file already exists for date 20131209. Skipping.
# Additional data file already exists for date 20131210. Skipping.
# Additional data file already exists for date 20131211. Skipping.
# Additional data file already exists for date 20131212. Skipping.
# Additional data file already exists for date 20131213. Skipping.
# Additional data file already exists for date 20131214. Skipping.
# Additional data file already exists for date 20131215. Skipping.
# Additional data file already exists for date 20131216. Skipping.
# Additional data file already exists for date 20131217. Skipping.
# Additional data file already exists for date 20131218. Skipping.
# Additional data file already exists for date 20131219. Skipping.
# Additional data file already exists for date 20131220. Skipping.
# Additional data file already exists for date 20131221. Skipping.
# Additional data file already exists for date 20131222. Skipping.
# Additional data file already exists for date 20131223. Skipping.
# Additional data file already exists for date 20131225. Skipping.
# Additional data file already exists for date 20131226. Skipping.
# Additional data file already exists for date 20131227. Skipping.
# Additional data file already exists for date 20131228. Skipping.
# Additional data file already exists for date 20131229. Skipping.
# Additional data file already exists for date 20131230. Skipping.
# Additional data file already exists for date 20131231. Skipping.
# Additional data file already exists for date 20140101. Skipping.
# Additional data file already exists for date 20140102. Skipping.
# Additional data file already exists for date 20140103. Skipping.
# Additional data file already exists for date 20140104. Skipping.
# Additional data file already exists for date 20140105. Skipping.
# Additional data file already exists for date 20140106. Skipping.
# Additional data file already exists for date 20140107. Skipping.
# Additional data file already exists for date 20140108. Skipping.
# Additional data file already exists for date 20140109. Skipping.
# Additional data file already exists for date 20140110. Skipping.
# Additional data file already exists for date 20140111. Skipping.
# Additional data file already exists for date 20140112. Skipping.
# Additional data file already exists for date 20140113. Skipping.
# Additional data file already exists for date 20140114. Skipping.
# Additional data file already exists for date 20140115. Skipping.
# Additional data file already exists for date 20140116. Skipping.
# Additional data file already exists for date 20140117. Skipping.
# Additional data file already exists for date 20140118. Skipping.
# Additional data file already exists for date 20140119. Skipping.
# Additional data file already exists for date 20140120. Skipping.
# Additional data file already exists for date 20140121. Skipping.
# Additional data file already exists for date 20140122. Skipping.
# Additional data file already exists for date 20140123. Skipping.
# Additional data file already exists for date 20140124. Skipping.
# Additional data file already exists for date 20140125. Skipping.
# Additional data file already exists for date 20140126. Skipping.
# Additional data file already exists for date 20140127. Skipping.
# Additional data file already exists for date 20140128. Skipping.
# Additional data file already exists for date 20140129. Skipping.
# Additional data file already exists for date 20140130. Skipping.
# Additional data file already exists for date 20140131. Skipping.
# Additional data file already exists for date 20140201. Skipping.
# Additional data file already exists for date 20140202. Skipping.
# Additional data file already exists for date 20140203. Skipping.
# Additional data file already exists for date 20140204. Skipping.
# Additional data file already exists for date 20140205. Skipping.
# Additional data file already exists for date 20140206. Skipping.
# Additional data file already exists for date 20140207. Skipping.
# Additional data file already exists for date 20140208. Skipping.
# Additional data file already exists for date 20140209. Skipping.
# Additional data file already exists for date 20140210. Skipping.
# Additional data file already exists for date 20140211. Skipping.
# Additional data file already exists for date 20140212. Skipping.
# Additional data file already exists for date 20140213. Skipping.
# Additional data file already exists for date 20140218. Skipping.
# Additional data file already exists for date 20140219. Skipping.
# Additional data file already exists for date 20140220. Skipping.
# Additional data file already exists for date 20140221. Skipping.
# Additional data file already exists for date 20140222. Skipping.
# Additional data file already exists for date 20140223. Skipping.
# Additional data file already exists for date 20140224. Skipping.
# Additional data file already exists for date 20140225. Skipping.
# Additional data file already exists for date 20140226. Skipping.
# Additional data file already exists for date 20140227. Skipping.
# Additional data file already exists for date 20140228. Skipping.
# Additional data file already exists for date 20140301. Skipping.
# Additional data file already exists for date 20140302. Skipping.
# Additional data file already exists for date 20140303. Skipping.
# Additional data file already exists for date 20140304. Skipping.
# Additional data file already exists for date 20140305. Skipping.
# Additional data file already exists for date 20140306. Skipping.
# Additional data file already exists for date 20140307. Skipping.
# Additional data file already exists for date 20140308. Skipping.
# Additional data file already exists for date 20140309. Skipping.
# Additional data file already exists for date 20140310. Skipping.
# Additional data file already exists for date 20140311. Skipping.
# Additional data file already exists for date 20140312. Skipping.
# Additional data file already exists for date 20140313. Skipping.
# Additional data file already exists for date 20140314. Skipping.
# Additional data file already exists for date 20140315. Skipping.
# Additional data file already exists for date 20140316. Skipping.
# Additional data file already exists for date 20140317. Skipping.
# Additional data file already exists for date 20140318. Skipping.
# Additional data file already exists for date 20140319. Skipping.
# Additional data file already exists for date 20140320. Skipping.
# Additional data file already exists for date 20140321. Skipping.
# Additional data file already exists for date 20140322. Skipping.
# Additional data file already exists for date 20140323. Skipping.
# Additional data file already exists for date 20140324. Skipping.
# Additional data file already exists for date 20140325. Skipping.
# Additional data file already exists for date 20140326. Skipping.
# Additional data file already exists for date 20140327. Skipping.
# Additional data file already exists for date 20140328. Skipping.
# Additional data file already exists for date 20140329. Skipping.
# Additional data file already exists for date 20140330. Skipping.
# Additional data file already exists for date 20140331. Skipping.
# Additional data file already exists for date 20140401. Skipping.
# Additional data file already exists for date 20140402. Skipping.
# Additional data file already exists for date 20140403. Skipping.
# Additional data file already exists for date 20140404. Skipping.
# Additional data file already exists for date 20140405. Skipping.
# Additional data file already exists for date 20140406. Skipping.
# Additional data file already exists for date 20140408. Skipping.
# Additional data file already exists for date 20140409. Skipping.
# Additional data file already exists for date 20140410. Skipping.
# Additional data file already exists for date 20140411. Skipping.
# Additional data file already exists for date 20140412. Skipping.
# Additional data file already exists for date 20140413. Skipping.
# Additional data file already exists for date 20140414. Skipping.
# Additional data file already exists for date 20140415. Skipping.
# Additional data file already exists for date 20140416. Skipping.
# Additional data file already exists for date 20140419. Skipping.
# Additional data file already exists for date 20140420. Skipping.
# Additional data file already exists for date 20140421. Skipping.
# Additional data file already exists for date 20140422. Skipping.
# Additional data file already exists for date 20140423. Skipping.
# Additional data file already exists for date 20140424. Skipping.
# Additional data file already exists for date 20140425. Skipping.
# Additional data file already exists for date 20140426. Skipping.
# Additional data file already exists for date 20140427. Skipping.
# Additional data file already exists for date 20140428. Skipping.
# Additional data file already exists for date 20140429. Skipping.
# Additional data file already exists for date 20140430. Skipping.
# Additional data file already exists for date 20140501. Skipping.
# Additional data file already exists for date 20140502. Skipping.
# Additional data file already exists for date 20140503. Skipping.
# Additional data file already exists for date 20140504. Skipping.
# Additional data file already exists for date 20140505. Skipping.
# Additional data file already exists for date 20140506. Skipping.
# Additional data file already exists for date 20140507. Skipping.
# Additional data file already exists for date 20140508. Skipping.
# Additional data file already exists for date 20140509. Skipping.
# Additional data file already exists for date 20140510. Skipping.
# Additional data file already exists for date 20140511. Skipping.
# Additional data file already exists for date 20140512. Skipping.
# Additional data file already exists for date 20140513. Skipping.
# Additional data file already exists for date 20140514. Skipping.
# Additional data file already exists for date 20140515. Skipping.
# Additional data file already exists for date 20140518. Skipping.
# Additional data file already exists for date 20140519. Skipping.
# Additional data file already exists for date 20140520. Skipping.
# Additional data file already exists for date 20140521. Skipping.
# Additional data file already exists for date 20140524. Skipping.
# Additional data file already exists for date 20140525. Skipping.
# Additional data file already exists for date 20140526. Skipping.
# Additional data file already exists for date 20140527. Skipping.
# Additional data file already exists for date 20140528. Skipping.
# Additional data file already exists for date 20140529. Skipping.
# Additional data file already exists for date 20140530. Skipping.
# Additional data file already exists for date 20140531. Skipping.
# Additional data file already exists for date 20140605. Skipping.
# Additional data file already exists for date 20140608. Skipping.
# Additional data file already exists for date 20140610. Skipping.
# Additional data file already exists for date 20140612. Skipping.
# Additional data file already exists for date 20140615. Skipping.
# Additional data file already exists for date 20141028. Skipping.
# Additional data file already exists for date 20141029. Skipping.
# Additional data file already exists for date 20141030. Skipping.
# Additional data file already exists for date 20141031. Skipping.
# Additional data file already exists for date 20141101. Skipping.
# Additional data file already exists for date 20141102. Skipping.
# Additional data file already exists for date 20141103. Skipping.
# Additional data file already exists for date 20141104. Skipping.
# Additional data file already exists for date 20141105. Skipping.
# Additional data file already exists for date 20141106. Skipping.
# Additional data file already exists for date 20141107. Skipping.
# Additional data file already exists for date 20141108. Skipping.
# Additional data file already exists for date 20141109. Skipping.
# Additional data file already exists for date 20141110. Skipping.
# Additional data file already exists for date 20141111. Skipping.
# Additional data file already exists for date 20141112. Skipping.
# Additional data file already exists for date 20141113. Skipping.
# Additional data file already exists for date 20141114. Skipping.
# Additional data file already exists for date 20141115. Skipping.
# Additional data file already exists for date 20141116. Skipping.
# Additional data file already exists for date 20141117. Skipping.
# Additional data file already exists for date 20141118. Skipping.
# Additional data file already exists for date 20141119. Skipping.
# Additional data file already exists for date 20141120. Skipping.
# Additional data file already exists for date 20141121. Skipping.
# Additional data file already exists for date 20141122. Skipping.
# Additional data file already exists for date 20141123. Skipping.
# Additional data file already exists for date 20141124. Skipping.
# Additional data file already exists for date 20141125. Skipping.
# Additional data file already exists for date 20141126. Skipping.
# Additional data file already exists for date 20141128. Skipping.
# Additional data file already exists for date 20141129. Skipping.
# Additional data file already exists for date 20141130. Skipping.
# Additional data file already exists for date 20141201. Skipping.
# Additional data file already exists for date 20141202. Skipping.
# Additional data file already exists for date 20141203. Skipping.
# Additional data file already exists for date 20141204. Skipping.
# Additional data file already exists for date 20141205. Skipping.
# Additional data file already exists for date 20141206. Skipping.
# Additional data file already exists for date 20141207. Skipping.
# Additional data file already exists for date 20141208. Skipping.
# Additional data file already exists for date 20141209. Skipping.
# Additional data file already exists for date 20141210. Skipping.
# Additional data file already exists for date 20141211. Skipping.
# Additional data file already exists for date 20141212. Skipping.
# Additional data file already exists for date 20141213. Skipping.
# Additional data file already exists for date 20141214. Skipping.
# Additional data file already exists for date 20141215. Skipping.
# Additional data file already exists for date 20141216. Skipping.
# Additional data file already exists for date 20141217. Skipping.
# Additional data file already exists for date 20141218. Skipping.
# Additional data file already exists for date 20141219. Skipping.
# Additional data file already exists for date 20141220. Skipping.
# Additional data file already exists for date 20141221. Skipping.
# Additional data file already exists for date 20141222. Skipping.
# Additional data file already exists for date 20141223. Skipping.
# Additional data file already exists for date 20141225. Skipping.
# Additional data file already exists for date 20141226. Skipping.
# Additional data file already exists for date 20141227. Skipping.
# Additional data file already exists for date 20141228. Skipping.
# Additional data file already exists for date 20141229. Skipping.
# Additional data file already exists for date 20141230. Skipping.
# Additional data file already exists for date 20141231. Skipping.
# Additional data file already exists for date 20150101. Skipping.
# Additional data file already exists for date 20150102. Skipping.
# Additional data file already exists for date 20150103. Skipping.
# Additional data file already exists for date 20150104. Skipping.
# Additional data file already exists for date 20150105. Skipping.
# Additional data file already exists for date 20150106. Skipping.
# Additional data file already exists for date 20150107. Skipping.
# Additional data file already exists for date 20150108. Skipping.
# Additional data file already exists for date 20150109. Skipping.
# Additional data file already exists for date 20150110. Skipping.
# Additional data file already exists for date 20150111. Skipping.
# Additional data file already exists for date 20150112. Skipping.
# Additional data file already exists for date 20150113. Skipping.
# Additional data file already exists for date 20150114. Skipping.
# Additional data file already exists for date 20150115. Skipping.
# Additional data file already exists for date 20150116. Skipping.
# Additional data file already exists for date 20150117. Skipping.
# Additional data file already exists for date 20150118. Skipping.
# Additional data file already exists for date 20150119. Skipping.
# Additional data file already exists for date 20150120. Skipping.
# Additional data file already exists for date 20150121. Skipping.
# Additional data file already exists for date 20150122. Skipping.
# Additional data file already exists for date 20150123. Skipping.
# Additional data file already exists for date 20150124. Skipping.
# Additional data file already exists for date 20150125. Skipping.
# Additional data file already exists for date 20150126. Skipping.
# Additional data file already exists for date 20150127. Skipping.
# Additional data file already exists for date 20150128. Skipping.
# Additional data file already exists for date 20150129. Skipping.
# Additional data file already exists for date 20150130. Skipping.
# Additional data file already exists for date 20150131. Skipping.
# Additional data file already exists for date 20150201. Skipping.
# Additional data file already exists for date 20150202. Skipping.
# Additional data file already exists for date 20150203. Skipping.
# Additional data file already exists for date 20150204. Skipping.
# Additional data file already exists for date 20150205. Skipping.
# Additional data file already exists for date 20150206. Skipping.
# Additional data file already exists for date 20150207. Skipping.
# Additional data file already exists for date 20150208. Skipping.
# Additional data file already exists for date 20150209. Skipping.
# Additional data file already exists for date 20150210. Skipping.
# Additional data file already exists for date 20150211. Skipping.
# Additional data file already exists for date 20150212. Skipping.
# Additional data file already exists for date 20150219. Skipping.
# Additional data file already exists for date 20150220. Skipping.
# Additional data file already exists for date 20150221. Skipping.
# Additional data file already exists for date 20150222. Skipping.
# Additional data file already exists for date 20150223. Skipping.
# Additional data file already exists for date 20150224. Skipping.
# Additional data file already exists for date 20150225. Skipping.
# Additional data file already exists for date 20150226. Skipping.
# Additional data file already exists for date 20150227. Skipping.
# Additional data file already exists for date 20150228. Skipping.
# Additional data file already exists for date 20150301. Skipping.
# Additional data file already exists for date 20150302. Skipping.
# Additional data file already exists for date 20150303. Skipping.
# Additional data file already exists for date 20150304. Skipping.
# Additional data file already exists for date 20150305. Skipping.
# Additional data file already exists for date 20150306. Skipping.
# Additional data file already exists for date 20150307. Skipping.
# Additional data file already exists for date 20150308. Skipping.
# Additional data file already exists for date 20150309. Skipping.
# Additional data file already exists for date 20150310. Skipping.
# Additional data file already exists for date 20150311. Skipping.
# Additional data file already exists for date 20150312. Skipping.
# Additional data file already exists for date 20150313. Skipping.
# Additional data file already exists for date 20150314. Skipping.
# Additional data file already exists for date 20150315. Skipping.
# Additional data file already exists for date 20150316. Skipping.
# Additional data file already exists for date 20150317. Skipping.
# Additional data file already exists for date 20150318. Skipping.
# Additional data file already exists for date 20150319. Skipping.
# Additional data file already exists for date 20150320. Skipping.
# Additional data file already exists for date 20150321. Skipping.
# Additional data file already exists for date 20150322. Skipping.
# Additional data file already exists for date 20150323. Skipping.
# Additional data file already exists for date 20150324. Skipping.
# Additional data file already exists for date 20150325. Skipping.
# Additional data file already exists for date 20150326. Skipping.
# Additional data file already exists for date 20150327. Skipping.
# Additional data file already exists for date 20150328. Skipping.
# Additional data file already exists for date 20150329. Skipping.
# Additional data file already exists for date 20150330. Skipping.
# Additional data file already exists for date 20150331. Skipping.
# Additional data file already exists for date 20150401. Skipping.
# Additional data file already exists for date 20150402. Skipping.
# Additional data file already exists for date 20150403. Skipping.
# Additional data file already exists for date 20150404. Skipping.
# Additional data file already exists for date 20150405. Skipping.
# Additional data file already exists for date 20150406. Skipping.
# Additional data file already exists for date 20150407. Skipping.
# Additional data file already exists for date 20150408. Skipping.
# Additional data file already exists for date 20150409. Skipping.
# Additional data file already exists for date 20150410. Skipping.
# Additional data file already exists for date 20150411. Skipping.
# Additional data file already exists for date 20150412. Skipping.
# Additional data file already exists for date 20150413. Skipping.
# Additional data file already exists for date 20150414. Skipping.
# Additional data file already exists for date 20150415. Skipping.
# Additional data file already exists for date 20150418. Skipping.
# Additional data file already exists for date 20150419. Skipping.
# Additional data file already exists for date 20150420. Skipping.
# Additional data file already exists for date 20150421. Skipping.
# Additional data file already exists for date 20150422. Skipping.
# Additional data file already exists for date 20150423. Skipping.
# Additional data file already exists for date 20150424. Skipping.
# Additional data file already exists for date 20150425. Skipping.
# Additional data file already exists for date 20150426. Skipping.
# Additional data file already exists for date 20150427. Skipping.
# Additional data file already exists for date 20150428. Skipping.
# Additional data file already exists for date 20150429. Skipping.
# Additional data file already exists for date 20150430. Skipping.
# Additional data file already exists for date 20150501. Skipping.
# Additional data file already exists for date 20150502. Skipping.
# Additional data file already exists for date 20150503. Skipping.
# Additional data file already exists for date 20150504. Skipping.
# Additional data file already exists for date 20150505. Skipping.
# Additional data file already exists for date 20150506. Skipping.
# Additional data file already exists for date 20150508. Skipping.
# Additional data file already exists for date 20150509. Skipping.
# Additional data file already exists for date 20150510. Skipping.
# Additional data file already exists for date 20150511. Skipping.
# Additional data file already exists for date 20150512. Skipping.
# Additional data file already exists for date 20150513. Skipping.
# Additional data file already exists for date 20150514. Skipping.
# Additional data file already exists for date 20150515. Skipping.
# Additional data file already exists for date 20150517. Skipping.
# Additional data file already exists for date 20150519. Skipping.
# Additional data file already exists for date 20150520. Skipping.
# Additional data file already exists for date 20150521. Skipping.
# Additional data file already exists for date 20150522. Skipping.
# Additional data file already exists for date 20150523. Skipping.
# Additional data file already exists for date 20150524. Skipping.
# Additional data file already exists for date 20150525. Skipping.
# Additional data file already exists for date 20150526. Skipping.
# Additional data file already exists for date 20150527. Skipping.
# Additional data file already exists for date 20150604. Skipping.
# Additional data file already exists for date 20150607. Skipping.
# Additional data file already exists for date 20150609. Skipping.
# Additional data file already exists for date 20150611. Skipping.
# Additional data file already exists for date 20150614. Skipping.
# Additional data file already exists for date 20150616. Skipping.
# Additional data file already exists for date 20151027. Skipping.
# Additional data file already exists for date 20151028. Skipping.
# Additional data file already exists for date 20151029. Skipping.
# Additional data file already exists for date 20151030. Skipping.
# Additional data file already exists for date 20151031. Skipping.
# Additional data file already exists for date 20151101. Skipping.
# Additional data file already exists for date 20151102. Skipping.
# Additional data file already exists for date 20151103. Skipping.
# Additional data file already exists for date 20151104. Skipping.
# Additional data file already exists for date 20151105. Skipping.
# Additional data file already exists for date 20151106. Skipping.
# Additional data file already exists for date 20151107. Skipping.
# Additional data file already exists for date 20151108. Skipping.
# Additional data file already exists for date 20151109. Skipping.
# Additional data file already exists for date 20151110. Skipping.
# Additional data file already exists for date 20151111. Skipping.
# Additional data file already exists for date 20151112. Skipping.
# Additional data file already exists for date 20151113. Skipping.
# Additional data file already exists for date 20151114. Skipping.
# Additional data file already exists for date 20151115. Skipping.
# Additional data file already exists for date 20151116. Skipping.
# Additional data file already exists for date 20151117. Skipping.
# Additional data file already exists for date 20151118. Skipping.
# Additional data file already exists for date 20151119. Skipping.
# Additional data file already exists for date 20151120. Skipping.
# Additional data file already exists for date 20151121. Skipping.
# Additional data file already exists for date 20151122. Skipping.
# Additional data file already exists for date 20151123. Skipping.
# Additional data file already exists for date 20151124. Skipping.
# Additional data file already exists for date 20151125. Skipping.
# Additional data file already exists for date 20151127. Skipping.
# Additional data file already exists for date 20151128. Skipping.
# Additional data file already exists for date 20151129. Skipping.
# Additional data file already exists for date 20151130. Skipping.
# Additional data file already exists for date 20151201. Skipping.
# Additional data file already exists for date 20151202. Skipping.
# Additional data file already exists for date 20151203. Skipping.
# Additional data file already exists for date 20151204. Skipping.
# Additional data file already exists for date 20151205. Skipping.
# Additional data file already exists for date 20151206. Skipping.
# Additional data file already exists for date 20151207. Skipping.
# Additional data file already exists for date 20151208. Skipping.
# Additional data file already exists for date 20151209. Skipping.
# Additional data file already exists for date 20151210. Skipping.
# Additional data file already exists for date 20151211. Skipping.
# Additional data file already exists for date 20151212. Skipping.
# Additional data file already exists for date 20151213. Skipping.
# Additional data file already exists for date 20151214. Skipping.
# Additional data file already exists for date 20151215. Skipping.
# Additional data file already exists for date 20151216. Skipping.
# Additional data file already exists for date 20151217. Skipping.
# Additional data file already exists for date 20151218. Skipping.
# Additional data file already exists for date 20151219. Skipping.
# Additional data file already exists for date 20151220. Skipping.
# Additional data file already exists for date 20151221. Skipping.
# Additional data file already exists for date 20151222. Skipping.
# Additional data file already exists for date 20151223. Skipping.
# Additional data file already exists for date 20151225. Skipping.
# Additional data file already exists for date 20151226. Skipping.
# Additional data file already exists for date 20151227. Skipping.
# Additional data file already exists for date 20151228. Skipping.
# Additional data file already exists for date 20151229. Skipping.
# Additional data file already exists for date 20151230. Skipping.
# Additional data file already exists for date 20151231. Skipping.
# Additional data file already exists for date 20160101. Skipping.
# Additional data file already exists for date 20160102. Skipping.
# Additional data file already exists for date 20160103. Skipping.
# Additional data file already exists for date 20160104. Skipping.
# Additional data file already exists for date 20160105. Skipping.
# Additional data file already exists for date 20160106. Skipping.
# Additional data file already exists for date 20160107. Skipping.
# Additional data file already exists for date 20160108. Skipping.
# Additional data file already exists for date 20160109. Skipping.
# Additional data file already exists for date 20160110. Skipping.
# Additional data file already exists for date 20160111. Skipping.
# Additional data file already exists for date 20160112. Skipping.
# Additional data file already exists for date 20160113. Skipping.
# Additional data file already exists for date 20160114. Skipping.
# Additional data file already exists for date 20160115. Skipping.
# Additional data file already exists for date 20160116. Skipping.
# Additional data file already exists for date 20160117. Skipping.
# Additional data file already exists for date 20160118. Skipping.
# Additional data file already exists for date 20160119. Skipping.
# Additional data file already exists for date 20160120. Skipping.
# Additional data file already exists for date 20160121. Skipping.
# Additional data file already exists for date 20160122. Skipping.
# Additional data file already exists for date 20160123. Skipping.
# Additional data file already exists for date 20160124. Skipping.
# Additional data file already exists for date 20160125. Skipping.
# Additional data file already exists for date 20160126. Skipping.
# Additional data file already exists for date 20160127. Skipping.
# Additional data file already exists for date 20160128. Skipping.
# Additional data file already exists for date 20160129. Skipping.
# Additional data file already exists for date 20160130. Skipping.
# Additional data file already exists for date 20160131. Skipping.
# Additional data file already exists for date 20160201. Skipping.
# Additional data file already exists for date 20160202. Skipping.
# Additional data file already exists for date 20160203. Skipping.
# Additional data file already exists for date 20160204. Skipping.
# Additional data file already exists for date 20160205. Skipping.
# Additional data file already exists for date 20160206. Skipping.
# Additional data file already exists for date 20160207. Skipping.
# Additional data file already exists for date 20160208. Skipping.
# Additional data file already exists for date 20160209. Skipping.
# Additional data file already exists for date 20160210. Skipping.
# Additional data file already exists for date 20160211. Skipping.
# Additional data file already exists for date 20160218. Skipping.
# Additional data file already exists for date 20160219. Skipping.
# Additional data file already exists for date 20160220. Skipping.
# Additional data file already exists for date 20160221. Skipping.
# Additional data file already exists for date 20160222. Skipping.
# Additional data file already exists for date 20160223. Skipping.
# Additional data file already exists for date 20160224. Skipping.
# Additional data file already exists for date 20160225. Skipping.
# Additional data file already exists for date 20160226. Skipping.
# Additional data file already exists for date 20160227. Skipping.
# Additional data file already exists for date 20160228. Skipping.
# Additional data file already exists for date 20160229. Skipping.
# Additional data file already exists for date 20160301. Skipping.
# Additional data file already exists for date 20160302. Skipping.
# Additional data file already exists for date 20160303. Skipping.
# Additional data file already exists for date 20160304. Skipping.
# Additional data file already exists for date 20160305. Skipping.
# Additional data file already exists for date 20160306. Skipping.
# Additional data file already exists for date 20160307. Skipping.
# Additional data file already exists for date 20160308. Skipping.
# Additional data file already exists for date 20160309. Skipping.
# Additional data file already exists for date 20160310. Skipping.
# Additional data file already exists for date 20160311. Skipping.
# Additional data file already exists for date 20160312. Skipping.
# Additional data file already exists for date 20160313. Skipping.
# Additional data file already exists for date 20160314. Skipping.
# Additional data file already exists for date 20160315. Skipping.
# Additional data file already exists for date 20160316. Skipping.
# Additional data file already exists for date 20160317. Skipping.
# Additional data file already exists for date 20160318. Skipping.
# Additional data file already exists for date 20160319. Skipping.
# Additional data file already exists for date 20160320. Skipping.
# Additional data file already exists for date 20160321. Skipping.
# Additional data file already exists for date 20160322. Skipping.
# Additional data file already exists for date 20160323. Skipping.
# Additional data file already exists for date 20160324. Skipping.
# Additional data file already exists for date 20160325. Skipping.
# Additional data file already exists for date 20160326. Skipping.
# Additional data file already exists for date 20160327. Skipping.
# Additional data file already exists for date 20160328. Skipping.
# Additional data file already exists for date 20160329. Skipping.
# Additional data file already exists for date 20160330. Skipping.
# Additional data file already exists for date 20160331. Skipping.
# Additional data file already exists for date 20160401. Skipping.
# Additional data file already exists for date 20160402. Skipping.
# Additional data file already exists for date 20160403. Skipping.
# Additional data file already exists for date 20160405. Skipping.
# Additional data file already exists for date 20160406. Skipping.
# Additional data file already exists for date 20160407. Skipping.
# Additional data file already exists for date 20160408. Skipping.
# Additional data file already exists for date 20160409. Skipping.
# Additional data file already exists for date 20160410. Skipping.
# Additional data file already exists for date 20160411. Skipping.
# Additional data file already exists for date 20160412. Skipping.
# Additional data file already exists for date 20160413. Skipping.
# Additional data file already exists for date 20160416. Skipping.
# Additional data file already exists for date 20160417. Skipping.
# Additional data file already exists for date 20160418. Skipping.
# Additional data file already exists for date 20160419. Skipping.
# Additional data file already exists for date 20160420. Skipping.
# Additional data file already exists for date 20160421. Skipping.
# Additional data file already exists for date 20160422. Skipping.
# Additional data file already exists for date 20160423. Skipping.
# Additional data file already exists for date 20160424. Skipping.
# Additional data file already exists for date 20160425. Skipping.
# Additional data file already exists for date 20160426. Skipping.
# Additional data file already exists for date 20160427. Skipping.
# Additional data file already exists for date 20160428. Skipping.
# Additional data file already exists for date 20160429. Skipping.
# Additional data file already exists for date 20160430. Skipping.
# Additional data file already exists for date 20160501. Skipping.
# Additional data file already exists for date 20160502. Skipping.
# Additional data file already exists for date 20160503. Skipping.
# Additional data file already exists for date 20160504. Skipping.
# Additional data file already exists for date 20160505. Skipping.
# Additional data file already exists for date 20160506. Skipping.
# Additional data file already exists for date 20160507. Skipping.
# Additional data file already exists for date 20160508. Skipping.
# Additional data file already exists for date 20160509. Skipping.
# Additional data file already exists for date 20160510. Skipping.
# Additional data file already exists for date 20160511. Skipping.
# Additional data file already exists for date 20160512. Skipping.
# Additional data file already exists for date 20160513. Skipping.
# Additional data file already exists for date 20160515. Skipping.
# Additional data file already exists for date 20160516. Skipping.
# Additional data file already exists for date 20160517. Skipping.
# Additional data file already exists for date 20160518. Skipping.
# Additional data file already exists for date 20160519. Skipping.
# Additional data file already exists for date 20160521. Skipping.
# Additional data file already exists for date 20160522. Skipping.
# Additional data file already exists for date 20160523. Skipping.
# Additional data file already exists for date 20160524. Skipping.
# Additional data file already exists for date 20160525. Skipping.
# Additional data file already exists for date 20160526. Skipping.
# Additional data file already exists for date 20160527. Skipping.
# Additional data file already exists for date 20160528. Skipping.
# Additional data file already exists for date 20160530. Skipping.
# Additional data file already exists for date 20160602. Skipping.
# Additional data file already exists for date 20160605. Skipping.
# Additional data file already exists for date 20160608. Skipping.
# Additional data file already exists for date 20160610. Skipping.
# Additional data file already exists for date 20160613. Skipping.
# Additional data file already exists for date 20160616. Skipping.
# Additional data file already exists for date 20160619. Skipping.
# Additional data file already exists for date 20161025. Skipping.
# Additional data file already exists for date 20161026. Skipping.
# Additional data file already exists for date 20161027. Skipping.
# Additional data file already exists for date 20161028. Skipping.
# Additional data file already exists for date 20161029. Skipping.
# Additional data file already exists for date 20161030. Skipping.
# Additional data file already exists for date 20161031. Skipping.
# Additional data file already exists for date 20161101. Skipping.
# Additional data file already exists for date 20161102. Skipping.
# Additional data file already exists for date 20161103. Skipping.
# Additional data file already exists for date 20161104. Skipping.
# Additional data file already exists for date 20161105. Skipping.
# Additional data file already exists for date 20161106. Skipping.
# Additional data file already exists for date 20161107. Skipping.
# Additional data file already exists for date 20161108. Skipping.
# Additional data file already exists for date 20161109. Skipping.
# Additional data file already exists for date 20161110. Skipping.
# Additional data file already exists for date 20161111. Skipping.
# Additional data file already exists for date 20161112. Skipping.
# Additional data file already exists for date 20161113. Skipping.
# Additional data file already exists for date 20161114. Skipping.
# Additional data file already exists for date 20161115. Skipping.
# Additional data file already exists for date 20161116. Skipping.
# Additional data file already exists for date 20161117. Skipping.
# Additional data file already exists for date 20161118. Skipping.
# Additional data file already exists for date 20161119. Skipping.
# Additional data file already exists for date 20161120. Skipping.
# Additional data file already exists for date 20161121. Skipping.
# Additional data file already exists for date 20161122. Skipping.
# Additional data file already exists for date 20161123. Skipping.
# Additional data file already exists for date 20161125. Skipping.
# Additional data file already exists for date 20161126. Skipping.
# Additional data file already exists for date 20161127. Skipping.
# Additional data file already exists for date 20161128. Skipping.
# Additional data file already exists for date 20161129. Skipping.
# Additional data file already exists for date 20161130. Skipping.
# Additional data file already exists for date 20161201. Skipping.
# Additional data file already exists for date 20161202. Skipping.
# Additional data file already exists for date 20161203. Skipping.
# Additional data file already exists for date 20161204. Skipping.
# Additional data file already exists for date 20161205. Skipping.
# Additional data file already exists for date 20161206. Skipping.
# Additional data file already exists for date 20161207. Skipping.
# Additional data file already exists for date 20161208. Skipping.
# Additional data file already exists for date 20161209. Skipping.
# Additional data file already exists for date 20161210. Skipping.
# Additional data file already exists for date 20161211. Skipping.
# Additional data file already exists for date 20161212. Skipping.
# Additional data file already exists for date 20161213. Skipping.
# Additional data file already exists for date 20161214. Skipping.
# Additional data file already exists for date 20161215. Skipping.
# Additional data file already exists for date 20161216. Skipping.
# Additional data file already exists for date 20161217. Skipping.
# Additional data file already exists for date 20161218. Skipping.
# Additional data file already exists for date 20161219. Skipping.
# Additional data file already exists for date 20161220. Skipping.
# Additional data file already exists for date 20161221. Skipping.
# Additional data file already exists for date 20161222. Skipping.
# Additional data file already exists for date 20161223. Skipping.
# Additional data file already exists for date 20161225. Skipping.
# Additional data file already exists for date 20161226. Skipping.
# Additional data file already exists for date 20161227. Skipping.
# Additional data file already exists for date 20161228. Skipping.
# Additional data file already exists for date 20161229. Skipping.
# Additional data file already exists for date 20161230. Skipping.
# Additional data file already exists for date 20161231. Skipping.
# Additional data file already exists for date 20170101. Skipping.
# Additional data file already exists for date 20170102. Skipping.
# Additional data file already exists for date 20170103. Skipping.
# Additional data file already exists for date 20170104. Skipping.
# Additional data file already exists for date 20170105. Skipping.
# Additional data file already exists for date 20170106. Skipping.
# Additional data file already exists for date 20170107. Skipping.
# Additional data file already exists for date 20170108. Skipping.
# Additional data file already exists for date 20170109. Skipping.
# Additional data file already exists for date 20170110. Skipping.
# Additional data file already exists for date 20170111. Skipping.
# Additional data file already exists for date 20170112. Skipping.
# Additional data file already exists for date 20170113. Skipping.
# Additional data file already exists for date 20170114. Skipping.
# Additional data file already exists for date 20170115. Skipping.
# Additional data file already exists for date 20170116. Skipping.
# Additional data file already exists for date 20170117. Skipping.
# Additional data file already exists for date 20170118. Skipping.
# Additional data file already exists for date 20170119. Skipping.
# Additional data file already exists for date 20170120. Skipping.
# Additional data file already exists for date 20170121. Skipping.
# Additional data file already exists for date 20170122. Skipping.
# Additional data file already exists for date 20170123. Skipping.
# Additional data file already exists for date 20170124. Skipping.
# Additional data file already exists for date 20170125. Skipping.
# Additional data file already exists for date 20170126. Skipping.
# Additional data file already exists for date 20170127. Skipping.
# Additional data file already exists for date 20170128. Skipping.
# Additional data file already exists for date 20170129. Skipping.
# Additional data file already exists for date 20170130. Skipping.
# Additional data file already exists for date 20170131. Skipping.
# Additional data file already exists for date 20170201. Skipping.
# Additional data file already exists for date 20170202. Skipping.
# Additional data file already exists for date 20170203. Skipping.
# Additional data file already exists for date 20170204. Skipping.
# Additional data file already exists for date 20170205. Skipping.
# Additional data file already exists for date 20170206. Skipping.
# Additional data file already exists for date 20170207. Skipping.
# Additional data file already exists for date 20170208. Skipping.
# Additional data file already exists for date 20170209. Skipping.
# Additional data file already exists for date 20170210. Skipping.
# Additional data file already exists for date 20170211. Skipping.
# Additional data file already exists for date 20170212. Skipping.
# Additional data file already exists for date 20170213. Skipping.
# Additional data file already exists for date 20170214. Skipping.
# Additional data file already exists for date 20170215. Skipping.
# Additional data file already exists for date 20170216. Skipping.
# Additional data file already exists for date 20170223. Skipping.
# Additional data file already exists for date 20170224. Skipping.
# Additional data file already exists for date 20170225. Skipping.
# ...
# Processing date: 20240507
# Successfully pulled Overall defense data for 20240507
# Successfully pulled 3PT defense data for 20240507
# Successfully pulled 2PT defense data for 20240507
# Successfully pulled <6ft defense data for 20240507
# Successfully pulled <10ft defense data for 20240507
# Successfully pulled >15ft defense data for 20240507
# Successfully pulled hustle stats for 20240507
# Successfully pulled post touch stats for 20240507
# Successfully pulled speed distance stats for 20240507
# Saved additional data for date 20240507
# Updated game file: 42300201
# Updated game file: 42300221
# Processing date: 20240508
# Successfully pulled Overall defense data for 20240508
# Successfully pulled 3PT defense data for 20240508
# Successfully pulled 2PT defense data for 20240508
# Successfully pulled <6ft defense data for 20240508
# Successfully pulled <10ft defense data for 20240508
# Successfully pulled >15ft defense data for 20240508
# Successfully pulled hustle stats for 20240508
# Successfully pulled post touch stats for 20240508
# Successfully pulled speed distance stats for 20240508
# Saved additional data for date 20240508
# Updated game file: 42300212
# Processing date: 20240509
# Successfully pulled Overall defense data for 20240509
# Successfully pulled 3PT defense data for 20240509
# Successfully pulled 2PT defense data for 20240509
# Successfully pulled <6ft defense data for 20240509
# Successfully pulled <10ft defense data for 20240509
# Successfully pulled >15ft defense data for 20240509
# Successfully pulled hustle stats for 20240509
# Successfully pulled post touch stats for 20240509
# Successfully pulled speed distance stats for 20240509
# Saved additional data for date 20240509
# Updated game file: 42300222
# Updated game file: 42300202
# Processing date: 20240510
# Successfully pulled Overall defense data for 20240510
# Successfully pulled 3PT defense data for 20240510
# Successfully pulled 2PT defense data for 20240510
# Successfully pulled <6ft defense data for 20240510
# Successfully pulled <10ft defense data for 20240510
# Successfully pulled >15ft defense data for 20240510
# Successfully pulled hustle stats for 20240510
# Successfully pulled post touch stats for 20240510
# Successfully pulled speed distance stats for 20240510
# Saved additional data for date 20240510
# Updated game file: 42300233
# Updated game file: 42300213
# Processing date: 20240511
# Successfully pulled Overall defense data for 20240511
# Successfully pulled 3PT defense data for 20240511
# Successfully pulled 2PT defense data for 20240511
# Successfully pulled <6ft defense data for 20240511
# Successfully pulled <10ft defense data for 20240511
# Successfully pulled >15ft defense data for 20240511
# Successfully pulled hustle stats for 20240511
# Successfully pulled post touch stats for 20240511
# Successfully pulled speed distance stats for 20240511
# Saved additional data for date 20240511
# Updated game file: 42300223
# Updated game file: 42300203
# Processing date: 20240512
# Successfully pulled Overall defense data for 20240512
# Successfully pulled 3PT defense data for 20240512
# Successfully pulled 2PT defense data for 20240512
# Successfully pulled <6ft defense data for 20240512
# Successfully pulled <10ft defense data for 20240512
# Successfully pulled >15ft defense data for 20240512
# Successfully pulled hustle stats for 20240512
# Successfully pulled post touch stats for 20240512
# Successfully pulled speed distance stats for 20240512
# Saved additional data for date 20240512
# Updated game file: 42300214
# Updated game file: 42300234
# Processing date: 20240513
# Successfully pulled Overall defense data for 20240513
# Successfully pulled 3PT defense data for 20240513
# Successfully pulled 2PT defense data for 20240513
# Successfully pulled <6ft defense data for 20240513
# Successfully pulled <10ft defense data for 20240513
# Successfully pulled >15ft defense data for 20240513
# Successfully pulled hustle stats for 20240513
# Successfully pulled post touch stats for 20240513
# Successfully pulled speed distance stats for 20240513
# Saved additional data for date 20240513
# Updated game file: 42300204
# Updated game file: 42300224
# Processing date: 20240514
# Successfully pulled Overall defense data for 20240514
# Successfully pulled 3PT defense data for 20240514
# Successfully pulled 2PT defense data for 20240514
# Successfully pulled <6ft defense data for 20240514
# Successfully pulled <10ft defense data for 20240514
# Successfully pulled >15ft defense data for 20240514
# Successfully pulled hustle stats for 20240514
# Successfully pulled post touch stats for 20240514
# Successfully pulled speed distance stats for 20240514
# Saved additional data for date 20240514
# Updated game file: 42300215
# Updated game file: 42300235
# Processing date: 20240515
# Successfully pulled Overall defense data for 20240515
# Successfully pulled 3PT defense data for 20240515
# Successfully pulled 2PT defense data for 20240515
# Successfully pulled <6ft defense data for 20240515
# Successfully pulled <10ft defense data for 20240515
# Successfully pulled >15ft defense data for 20240515
# Successfully pulled hustle stats for 20240515
# Successfully pulled post touch stats for 20240515
# Successfully pulled speed distance stats for 20240515
# Saved additional data for date 20240515
# Updated game file: 42300205
# Updated game file: 42300225
# Processing date: 20240516
# Successfully pulled Overall defense data for 20240516
# Successfully pulled 3PT defense data for 20240516
# Successfully pulled 2PT defense data for 20240516
# Successfully pulled <6ft defense data for 20240516
# Successfully pulled <10ft defense data for 20240516
# Successfully pulled >15ft defense data for 20240516
# Successfully pulled hustle stats for 20240516
# Successfully pulled post touch stats for 20240516
# Successfully pulled speed distance stats for 20240516
# Saved additional data for date 20240516
# Updated game file: 42300236
# Processing date: 20240517
# Successfully pulled Overall defense data for 20240517
# Successfully pulled 3PT defense data for 20240517
# Successfully pulled 2PT defense data for 20240517
# Successfully pulled <6ft defense data for 20240517
# Successfully pulled <10ft defense data for 20240517
# Successfully pulled >15ft defense data for 20240517
# Successfully pulled hustle stats for 20240517
# Successfully pulled post touch stats for 20240517
# Successfully pulled speed distance stats for 20240517
# Saved additional data for date 20240517
# Updated game file: 42300216
# Processing date: 20240518
# Successfully pulled Overall defense data for 20240518
# Successfully pulled 3PT defense data for 20240518
# Successfully pulled 2PT defense data for 20240518
# Successfully pulled <6ft defense data for 20240518
# Successfully pulled <10ft defense data for 20240518
# Successfully pulled >15ft defense data for 20240518
# Successfully pulled hustle stats for 20240518
# Successfully pulled post touch stats for 20240518
# Successfully pulled speed distance stats for 20240518
# Saved additional data for date 20240518
# Updated game file: 42300226
# Processing date: 20240519
# Successfully pulled Overall defense data for 20240519
# Successfully pulled 3PT defense data for 20240519
# Successfully pulled 2PT defense data for 20240519
# Successfully pulled <6ft defense data for 20240519
# Successfully pulled <10ft defense data for 20240519
# Successfully pulled >15ft defense data for 20240519
# Successfully pulled hustle stats for 20240519
# Successfully pulled post touch stats for 20240519
# Successfully pulled speed distance stats for 20240519
# Saved additional data for date 20240519
# Updated game file: 42300237
# Updated game file: 42300217
# Processing date: 20240521
# Successfully pulled Overall defense data for 20240521
# Successfully pulled 3PT defense data for 20240521
# Successfully pulled 2PT defense data for 20240521
# Successfully pulled <6ft defense data for 20240521
# Successfully pulled <10ft defense data for 20240521
# Successfully pulled >15ft defense data for 20240521
# Successfully pulled hustle stats for 20240521
# Successfully pulled post touch stats for 20240521
# Successfully pulled speed distance stats for 20240521
# Saved additional data for date 20240521
# Updated game file: 42300301
# Processing date: 20240522
# Successfully pulled Overall defense data for 20240522
# Successfully pulled 3PT defense data for 20240522
# Successfully pulled 2PT defense data for 20240522
# Successfully pulled <6ft defense data for 20240522
# Successfully pulled <10ft defense data for 20240522
# Successfully pulled >15ft defense data for 20240522
# Successfully pulled hustle stats for 20240522
# Successfully pulled post touch stats for 20240522
# Successfully pulled speed distance stats for 20240522
# Saved additional data for date 20240522
# Updated game file: 42300311
# Processing date: 20240523
# Successfully pulled Overall defense data for 20240523
# Successfully pulled 3PT defense data for 20240523
# Successfully pulled 2PT defense data for 20240523
# Successfully pulled <6ft defense data for 20240523
# Successfully pulled <10ft defense data for 20240523
# Successfully pulled >15ft defense data for 20240523
# Successfully pulled hustle stats for 20240523
# Successfully pulled post touch stats for 20240523
# Successfully pulled speed distance stats for 20240523
# Saved additional data for date 20240523
# Updated game file: 42300302
# Processing date: 20240524
# Successfully pulled Overall defense data for 20240524
# Successfully pulled 3PT defense data for 20240524
# Successfully pulled 2PT defense data for 20240524
# Successfully pulled <6ft defense data for 20240524
# Successfully pulled <10ft defense data for 20240524
# Successfully pulled >15ft defense data for 20240524
# Successfully pulled hustle stats for 20240524
# Successfully pulled post touch stats for 20240524
# Successfully pulled speed distance stats for 20240524
# Saved additional data for date 20240524
# Updated game file: 42300312
# Processing date: 20240525
# Successfully pulled Overall defense data for 20240525
# Successfully pulled 3PT defense data for 20240525
# Successfully pulled 2PT defense data for 20240525
# Successfully pulled <6ft defense data for 20240525
# Successfully pulled <10ft defense data for 20240525
# Successfully pulled >15ft defense data for 20240525
# Successfully pulled hustle stats for 20240525
# Successfully pulled post touch stats for 20240525
# Successfully pulled speed distance stats for 20240525
# Saved additional data for date 20240525
# Updated game file: 42300303
# Processing date: 20240526
# Successfully pulled Overall defense data for 20240526
# Successfully pulled 3PT defense data for 20240526
# Successfully pulled 2PT defense data for 20240526
# Successfully pulled <6ft defense data for 20240526
# Successfully pulled <10ft defense data for 20240526
# Successfully pulled >15ft defense data for 20240526
# Successfully pulled hustle stats for 20240526
# Successfully pulled post touch stats for 20240526
# Successfully pulled speed distance stats for 20240526
# Saved additional data for date 20240526
# Updated game file: 42300313
# Processing date: 20240527
# Successfully pulled Overall defense data for 20240527
# Successfully pulled 3PT defense data for 20240527
# Successfully pulled 2PT defense data for 20240527
# Successfully pulled <6ft defense data for 20240527
# Successfully pulled <10ft defense data for 20240527
# Successfully pulled >15ft defense data for 20240527
# Successfully pulled hustle stats for 20240527
# Successfully pulled post touch stats for 20240527
# Successfully pulled speed distance stats for 20240527
# Saved additional data for date 20240527
# Updated game file: 42300304
# Processing date: 20240528
# Successfully pulled Overall defense data for 20240528
# Successfully pulled 3PT defense data for 20240528
# Successfully pulled 2PT defense data for 20240528
# Successfully pulled <6ft defense data for 20240528
# Successfully pulled <10ft defense data for 20240528
# Successfully pulled >15ft defense data for 20240528
# Successfully pulled hustle stats for 20240528
# Successfully pulled post touch stats for 20240528
# Successfully pulled speed distance stats for 20240528
# Saved additional data for date 20240528
# Updated game file: 42300314
# Processing date: 20240530
# Successfully pulled Overall defense data for 20240530
# Successfully pulled 3PT defense data for 20240530
# Successfully pulled 2PT defense data for 20240530
# Successfully pulled <6ft defense data for 20240530
# Successfully pulled <10ft defense data for 20240530
# Successfully pulled >15ft defense data for 20240530
# Successfully pulled hustle stats for 20240530
# Successfully pulled post touch stats for 20240530
# Successfully pulled speed distance stats for 20240530
# Saved additional data for date 20240530
# Updated game file: 42300315
# Processing date: 20240606
# Successfully pulled Overall defense data for 20240606
# Successfully pulled 3PT defense data for 20240606
# Successfully pulled 2PT defense data for 20240606
# Successfully pulled <6ft defense data for 20240606
# Successfully pulled <10ft defense data for 20240606
# Successfully pulled >15ft defense data for 20240606
# Successfully pulled hustle stats for 20240606
# Successfully pulled post touch stats for 20240606
# Successfully pulled speed distance stats for 20240606
# Saved additional data for date 20240606
# Updated game file: 42300401
# Processing date: 20240609
# Successfully pulled Overall defense data for 20240609
# Successfully pulled 3PT defense data for 20240609
# Successfully pulled 2PT defense data for 20240609
# Successfully pulled <6ft defense data for 20240609
# Successfully pulled <10ft defense data for 20240609
# Successfully pulled >15ft defense data for 20240609
# Successfully pulled hustle stats for 20240609
# Successfully pulled post touch stats for 20240609
# Successfully pulled speed distance stats for 20240609
# Saved additional data for date 20240609
# Updated game file: 42300402
# Processing date: 20240612
# Successfully pulled Overall defense data for 20240612
# Successfully pulled 3PT defense data for 20240612
# Successfully pulled 2PT defense data for 20240612
# Successfully pulled <6ft defense data for 20240612
# Successfully pulled <10ft defense data for 20240612
# Successfully pulled >15ft defense data for 20240612
# Successfully pulled hustle stats for 20240612
# Successfully pulled post touch stats for 20240612
# Successfully pulled speed distance stats for 20240612
# Saved additional data for date 20240612
# Updated game file: 42300403
# Processing date: 20240614
# Successfully pulled Overall defense data for 20240614
# Successfully pulled 3PT defense data for 20240614
# Successfully pulled 2PT defense data for 20240614
# Successfully pulled <6ft defense data for 20240614
# Successfully pulled <10ft defense data for 20240614
# Successfully pulled >15ft defense data for 20240614
# Successfully pulled hustle stats for 20240614
# Successfully pulled post touch stats for 20240614
# Successfully pulled speed distance stats for 20240614
# Saved additional data for date 20240614
# Updated game file: 42300404
# Processing date: 20240617
# Successfully pulled Overall defense data for 20240617
# Successfully pulled 3PT defense data for 20240617
# Successfully pulled 2PT defense data for 20240617
# Successfully pulled <6ft defense data for 20240617
# Successfully pulled <10ft defense data for 20240617
# Successfully pulled >15ft defense data for 20240617
# Successfully pulled hustle stats for 20240617
# Successfully pulled post touch stats for 20240617
# Successfully pulled speed distance stats for 20240617
# Saved additional data for date 20240617
# Updated game file: 42300405
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 352
#     349         cleanup_and_rename(year)
#     351 if __name__ == "__main__":
# --> 352     main()
#
# Cell In[1], line 341, in main()
#     338 end_year = 2026
#     340 # Update game files with additional data
# --> 341 update_game_files(start_year, end_year)
#     343 # Update consolidated files
#     344 for year in range(start_year, end_year):
#
# Cell In[1], line 232, in update_game_files(start_year, end_year, stype)
#     230 year=int(season.split('-')[0])
#     231 year+=1
# --> 232 cutoff= date_dict[year]
#     234 for date in sorted(existing_dates):
#     235     additional_data_file = f'{additional_data_dir}/{date}_additional.csv'
#
# KeyError: 2025
