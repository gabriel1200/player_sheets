# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import requests
import os
import time
from datetime import datetime
import glob

def format_date_to_url(date):
    # Convert date from YYYYMMDD to datetime object
    date_obj = datetime.strptime(str(date), '%Y%m%d')
    
    # Format the date as MM%2FDD%2FYYYY
    formatted_date = date_obj.strftime('%m%%2F%d%%2F%Y')
    
    return formatted_date

def pull_data(url):
    headers = {
        "Host": "stats.nba.com",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
        "Accept": "application/json, text/plain, */*",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
        "Referer": "https://stats.nba.com/",
        "Origin": "https://stats.nba.com",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
    }

    json = requests.get(url, headers=headers).json()

    if len(json["resultSets"]) == 1:
        data = json["resultSets"][0]["rowSet"]
        columns = json["resultSets"][0]["headers"]
        df = pd.DataFrame.from_records(data, columns=columns)
    else:
        data = json["resultSets"]["rowSet"]
        columns = json["resultSets"]["headers"][1]['columnNames']
        df = pd.DataFrame.from_records(data, columns=columns)

    time.sleep(.1)  # Respect rate limits
    return df

def pull_additional_data(date_num, season, stype='Regular%20Season'):
    """
    Pull additional data from new endpoints for a specific date
    """
    date = format_date_to_url(date_num)
    
    additional_data_frames = []
    year=int(season.split('-')[0])+1
    
    # Get data from your additional links
    # Link 1: Overall defense stats
    ps=False
    if stype=='Playoffs':
        ps=True
    passed=True
    url1 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Overall&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df1 = pull_data(url1)
        df1.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df1.rename(columns={col: f'overall_def_{col}' for col in df1.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df1)
        print(f"Successfully pulled Overall defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling Overall defense data for {date_num}: {str(e)}")
    
    # Link 2: 3-pointers defense stats
    url2 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=3%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df2 = pull_data(url2)
        df2.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df2.rename(columns={col: f'three_pt_def_{col}' for col in df2.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df2)
        print(f"Successfully pulled 3PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 3PT defense data for {date_num}: {str(e)}")
    
    # Link 3: 2-pointers defense stats
    url3 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=2%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df3 = pull_data(url3)
        df3.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df3.rename(columns={col: f'two_pt_def_{col}' for col in df3.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df3)
        print(f"Successfully pulled 2PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 2PT defense data for {date_num}: {str(e)}")
    
    # Link 4: Less than 6ft defense stats
    url4 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%206Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df4 = pull_data(url4)
        df4.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df4.rename(columns={col: f'less_6ft_def_{col}' for col in df4.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df4)
        print(f"Successfully pulled <6ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <6ft defense data for {date_num}: {str(e)}")
    
    # Link 5: Less than 10ft defense stats
    url5 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%2010Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df5 = pull_data(url5)
        df5.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df5.rename(columns={col: f'less_10ft_def_{col}' for col in df5.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df5)
        print(f"Successfully pulled <10ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <10ft defense data for {date_num}: {str(e)}")
    
    # Link 6: Less than 15ft defense stats
    url6 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Greater%20Than%2015Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df6 = pull_data(url6)
        df6.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df6.rename(columns={col: f'more_15ft_def_{col}' for col in df6.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df6)
        print(f"Successfully pulled >15ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <15ft defense data for {date_num}: {str(e)}")
    
    # Link 7: Hustle stats
    if year>=2016:
        url7 = f'https://stats.nba.com/stats/leaguehustlestatsplayer?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season={season}&SeasonSegment=&SeasonType={stype}&TeamID=0&VsConference=&VsDivision=&Weight='
        try:
            df7 = pull_data(url7)
            df7.rename(columns={col: f'hustle_{col}' for col in df7.columns if col != 'PLAYER_ID'}, inplace=True)
            additional_data_frames.append(df7)
            print(f"Successfully pulled hustle stats for {date_num}")
        except Exception as e:
            passed=False
            print(f"Error pulling hustle stats for {date_num}: {str(e)}")
    
    # Link 8: Post touch stats
    url8 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PostTouch&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df8 = pull_data(url8)
        df8.rename(columns={col: f'post_touch_{col}' for col in df8.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df8)
        print(f"Successfully pulled post touch stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling post touch stats for {date_num}: {str(e)}")
    
    # Link 9: Speed distance stats
    url9 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=SpeedDistance&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df9 = pull_data(url9)
        df9.rename(columns={col: f'speed_distance_{col}' for col in df9.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df9)
        print(f"Successfully pulled speed distance stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling speed distance stats for {date_num}: {str(e)}")
    
    # Merge all the additional data frames on PLAYER_ID
    result_df = additional_data_frames[0]
    for df in additional_data_frames[1:]:
        result_df = result_df.merge(df, on='PLAYER_ID', how='outer')
    
    # Add date and season information
    result_df['date'] = date_num
    result_df['season'] = season.replace('-', '_')
    
    return result_df,passed

def update_game_files(start_year, end_year, stype='Regular%20Season'):
    """
    Update existing game files with additional data for a range of seasons
    """
    # Get all dates for which we have existing data
    for year in range(start_year, end_year):
        season = f"{year-1}-{str(year)[-2:]}"
        
        # Create a directory for additional data if it doesn't exist
        additional_data_dir = f'additional_data/{year}'
        if not os.path.exists(additional_data_dir):
            os.makedirs(additional_data_dir, exist_ok=True)
        
        # Get list of game files we already have
        game_files = glob.glob(f'{year}/*.csv')
        
        # Extract unique dates from existing files
        existing_dates = set()
        date_to_games = {}
        
        # Read the date information from existing files
        for game_file in game_files:
            try:
                game_id = os.path.basename(game_file).replace('.csv', '')
                game_df = pd.read_csv(game_file)
                
                if 'date' in game_df.columns:
                    date = game_df['date'].iloc[0]
                    existing_dates.add(date)
                    
                    if date not in date_to_games:
                        date_to_games[date] = []
                    date_to_games[date].append(game_id)
            except Exception as e:
                print(f"Error reading file {game_file}: {str(e)}")
        
        # Process each date to get additional data
        date_dict={
                2014: 20140419,
                2015: 20150418,
                2016: 20160416,
                2017: 20170415,
                2018: 20180414,
                2019: 20190413,
                2020: 20200817,  # Delayed due to COVID-19
                2021: 20210522,
                2022: 20220416,
                2023: 20230415,
                2024: 20240420,
                2025: 20250420
            }
        year=int(season.split('-')[0])
        year+=1
        cutoff= date_dict[year]
  
        for date in sorted(existing_dates):
            additional_data_file = f'{additional_data_dir}/{date}_additional.csv'
            additional_df = None
            
            # Check if additional data file already exists
            if os.path.exists(additional_data_file):
                print(f"Additional data file already exists for date {date}. Loading existing file.")
                try:
                    additional_df = pd.read_csv(additional_data_file)
                    print(f"Loaded existing additional data for date {date}")
                except Exception as e:
                    print(f"Error loading existing additional data for {date}: {str(e)}")
                    continue
            else:
                print(f"Processing date: {date} - pulling new additional data")
                
                try:
                    # Pull additional data
                    if date>=cutoff:
                        season_type='Playoffs'
                    else:
                        season_type='Regular%20Season'
                    additional_df, passed = pull_additional_data(date, season, season_type)
                    
                    # Save the additional data for this date
                    if passed:
                        additional_df.to_csv(additional_data_file, index=False)
                        print(f"Saved additional data for date {date}")
                    else:
                        print(f"Failed to pull additional data for date {date}")
                        continue
                        
                except Exception as e:
                    print(f"Error processing additional data for date {date}: {str(e)}")
                    continue
            
            # Now update each game file for this date with the additional data
            # (This happens whether we loaded existing data or pulled new data)
            if additional_df is not None:
                game_ids = date_to_games.get(date, [])
                
                for game_id in game_ids:
                    game_file = f'{year}/{game_id}.csv'
                    updated_game_file = f'{year}/{game_id}_updated.csv'
                    
                    # Skip if updated file already exists
                    if os.path.exists(updated_game_file):
                        print(f"Updated game file already exists for {game_id}. Skipping.")
                        continue
                    
                    try:
                        # Load the game file data
                        game_df = pd.read_csv(game_file)
                        
                        # Identify columns to keep (merge keys) and remove overlapping columns
                        cols_to_keep = ['PLAYER_ID', 'date']
                        cols_to_remove = [col for col in game_df.columns if col in additional_df.columns and col not in cols_to_keep]

                        # Drop the overlapping columns
                        if cols_to_remove:
                            game_df = game_df.drop(columns=cols_to_remove)

                        # Merge with additional data
                        updated_df = game_df.merge(additional_df, on=cols_to_keep, how='left')

                        # Save the updated game file
                        updated_df.to_csv(updated_game_file, index=False)
                        print(f"Updated game file: {game_id}")
                    except Exception as e:
                        print(f"Error updating game file {game_id}: {str(e)}")
            else:
                print(f"No additional data available for date {date}")
 

def update_all_games_file(year):
    """
    Update the consolidated 'all_games' file with additional data
    """
    # Get all updated game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    if not updated_game_files:
        print(f"No updated game files found for year {year}")
        return
    
    
    # Combine all updated game files
    all_updated_games = []
    
    for game_file in updated_game_files:
        try:
            game_df = pd.read_csv(game_file)
            all_updated_games.append(game_df)
        except Exception as e:
            print(f"Error reading updated game file {game_file}: {str(e)}")
    
    if all_updated_games:
        # Concatenate all game data
        all_games_df = pd.concat(all_updated_games, ignore_index=True)
        
        # Save as CSV and parquet
        all_games_df.to_csv(f'all_games/all_{year}_updated.csv', index=False)
        all_games_df.to_parquet(f'all_games/all_{year}_updated.parquet', index=False)
        print(f"Updated consolidated files for year {year}")
    else:
        print(f"No valid updated game files to concatenate for year {year}")

def cleanup_and_rename(year):
    """
    After successful update, rename updated files to replace originals
    """
    # Rename individual game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    for game_file in updated_game_files:
        original_file = game_file.replace('_updated.csv', '.csv')
        os.rename(game_file, original_file)
        print(f"Replaced {original_file} with updated version")
    
    # Rename consolidated files
    if os.path.exists(f'all_games/all_{year}_updated.csv'):
        os.rename(f'all_games/all_{year}_updated.csv', f'all_games/all_{year}.csv')
        print(f"Replaced all_games/all_{year}.csv with updated version")
    
    if os.path.exists(f'all_games/all_{year}_updated.parquet'):
        os.rename(f'all_games/all_{year}_updated.parquet', f'all_games/all_{year}.parquet')
        print(f"Replaced all_games/all_{year}.parquet with updated version")

def main():
    # Define year range
    start_year = 2025
    end_year = 2026
    
    # Update game files with additional data
    update_game_files(start_year, end_year)
    
    # Update consolidated files
    for year in range(start_year, end_year):
        update_all_games_file(year)
    
    # Clean up and rename files
    for year in range(start_year, end_year):
        cleanup_and_rename(year)

if __name__ == "__main__":
    main()
# Out:
# Additional data file already exists for date 20241022. Loading existing file.
# Loaded existing additional data for date 20241022
# Updated game file: 22400062
# Updated game file: 22400958
# Updated game file: 22400967
# Updated game file: 22400965
# Updated game file: 22400964
# Updated game file: 22400960
# Updated game file: 22400966
# Additional data file already exists for date 20250315. Loading existing file.
# Loaded existing additional data for date 20250315
# Updated game file: 22400975
# Updated game file: 22400973
# Updated game file: 22400970
# Updated game file: 22400974
# Updated game file: 22400968
# Updated game file: 22400969
# Updated game file: 22400972
# Updated game file: 22400971
# Additional data file already exists for date 20250316. Loading existing file.
# Loaded existing additional data for date 20250316
# Updated game file: 22400978
# Updated game file: 22400980
# Updated game file: 22400976
# Updated game file: 22400977
# Updated game file: 22400982
# Updated game file: 22400981
# Updated game file: 22400538
# Updated game file: 22400979
# Additional data file already exists for date 20250317. Loading existing file.
# Loaded existing additional data for date 20250317
# Updated game file: 22400537
# Updated game file: 22400995
# Updated game file: 22400990
# Updated game file: 22400986
# Updated game file: 22400992
# Updated game file: 22400985
# Updated game file: 22400984
# Updated game file: 22400987
# Updated game file: 22400989
# Updated game file: 22400991
# Additional data file already exists for date 20250318. Loading existing file.
# Loaded existing additional data for date 20250318
# Updated game file: 22400994
# Updated game file: 22401012
# Updated game file: 22400997
# Updated game file: 22400993
# Additional data file already exists for date 20250319. Loading existing file.
# Loaded existing additional data for date 20250319
# Updated game file: 22401000
# Updated game file: 22400998
# Updated game file: 22400627
# Updated game file: 22401008
# Updated game file: 22401003
# Updated game file: 22401009
# Updated game file: 22401001
# Updated game file: 22401002
# Updated game file: 22401006
# Updated game file: 22401007
# Updated game file: 22400999
# Additional data file already exists for date 20250320. Loading existing file.
# Loaded existing additional data for date 20250320
# Updated game file: 22400996
# Updated game file: 22401011
# Updated game file: 22401013
# Updated game file: 22401005
# Updated game file: 22401010
# Additional data file already exists for date 20250321. Loading existing file.
# Loaded existing additional data for date 20250321
# Updated game file: 22401016
# Updated game file: 22401023
# Updated game file: 22401022
# Updated game file: 22401015
# Updated game file: 22401021
# Updated game file: 22401014
# Updated game file: 22401019
# Updated game file: 22401017
# Updated game file: 22401018
# Updated game file: 22401020
# Additional data file already exists for date 20250322. Loading existing file.
# Loaded existing additional data for date 20250322
# Updated game file: 22401024
# Updated game file: 22401028
# Updated game file: 22401026
# Updated game file: 22401027
# Updated game file: 22401025
# Additional data file already exists for date 20250323. Loading existing file.
# Loaded existing additional data for date 20250323
# Updated game file: 22401034
# Updated game file: 22401033
# Updated game file: 22401032
# ...
# Replaced 2025/22401088.csv with updated version
# Replaced 2025/22400782.csv with updated version
# Replaced 2025/22400627.csv with updated version
# Replaced 2025/22400768.csv with updated version
# Replaced 2025/22400895.csv with updated version
# Replaced 2025/22400488.csv with updated version
# Replaced 2025/22400505.csv with updated version
# Replaced 2025/22401098.csv with updated version
# Replaced 2025/22400241.csv with updated version
# Replaced 2025/22400553.csv with updated version
# Replaced 2025/22400427.csv with updated version
# Replaced 2025/22400269.csv with updated version
# Replaced 2025/22400869.csv with updated version
# Replaced 2025/22400208.csv with updated version
# Replaced 2025/22400710.csv with updated version
# Replaced 2025/22400811.csv with updated version
# Replaced 2025/22400114.csv with updated version
# Replaced 2025/22400592.csv with updated version
# Replaced 2025/22401053.csv with updated version
# Replaced 2025/42400313.csv with updated version
# Replaced 2025/22400542.csv with updated version
# Replaced 2025/22400254.csv with updated version
# Replaced 2025/42400152.csv with updated version
# Replaced 2025/22400360.csv with updated version
# Replaced 2025/22400112.csv with updated version
# Replaced 2025/22401077.csv with updated version
# Replaced 2025/22400091.csv with updated version
# Replaced 2025/22401138.csv with updated version
# Replaced 2025/22400708.csv with updated version
# Replaced 2025/22400978.csv with updated version
# Replaced 2025/22400470.csv with updated version
# Replaced 2025/22401137.csv with updated version
# Replaced 2025/22400660.csv with updated version
# Replaced 2025/22400397.csv with updated version
# Replaced 2025/22401073.csv with updated version
# Replaced 2025/22400762.csv with updated version
# Replaced 2025/22400792.csv with updated version
# Replaced 2025/22401115.csv with updated version
# Replaced 2025/22400433.csv with updated version
# Replaced 2025/22401133.csv with updated version
# Replaced 2025/22400939.csv with updated version
# Replaced 2025/22400296.csv with updated version
# Replaced 2025/22400279.csv with updated version
# Replaced 2025/22400425.csv with updated version
# Replaced 2025/42400406.csv with updated version
# Replaced 2025/22400727.csv with updated version
# Replaced 2025/22400570.csv with updated version
# Replaced 2025/22400482.csv with updated version
# Replaced 2025/22400162.csv with updated version
# Replaced 2025/22400742.csv with updated version
# Replaced 2025/22400414.csv with updated version
# Replaced 2025/22401159.csv with updated version
# Replaced 2025/22400009.csv with updated version
# Replaced 2025/22400930.csv with updated version
# Replaced 2025/22400907.csv with updated version
# Replaced 2025/42400141.csv with updated version
# Replaced 2025/22400008.csv with updated version
# Replaced 2025/22400784.csv with updated version
# Replaced 2025/22400961.csv with updated version
# Replaced 2025/22401196.csv with updated version
# Replaced 2025/22400567.csv with updated version
# Replaced 2025/22401031.csv with updated version
# Replaced 2025/22400685.csv with updated version
# Replaced 2025/22400726.csv with updated version
# Replaced 2025/42400227.csv with updated version
# Replaced 2025/22400870.csv with updated version
# Replaced 2025/22400622.csv with updated version
# Replaced 2025/22400932.csv with updated version
# Replaced 2025/22400183.csv with updated version
# Replaced 2025/22400926.csv with updated version
# Replaced 2025/22400234.csv with updated version
# Replaced 2025/22400294.csv with updated version
# Replaced 2025/22400031.csv with updated version
# Replaced 2025/22400942.csv with updated version
# Replaced 2025/22400228.csv with updated version
# Replaced 2025/22400402.csv with updated version
# Replaced 2025/22400308.csv with updated version
# Replaced 2025/22400679.csv with updated version
# Replaced 2025/22400189.csv with updated version
# Replaced 2025/22400003.csv with updated version
# Replaced 2025/22400587.csv with updated version
# Replaced 2025/22400410.csv with updated version
# Replaced 2025/22400658.csv with updated version
# Replaced 2025/22400215.csv with updated version
# Replaced 2025/22400284.csv with updated version
# Replaced 2025/22400213.csv with updated version
# Replaced 2025/22400786.csv with updated version
# Replaced 2025/22401057.csv with updated version
# Replaced 2025/22400772.csv with updated version
# Replaced 2025/22401099.csv with updated version
# Replaced 2025/22400348.csv with updated version
# Replaced 2025/22401171.csv with updated version
# Replaced 2025/22400256.csv with updated version
# Replaced 2025/22400404.csv with updated version
# Replaced 2025/22400380.csv with updated version
# Replaced 2025/22400160.csv with updated version
# Replaced 2025/22400858.csv with updated version
# Replaced 2025/22400638.csv with updated version
# Replaced 2025/22400111.csv with updated version
# Replaced 2025/22400081.csv with updated version
# Replaced 2025/22401118.csv with updated version
# Replaced 2025/22401214.csv with updated version
# Replaced 2025/22400442.csv with updated version
# Replaced 2025/22400823.csv with updated version
# Replaced 2025/22401111.csv with updated version
# Replaced 2025/22400668.csv with updated version
# Replaced 2025/22400509.csv with updated version
# Replaced 2025/22400274.csv with updated version
# Replaced 2025/22400035.csv with updated version
# Replaced 2025/22401103.csv with updated version
# Replaced 2025/22401156.csv with updated version
# Replaced 2025/22400196.csv with updated version
# Replaced 2025/22401054.csv with updated version
# Replaced 2025/22400498.csv with updated version
# Replaced 2025/22400968.csv with updated version
# Replaced 2025/22400381.csv with updated version
# Replaced 2025/42400104.csv with updated version
# Replaced 2025/22400686.csv with updated version
# Replaced 2025/42400212.csv with updated version
# Replaced 2025/22400562.csv with updated version
# Replaced 2025/22400707.csv with updated version
# Replaced 2025/22400965.csv with updated version
# Replaced 2025/22400448.csv with updated version
# Replaced 2025/22400025.csv with updated version
# Replaced 2025/22400781.csv with updated version
# Replaced 2025/22400315.csv with updated version
# Replaced 2025/22400155.csv with updated version
# Replaced 2025/22400525.csv with updated version
# Replaced 2025/22400879.csv with updated version
# Replaced 2025/22400512.csv with updated version
# Replaced 2025/22400884.csv with updated version
# Replaced 2025/22400655.csv with updated version
# Replaced 2025/42400164.csv with updated version
# Replaced 2025/22400807.csv with updated version
# Replaced 2025/22401169.csv with updated version
# Replaced 2025/22400576.csv with updated version
# Replaced 2025/22400921.csv with updated version
# Replaced 2025/22400202.csv with updated version
# Replaced 2025/22401049.csv with updated version
# Replaced 2025/22400514.csv with updated version
# Replaced 2025/22400521.csv with updated version
# Replaced 2025/22400064.csv with updated version
# Replaced 2025/22400844.csv with updated version
# Replaced 2025/22400321.csv with updated version
# Replaced 2025/22400958.csv with updated version
# Replaced 2025/22400201.csv with updated version
# Replaced 2025/22400608.csv with updated version
# Replaced 2025/22400572.csv with updated version
# Replaced 2025/22400732.csv with updated version
# Replaced 2025/22400751.csv with updated version
# Replaced 2025/42400407.csv with updated version
# Replaced 2025/22400983.csv with updated version
# Replaced 2025/22400990.csv with updated version
# Replaced 2025/22400351.csv with updated version
# Replaced 2025/22400993.csv with updated version
# Replaced 2025/22400331.csv with updated version
# Replaced 2025/22400203.csv with updated version
# Replaced 2025/22400728.csv with updated version
# Replaced 2025/22400453.csv with updated version
# Replaced 2025/22401131.csv with updated version
# Replaced 2025/22400210.csv with updated version
# Replaced 2025/42400125.csv with updated version
# Replaced 2025/22401078.csv with updated version
# Replaced 2025/42400312.csv with updated version
# Replaced 2025/22400748.csv with updated version
# Replaced 2025/22401006.csv with updated version
# Replaced 2025/22400137.csv with updated version
# Replaced 2025/22401104.csv with updated version
# Replaced 2025/22400032.csv with updated version
# Replaced 2025/22400354.csv with updated version
# Replaced 2025/22400350.csv with updated version
# Replaced 2025/22400560.csv with updated version
# Replaced 2025/22400650.csv with updated version
# Replaced 2025/22401127.csv with updated version
# Replaced 2025/22400695.csv with updated version
# Replaced 2025/22401201.csv with updated version
# Replaced 2025/22400312.csv with updated version
# Replaced 2025/22400729.csv with updated version
# Replaced 2025/22400507.csv with updated version
# Replaced 2025/22400044.csv with updated version
# Replaced 2025/22400796.csv with updated version
# Replaced 2025/22400452.csv with updated version
# Replaced 2025/22401192.csv with updated version
# Replaced 2025/42400102.csv with updated version
# Replaced 2025/22401153.csv with updated version
# Replaced 2025/22400430.csv with updated version
# Replaced 2025/22400336.csv with updated version
# Replaced 2025/22400893.csv with updated version
# Replaced 2025/22400421.csv with updated version
# Replaced 2025/22400657.csv with updated version
# Replaced 2025/22400510.csv with updated version
# Replaced 2025/22400682.csv with updated version
# Replaced 2025/22400182.csv with updated version
# Replaced 2025/22400329.csv with updated version
# Replaced 2025/22400799.csv with updated version
# Replaced 2025/22400740.csv with updated version
# Replaced 2025/22400797.csv with updated version
# Replaced 2025/22400595.csv with updated version
# Replaced 2025/22400838.csv with updated version
# Replaced 2025/22400609.csv with updated version
# Replaced 2025/22400227.csv with updated version
# Replaced 2025/22400731.csv with updated version
# Replaced 2025/22400310.csv with updated version
# Replaced 2025/22401154.csv with updated version
# Replaced 2025/22400190.csv with updated version
# Replaced 2025/22400143.csv with updated version
# Replaced 2025/22400149.csv with updated version
# Replaced 2025/22400614.csv with updated version
# Replaced 2025/22401184.csv with updated version
# Replaced 2025/22400598.csv with updated version
# Replaced 2025/22400988.csv with updated version
# Replaced 2025/22400133.csv with updated version
# Replaced 2025/22400857.csv with updated version
# Replaced 2025/22400478.csv with updated version
# Replaced 2025/22400095.csv with updated version
# Replaced 2025/22400664.csv with updated version
# Replaced 2025/42400122.csv with updated version
# Replaced 2025/22400191.csv with updated version
# Replaced 2025/42400177.csv with updated version
# Replaced 2025/42400235.csv with updated version
# Replaced 2025/22400654.csv with updated version
# Replaced 2025/22400341.csv with updated version
# Replaced 2025/22400743.csv with updated version
# Replaced 2025/22400620.csv with updated version
# Replaced 2025/22401173.csv with updated version
# Replaced 2025/22400531.csv with updated version
# Replaced 2025/22400681.csv with updated version
# Replaced 2025/22401166.csv with updated version
# Replaced 2025/22400099.csv with updated version
# Replaced 2025/22401203.csv with updated version
# Replaced 2025/42400103.csv with updated version
# Replaced 2025/22400634.csv with updated version
# Replaced 2025/22400544.csv with updated version
# Replaced 2025/22400224.csv with updated version
# Replaced 2025/22401072.csv with updated version
# Replaced 2025/22401015.csv with updated version
# Replaced 2025/22400890.csv with updated version
# Replaced 2025/22400984.csv with updated version
# Replaced 2025/22400451.csv with updated version
# Replaced 2025/22400783.csv with updated version
# Replaced 2025/22400205.csv with updated version
# Replaced 2025/22400429.csv with updated version
# Replaced 2025/22401093.csv with updated version
# Replaced 2025/22400456.csv with updated version
# Replaced 2025/22400142.csv with updated version
# Replaced 2025/22401087.csv with updated version
# Replaced 2025/22400563.csv with updated version
# Replaced 2025/22400813.csv with updated version
# Replaced 2025/22400676.csv with updated version
# Replaced 2025/22400853.csv with updated version
# Replaced 2025/22400484.csv with updated version
# Replaced 2025/22401105.csv with updated version
# Replaced 2025/22400062.csv with updated version
# Replaced 2025/42400101.csv with updated version
# Replaced 2025/22400946.csv with updated version
# Replaced 2025/22400378.csv with updated version
# Replaced 2025/22400055.csv with updated version
# Replaced 2025/22400100.csv with updated version
# Replaced 2025/22401032.csv with updated version
# Replaced 2025/22400529.csv with updated version
# Replaced 2025/22400917.csv with updated version
# Replaced 2025/42400203.csv with updated version
# Replaced 2025/22400522.csv with updated version
# Replaced 2025/22401199.csv with updated version
# Replaced 2025/22401182.csv with updated version
# Replaced 2025/22400365.csv with updated version
# Replaced 2025/22400767.csv with updated version
# Replaced 2025/42400302.csv with updated version
# Replaced 2025/22400450.csv with updated version
# Replaced 2025/22400959.csv with updated version
# Replaced 2025/22401010.csv with updated version
# Replaced 2025/22400541.csv with updated version
# Replaced 2025/22400516.csv with updated version
# Replaced 2025/22400839.csv with updated version
# Replaced 2025/22401218.csv with updated version
# Replaced 2025/22400914.csv with updated version
# Replaced 2025/22400550.csv with updated version
# Replaced 2025/22400886.csv with updated version
# Replaced 2025/22400299.csv with updated version
# Replaced 2025/22400871.csv with updated version
# Replaced 2025/22400173.csv with updated version
# Replaced 2025/22400277.csv with updated version
# Replaced 2025/22401030.csv with updated version
# Replaced 2025/22400130.csv with updated version
# Replaced 2025/22401165.csv with updated version
# Replaced 2025/22401151.csv with updated version
# Replaced 2025/22400383.csv with updated version
# Replaced 2025/22400925.csv with updated version
# Replaced 2025/22400217.csv with updated version
# Replaced 2025/22400054.csv with updated version
# Replaced 2025/22400675.csv with updated version
# Replaced 2025/42400131.csv with updated version
# Replaced 2025/22401096.csv with updated version
# Replaced 2025/22400764.csv with updated version
# Replaced 2025/22400358.csv with updated version
# Replaced 2025/22400275.csv with updated version
# Replaced 2025/42400112.csv with updated version
# Replaced 2025/22400854.csv with updated version
# Replaced 2025/22401208.csv with updated version
# Replaced 2025/22400557.csv with updated version
# Replaced 2025/22400019.csv with updated version
# Replaced 2025/42400165.csv with updated version
# Replaced 2025/42400144.csv with updated version
# Replaced 2025/22400931.csv with updated version
# Replaced 2025/22400083.csv with updated version
# Replaced 2025/22400373.csv with updated version
# Replaced 2025/22401056.csv with updated version
# Replaced 2025/22400774.csv with updated version
# Replaced 2025/22400628.csv with updated version
# Replaced 2025/22400535.csv with updated version
# Replaced 2025/22401224.csv with updated version
# Replaced 2025/22400737.csv with updated version
# Replaced 2025/22400084.csv with updated version
# Replaced 2025/22400368.csv with updated version
# Replaced 2025/22400386.csv with updated version
# Replaced 2025/22400687.csv with updated version
# Replaced 2025/22400353.csv with updated version
# Replaced 2025/22400624.csv with updated version
# Replaced 2025/22400683.csv with updated version
# Replaced 2025/22400974.csv with updated version
# Replaced 2025/22401075.csv with updated version
# Replaced 2025/22400504.csv with updated version
# Replaced 2025/22400460.csv with updated version
# Replaced 2025/42400226.csv with updated version
# Replaced 2025/22400148.csv with updated version
# Replaced 2025/22400633.csv with updated version
# Replaced 2025/22400927.csv with updated version
# Replaced 2025/22400164.csv with updated version
# Replaced 2025/22400924.csv with updated version
# Replaced 2025/22400225.csv with updated version
# Replaced 2025/22400997.csv with updated version
# Replaced all_games/all_2025.csv with updated version
# Replaced all_games/all_2025.parquet with updated version
