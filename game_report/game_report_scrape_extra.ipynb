# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd
import requests
import os
import time
from datetime import datetime
import glob

def format_date_to_url(date):
    # Convert date from YYYYMMDD to datetime object
    date_obj = datetime.strptime(str(date), '%Y%m%d')
    
    # Format the date as MM%2FDD%2FYYYY
    formatted_date = date_obj.strftime('%m%%2F%d%%2F%Y')
    
    return formatted_date

def pull_data(url):
    headers = {
        "Host": "stats.nba.com",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
        "Accept": "application/json, text/plain, */*",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
        "Referer": "https://stats.nba.com/",
        "Origin": "https://stats.nba.com",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
    }

    json = requests.get(url, headers=headers).json()

    if len(json["resultSets"]) == 1:
        data = json["resultSets"][0]["rowSet"]
        columns = json["resultSets"][0]["headers"]
        df = pd.DataFrame.from_records(data, columns=columns)
    else:
        data = json["resultSets"]["rowSet"]
        columns = json["resultSets"]["headers"][1]['columnNames']
        df = pd.DataFrame.from_records(data, columns=columns)

    time.sleep(.1)  # Respect rate limits
    return df

def pull_additional_data(date_num, season, stype='Regular%20Season'):
    """
    Pull additional data from new endpoints for a specific date
    """
    date = format_date_to_url(date_num)
    
    additional_data_frames = []
    year=int(season.split('-')[0])+1
    
    # Get data from your additional links
    # Link 1: Overall defense stats
    ps=False
    if stype=='Playoffs':
        ps=True
    passed=True
    url1 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Overall&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df1 = pull_data(url1)
        df1.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df1.rename(columns={col: f'overall_def_{col}' for col in df1.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df1)
        print(f"Successfully pulled Overall defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling Overall defense data for {date_num}: {str(e)}")
    
    # Link 2: 3-pointers defense stats
    url2 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=3%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df2 = pull_data(url2)
        df2.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df2.rename(columns={col: f'three_pt_def_{col}' for col in df2.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df2)
        print(f"Successfully pulled 3PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 3PT defense data for {date_num}: {str(e)}")
    
    # Link 3: 2-pointers defense stats
    url3 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=2%20Pointers&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df3 = pull_data(url3)
        df3.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df3.rename(columns={col: f'two_pt_def_{col}' for col in df3.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df3)
        print(f"Successfully pulled 2PT defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling 2PT defense data for {date_num}: {str(e)}")
    
    # Link 4: Less than 6ft defense stats
    url4 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%206Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df4 = pull_data(url4)
        df4.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df4.rename(columns={col: f'less_6ft_def_{col}' for col in df4.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df4)
        print(f"Successfully pulled <6ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <6ft defense data for {date_num}: {str(e)}")
    
    # Link 5: Less than 10ft defense stats
    url5 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Less%20Than%2010Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df5 = pull_data(url5)
        df5.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df5.rename(columns={col: f'less_10ft_def_{col}' for col in df5.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df5)
        print(f"Successfully pulled <10ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <10ft defense data for {date_num}: {str(e)}")
    
    # Link 6: Less than 15ft defense stats
    url6 = f'https://stats.nba.com/stats/leaguedashptdefend?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&DefenseCategory=Greater%20Than%2015Ft&Division=&DraftPick=&DraftYear=&GameSegment=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df6 = pull_data(url6)
        df6.rename(columns={'CLOSE_DEF_PERSON_ID': 'PLAYER_ID'}, inplace=True)
        df6.rename(columns={col: f'more_15ft_def_{col}' for col in df6.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df6)
        print(f"Successfully pulled >15ft defense data for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling <15ft defense data for {date_num}: {str(e)}")
    
    # Link 7: Hustle stats
    if year>=2016:
        url7 = f'https://stats.nba.com/stats/leaguehustlestatsplayer?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season={season}&SeasonSegment=&SeasonType={stype}&TeamID=0&VsConference=&VsDivision=&Weight='
        try:
            df7 = pull_data(url7)
            df7.rename(columns={col: f'hustle_{col}' for col in df7.columns if col != 'PLAYER_ID'}, inplace=True)
            additional_data_frames.append(df7)
            print(f"Successfully pulled hustle stats for {date_num}")
        except Exception as e:
            passed=False
            print(f"Error pulling hustle stats for {date_num}: {str(e)}")
    
    # Link 8: Post touch stats
    url8 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=PostTouch&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df8 = pull_data(url8)
        df8.rename(columns={col: f'post_touch_{col}' for col in df8.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df8)
        print(f"Successfully pulled post touch stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling post touch stats for {date_num}: {str(e)}")
    
    # Link 9: Speed distance stats
    url9 = f'https://stats.nba.com/stats/leaguedashptstats?College=&Conference=&Country=&DateFrom={date}&DateTo={date}&Division=&DraftPick=&DraftYear=&GameScope=&Height=&ISTRound=&LastNGames=0&LeagueID=00&Location=&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PerMode=PerGame&PlayerExperience=&PlayerOrTeam=Player&PlayerPosition=&PtMeasureType=SpeedDistance&Season={season}&SeasonSegment=&SeasonType={stype}&StarterBench=&TeamID=0&VsConference=&VsDivision=&Weight='
    try:
        df9 = pull_data(url9)
        df9.rename(columns={col: f'speed_distance_{col}' for col in df9.columns if col != 'PLAYER_ID'}, inplace=True)
        additional_data_frames.append(df9)
        print(f"Successfully pulled speed distance stats for {date_num}")
    except Exception as e:
        passed=False
        print(f"Error pulling speed distance stats for {date_num}: {str(e)}")
    
    # Merge all the additional data frames on PLAYER_ID
    result_df = additional_data_frames[0]
    for df in additional_data_frames[1:]:
        result_df = result_df.merge(df, on='PLAYER_ID', how='outer')
    
    # Add date and season information
    result_df['date'] = date_num
    result_df['season'] = season.replace('-', '_')
    
    return result_df,passed

def update_game_files(start_year, end_year, stype='Regular%20Season'):
    """
    Update existing game files with additional data for a range of seasons
    """
    # Get all dates for which we have existing data
    for year in range(start_year, end_year):
        season = f"{year-1}-{str(year)[-2:]}"
        
        # Create a directory for additional data if it doesn't exist
        additional_data_dir = f'additional_data/{year}'
        if not os.path.exists(additional_data_dir):
            os.makedirs(additional_data_dir, exist_ok=True)
        
        # Get list of game files we already have
        game_files = glob.glob(f'{year}/*.csv')
        
        # Extract unique dates from existing files
        existing_dates = set()
        date_to_games = {}
        
        # Read the date information from existing files
        for game_file in game_files:
            try:
                game_id = os.path.basename(game_file).replace('.csv', '')
                game_df = pd.read_csv(game_file)
                
                if 'date' in game_df.columns:
                    date = game_df['date'].iloc[0]
                    existing_dates.add(date)
                    
                    if date not in date_to_games:
                        date_to_games[date] = []
                    date_to_games[date].append(game_id)
            except Exception as e:
                print(f"Error reading file {game_file}: {str(e)}")
        
        # Process each date to get additional data
        date_dict={
                2014: 20140419,
                2015: 20150418,
                2016: 20160416,
                2017: 20170415,
                2018: 20180414,
                2019: 20190413,
                2020: 20200817,  # Delayed due to COVID-19
                2021: 20210522,
                2022: 20220416,
                2023: 20230415,
                2024: 20240420
            }
        year=int(season.split('-')[0])
        year+=1
        cutoff= date_dict[year]
  
        for date in sorted(existing_dates):
            additional_data_file = f'{additional_data_dir}/{date}_additional.csv'
            
            # Skip if we already have the additional data file
            if os.path.exists(additional_data_file):
                print(f"Additional data file already exists for date {date}. Skipping.")
                continue
            
            print(f"Processing date: {date}")


            
            try:
                # Pull additional data

                if date>=cutoff:
                    season_type='Playoffs'
                else:
                    season_type='Regular%20Season'
                additional_df,passed = pull_additional_data(date, season, season_type)
                
                # Save the additional data for this date
                if passed:
                    additional_df.to_csv(additional_data_file, index=False)
                    print(f"Saved additional data for date {date}")
                    
                    # Now update each game file for this date with the additional data
                    game_ids = date_to_games.get(date, [])
                    
                    for game_id in game_ids:
                        game_file = f'{year}/{game_id}.csv'
                        
                        try:
                            # Read the existing game data
                            game_df = pd.read_csv(game_file)
                            
                            # Merge with additional data
                            updated_df = game_df.merge(additional_df, on=['PLAYER_ID', 'date'], how='left')
                            
                            # Save the updated game file
                            updated_df.to_csv(f'{year}/{game_id}_updated.csv', index=False)
                            print(f"Updated game file: {game_id}")
                        except Exception as e:
                            print(f"Error updating game file {game_id}: {str(e)}")
                    
            except Exception as e:
                print(f"Error processing additional data for date {date}: {str(e)}")

def update_all_games_file(year):
    """
    Update the consolidated 'all_games' file with additional data
    """
    # Get all updated game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    if not updated_game_files:
        print(f"No updated game files found for year {year}")
        return
    
    # Combine all updated game files
    all_updated_games = []
    
    for game_file in updated_game_files:
        try:
            game_df = pd.read_csv(game_file)
            all_updated_games.append(game_df)
        except Exception as e:
            print(f"Error reading updated game file {game_file}: {str(e)}")
    
    if all_updated_games:
        # Concatenate all game data
        all_games_df = pd.concat(all_updated_games, ignore_index=True)
        
        # Save as CSV and parquet
        all_games_df.to_csv(f'all_games/all_{year}_updated.csv', index=False)
        all_games_df.to_parquet(f'all_games/all_{year}_updated.parquet', index=False)
        print(f"Updated consolidated files for year {year}")
    else:
        print(f"No valid updated game files to concatenate for year {year}")

def cleanup_and_rename(year):
    """
    After successful update, rename updated files to replace originals
    """
    # Rename individual game files
    updated_game_files = glob.glob(f'{year}/*_updated.csv')
    
    for game_file in updated_game_files:
        original_file = game_file.replace('_updated.csv', '.csv')
        os.rename(game_file, original_file)
        print(f"Replaced {original_file} with updated version")
    
    # Rename consolidated files
    if os.path.exists(f'all_games/all_{year}_updated.csv'):
        os.rename(f'all_games/all_{year}_updated.csv', f'all_games/all_{year}.csv')
        print(f"Replaced all_games/all_{year}.csv with updated version")
    
    if os.path.exists(f'all_games/all_{year}_updated.parquet'):
        os.rename(f'all_games/all_{year}_updated.parquet', f'all_games/all_{year}.parquet')
        print(f"Replaced all_games/all_{year}.parquet with updated version")

def main():
    # Define year range
    start_year = 2014
    end_year = 2026
    
    # Update game files with additional data
    update_game_files(start_year, end_year)
    
    # Update consolidated files
    for year in range(start_year, end_year):
        update_all_games_file(year)
    
    # Clean up and rename files
    for year in range(start_year, end_year):
        cleanup_and_rename(year)

if __name__ == "__main__":
    main()
# Out:
# Additional data file already exists for date 20131029. Skipping.
# Additional data file already exists for date 20131030. Skipping.
# Additional data file already exists for date 20131031. Skipping.
# Additional data file already exists for date 20131101. Skipping.
# Additional data file already exists for date 20131102. Skipping.
# Additional data file already exists for date 20131103. Skipping.
# Additional data file already exists for date 20131104. Skipping.
# Additional data file already exists for date 20131105. Skipping.
# Additional data file already exists for date 20131106. Skipping.
# Additional data file already exists for date 20131107. Skipping.
# Additional data file already exists for date 20131108. Skipping.
# Additional data file already exists for date 20131109. Skipping.
# Additional data file already exists for date 20131110. Skipping.
# Additional data file already exists for date 20131111. Skipping.
# Additional data file already exists for date 20131112. Skipping.
# Additional data file already exists for date 20131113. Skipping.
# Additional data file already exists for date 20131114. Skipping.
# Additional data file already exists for date 20131115. Skipping.
# Additional data file already exists for date 20131116. Skipping.
# Additional data file already exists for date 20131117. Skipping.
# Additional data file already exists for date 20131118. Skipping.
# Additional data file already exists for date 20131119. Skipping.
# Additional data file already exists for date 20131120. Skipping.
# Additional data file already exists for date 20131121. Skipping.
# Additional data file already exists for date 20131122. Skipping.
# Additional data file already exists for date 20131123. Skipping.
# Additional data file already exists for date 20131124. Skipping.
# Additional data file already exists for date 20131125. Skipping.
# Additional data file already exists for date 20131126. Skipping.
# Additional data file already exists for date 20131127. Skipping.
# Additional data file already exists for date 20131129. Skipping.
# Additional data file already exists for date 20131130. Skipping.
# Additional data file already exists for date 20131201. Skipping.
# Additional data file already exists for date 20131202. Skipping.
# Additional data file already exists for date 20131203. Skipping.
# Additional data file already exists for date 20131204. Skipping.
# Additional data file already exists for date 20131205. Skipping.
# Additional data file already exists for date 20131206. Skipping.
# Additional data file already exists for date 20131207. Skipping.
# Additional data file already exists for date 20131208. Skipping.
# Additional data file already exists for date 20131209. Skipping.
# Additional data file already exists for date 20131210. Skipping.
# Additional data file already exists for date 20131211. Skipping.
# Additional data file already exists for date 20131212. Skipping.
# Additional data file already exists for date 20131213. Skipping.
# Additional data file already exists for date 20131214. Skipping.
# Additional data file already exists for date 20131215. Skipping.
# Additional data file already exists for date 20131216. Skipping.
# Additional data file already exists for date 20131217. Skipping.
# Additional data file already exists for date 20131218. Skipping.
# Additional data file already exists for date 20131219. Skipping.
# Additional data file already exists for date 20131220. Skipping.
# Additional data file already exists for date 20131221. Skipping.
# Additional data file already exists for date 20131222. Skipping.
# Additional data file already exists for date 20131223. Skipping.
# Additional data file already exists for date 20131225. Skipping.
# Additional data file already exists for date 20131226. Skipping.
# Additional data file already exists for date 20131227. Skipping.
# Additional data file already exists for date 20131228. Skipping.
# Additional data file already exists for date 20131229. Skipping.
# Additional data file already exists for date 20131230. Skipping.
# Additional data file already exists for date 20131231. Skipping.
# Additional data file already exists for date 20140101. Skipping.
# Additional data file already exists for date 20140102. Skipping.
# Additional data file already exists for date 20140103. Skipping.
# Additional data file already exists for date 20140104. Skipping.
# Additional data file already exists for date 20140105. Skipping.
# Additional data file already exists for date 20140106. Skipping.
# Additional data file already exists for date 20140107. Skipping.
# Additional data file already exists for date 20140108. Skipping.
# Additional data file already exists for date 20140109. Skipping.
# Additional data file already exists for date 20140110. Skipping.
# Additional data file already exists for date 20140111. Skipping.
# Additional data file already exists for date 20140112. Skipping.
# Additional data file already exists for date 20140113. Skipping.
# Additional data file already exists for date 20140114. Skipping.
# Additional data file already exists for date 20140115. Skipping.
# Additional data file already exists for date 20140116. Skipping.
# Additional data file already exists for date 20140117. Skipping.
# Additional data file already exists for date 20140118. Skipping.
# Additional data file already exists for date 20140119. Skipping.
# Additional data file already exists for date 20140120. Skipping.
# Additional data file already exists for date 20140121. Skipping.
# Additional data file already exists for date 20140122. Skipping.
# Additional data file already exists for date 20140123. Skipping.
# Additional data file already exists for date 20140124. Skipping.
# Additional data file already exists for date 20140125. Skipping.
# Additional data file already exists for date 20140126. Skipping.
# Additional data file already exists for date 20140127. Skipping.
# Additional data file already exists for date 20140128. Skipping.
# Additional data file already exists for date 20140129. Skipping.
# Additional data file already exists for date 20140130. Skipping.
# Additional data file already exists for date 20140131. Skipping.
# Additional data file already exists for date 20140201. Skipping.
# Additional data file already exists for date 20140202. Skipping.
# Additional data file already exists for date 20140203. Skipping.
# Additional data file already exists for date 20140204. Skipping.
# Additional data file already exists for date 20140205. Skipping.
# Additional data file already exists for date 20140206. Skipping.
# Additional data file already exists for date 20140207. Skipping.
# Additional data file already exists for date 20140208. Skipping.
# Additional data file already exists for date 20140209. Skipping.
# Additional data file already exists for date 20140210. Skipping.
# Additional data file already exists for date 20140211. Skipping.
# Additional data file already exists for date 20140212. Skipping.
# Additional data file already exists for date 20140213. Skipping.
# Additional data file already exists for date 20140218. Skipping.
# Additional data file already exists for date 20140219. Skipping.
# Additional data file already exists for date 20140220. Skipping.
# Additional data file already exists for date 20140221. Skipping.
# Additional data file already exists for date 20140222. Skipping.
# Additional data file already exists for date 20140223. Skipping.
# Additional data file already exists for date 20140224. Skipping.
# Additional data file already exists for date 20140225. Skipping.
# Additional data file already exists for date 20140226. Skipping.
# Additional data file already exists for date 20140227. Skipping.
# Additional data file already exists for date 20140228. Skipping.
# Additional data file already exists for date 20140301. Skipping.
# Additional data file already exists for date 20140302. Skipping.
# Additional data file already exists for date 20140303. Skipping.
# Additional data file already exists for date 20140304. Skipping.
# Additional data file already exists for date 20140305. Skipping.
# Additional data file already exists for date 20140306. Skipping.
# Additional data file already exists for date 20140307. Skipping.
# Additional data file already exists for date 20140308. Skipping.
# Additional data file already exists for date 20140309. Skipping.
# Additional data file already exists for date 20140310. Skipping.
# Additional data file already exists for date 20140311. Skipping.
# Additional data file already exists for date 20140312. Skipping.
# Additional data file already exists for date 20140313. Skipping.
# Additional data file already exists for date 20140314. Skipping.
# Additional data file already exists for date 20140315. Skipping.
# Additional data file already exists for date 20140316. Skipping.
# Additional data file already exists for date 20140317. Skipping.
# Additional data file already exists for date 20140318. Skipping.
# Additional data file already exists for date 20140319. Skipping.
# Additional data file already exists for date 20140320. Skipping.
# Additional data file already exists for date 20140321. Skipping.
# Additional data file already exists for date 20140322. Skipping.
# Additional data file already exists for date 20140323. Skipping.
# Additional data file already exists for date 20140324. Skipping.
# Additional data file already exists for date 20140325. Skipping.
# Additional data file already exists for date 20140326. Skipping.
# Additional data file already exists for date 20140327. Skipping.
# Additional data file already exists for date 20140328. Skipping.
# Additional data file already exists for date 20140329. Skipping.
# Additional data file already exists for date 20140330. Skipping.
# Additional data file already exists for date 20140331. Skipping.
# Processing date: 20140401
# Successfully pulled Overall defense data for 20140401
# Successfully pulled 3PT defense data for 20140401
# Successfully pulled 2PT defense data for 20140401
# Successfully pulled <6ft defense data for 20140401
# Successfully pulled <10ft defense data for 20140401
# Successfully pulled >15ft defense data for 20140401
# Successfully pulled post touch stats for 20140401
# Successfully pulled speed distance stats for 20140401
# Saved additional data for date 20140401
# Updated game file: 21301112
# Updated game file: 21301111
# Updated game file: 21301111_updated
# Updated game file: 21301113
# Updated game file: 21301112_updated
# Updated game file: 21301113_updated
# Processing date: 20140402
# Successfully pulled Overall defense data for 20140402
# Successfully pulled 3PT defense data for 20140402
# Successfully pulled 2PT defense data for 20140402
# Successfully pulled <6ft defense data for 20140402
# Successfully pulled <10ft defense data for 20140402
# Successfully pulled >15ft defense data for 20140402
# Successfully pulled post touch stats for 20140402
# Successfully pulled speed distance stats for 20140402
# Saved additional data for date 20140402
# Updated game file: 21301115
# Updated game file: 21301121
# Updated game file: 21301125_updated
# Updated game file: 21301126
# Updated game file: 21301122
# Updated game file: 21301124
# Updated game file: 21301114
# Updated game file: 21301120
# Updated game file: 21301114_updated
# Updated game file: 21301119
# Updated game file: 21301123_updated
# Updated game file: 21301118_updated
# Updated game file: 21301124_updated
# Updated game file: 21301117
# Updated game file: 21301126_updated
# Updated game file: 21301123
# Updated game file: 21301117_updated
# Updated game file: 21301116_updated
# Updated game file: 21301122_updated
# Updated game file: 21301121_updated
# Updated game file: 21301118
# Updated game file: 21301115_updated
# Updated game file: 21301125
# Updated game file: 21301116
# Updated game file: 21301119_updated
# Updated game file: 21301120_updated
# Processing date: 20140403
# Successfully pulled Overall defense data for 20140403
# Successfully pulled 3PT defense data for 20140403
# Successfully pulled 2PT defense data for 20140403
# Successfully pulled <6ft defense data for 20140403
# Successfully pulled <10ft defense data for 20140403
# Successfully pulled >15ft defense data for 20140403
# Successfully pulled post touch stats for 20140403
# Successfully pulled speed distance stats for 20140403
# Saved additional data for date 20140403
# Updated game file: 21301128_updated
# Updated game file: 21301127_updated
# Updated game file: 21301128
# Updated game file: 21301127
# Processing date: 20140404
# Successfully pulled Overall defense data for 20140404
# Successfully pulled 3PT defense data for 20140404
# Successfully pulled 2PT defense data for 20140404
# Successfully pulled <6ft defense data for 20140404
# Successfully pulled <10ft defense data for 20140404
# Successfully pulled >15ft defense data for 20140404
# Successfully pulled post touch stats for 20140404
# Successfully pulled speed distance stats for 20140404
# Saved additional data for date 20140404
# Updated game file: 21301135_updated
# Updated game file: 21301133
# Updated game file: 21301136
# Updated game file: 21301136_updated
# Updated game file: 21301137
# Updated game file: 21301142_updated
# Updated game file: 21301141_updated
# Updated game file: 21301132_updated
# Updated game file: 21301129_updated
# Updated game file: 21301131
# Updated game file: 21301134_updated
# Updated game file: 21301134
# Updated game file: 21301131_updated
# Updated game file: 21301140
# Updated game file: 21301138_updated
# Updated game file: 21301139_updated
# Updated game file: 21301130
# Updated game file: 21301141
# Updated game file: 21301133_updated
# Updated game file: 21301135
# Updated game file: 21301129
# Updated game file: 21301132
# Updated game file: 21301139
# Updated game file: 21301138
# Updated game file: 21301137_updated
# Updated game file: 21301130_updated
# Updated game file: 21301140_updated
# Updated game file: 21301142
# Processing date: 20140405
# Successfully pulled Overall defense data for 20140405
# Successfully pulled 3PT defense data for 20140405
# Successfully pulled 2PT defense data for 20140405
# Successfully pulled <6ft defense data for 20140405
# Successfully pulled <10ft defense data for 20140405
# Successfully pulled >15ft defense data for 20140405
# Successfully pulled post touch stats for 20140405
# Successfully pulled speed distance stats for 20140405
# Saved additional data for date 20140405
# Updated game file: 21301145
# Updated game file: 21301143_updated
# Updated game file: 21301143
# Updated game file: 21301145_updated
# Updated game file: 21301148_updated
# Updated game file: 21301147_updated
# Updated game file: 21301147
# Updated game file: 21301144
# Updated game file: 21301146
# Updated game file: 21301146_updated
# Updated game file: 21301144_updated
# Updated game file: 21301148
# Processing date: 20140406
# Successfully pulled Overall defense data for 20140406
# Successfully pulled 3PT defense data for 20140406
# Successfully pulled 2PT defense data for 20140406
# Successfully pulled <6ft defense data for 20140406
# Successfully pulled <10ft defense data for 20140406
# Successfully pulled >15ft defense data for 20140406
# Successfully pulled post touch stats for 20140406
# Successfully pulled speed distance stats for 20140406
# Saved additional data for date 20140406
# Updated game file: 21301151
# Updated game file: 21301154
# Updated game file: 21301152_updated
# Updated game file: 21301155
# Updated game file: 21301150_updated
# Updated game file: 21301157_updated
# Updated game file: 21301154_updated
# Updated game file: 21301152
# Updated game file: 21301149_updated
# Updated game file: 21301156
# Updated game file: 21301155_updated
# Updated game file: 21301149
# Updated game file: 21301157
# Updated game file: 21301151_updated
# Updated game file: 21301153_updated
# Updated game file: 21301156_updated
# Updated game file: 21301153
# Updated game file: 21301150
# Processing date: 20140408
# Successfully pulled Overall defense data for 20140408
# Successfully pulled 3PT defense data for 20140408
# Successfully pulled 2PT defense data for 20140408
# Successfully pulled <6ft defense data for 20140408
# Successfully pulled <10ft defense data for 20140408
# Successfully pulled >15ft defense data for 20140408
# Successfully pulled post touch stats for 20140408
# Successfully pulled speed distance stats for 20140408
# Saved additional data for date 20140408
# Updated game file: 21300677_updated
# Updated game file: 21301158
# Updated game file: 21301160
# Updated game file: 21301161
# Updated game file: 21301159
# Updated game file: 21301161_updated
# Updated game file: 21301158_updated
# Updated game file: 21300275
# Updated game file: 21300677
# Updated game file: 21301160_updated
# Updated game file: 21300275_updated
# Updated game file: 21301159_updated
# Processing date: 20140409
# Successfully pulled Overall defense data for 20140409
# Successfully pulled 3PT defense data for 20140409
# Successfully pulled 2PT defense data for 20140409
# Successfully pulled <6ft defense data for 20140409
# Successfully pulled <10ft defense data for 20140409
# Successfully pulled >15ft defense data for 20140409
# Successfully pulled post touch stats for 20140409
# Successfully pulled speed distance stats for 20140409
# Saved additional data for date 20140409
# Updated game file: 21301164
# Updated game file: 21301166_updated
# Updated game file: 21301171
# Updated game file: 21301167
# Updated game file: 21301162
# Updated game file: 21301163
# Updated game file: 21301168_updated
# Updated game file: 21301167_updated
# Updated game file: 21301170
# Updated game file: 21301170_updated
# Updated game file: 21301165_updated
# Updated game file: 21301165
# Updated game file: 21301171_updated
# Updated game file: 21301173_updated
# Updated game file: 21301162_updated
# Updated game file: 21301164_updated
# Updated game file: 21301172_updated
# Updated game file: 21301168
# Updated game file: 21301169
# Updated game file: 21301173
# Updated game file: 21301172
# Updated game file: 21301169_updated
# Updated game file: 21301163_updated
# Updated game file: 21301166
# Processing date: 20140410
# Successfully pulled Overall defense data for 20140410
# Successfully pulled 3PT defense data for 20140410
# Successfully pulled 2PT defense data for 20140410
# Successfully pulled <6ft defense data for 20140410
# Successfully pulled <10ft defense data for 20140410
# Successfully pulled >15ft defense data for 20140410
# Successfully pulled post touch stats for 20140410
# Successfully pulled speed distance stats for 20140410
# Saved additional data for date 20140410
# Updated game file: 21301174_updated
# Updated game file: 21301174
# Updated game file: 21301175_updated
# Updated game file: 21301175
# Processing date: 20140411
# Successfully pulled Overall defense data for 20140411
# Successfully pulled 3PT defense data for 20140411
# Successfully pulled 2PT defense data for 20140411
# Successfully pulled <6ft defense data for 20140411
# Successfully pulled <10ft defense data for 20140411
# Successfully pulled >15ft defense data for 20140411
# Successfully pulled post touch stats for 20140411
# Successfully pulled speed distance stats for 20140411
# Saved additional data for date 20140411
# Updated game file: 21301180
# Updated game file: 21301180_updated
# Updated game file: 21301186
# Updated game file: 21301182
# Updated game file: 21301184_updated
# Updated game file: 21301187
# Updated game file: 21301188_updated
# Updated game file: 21301181_updated
# Updated game file: 21301186_updated
# Updated game file: 21301182_updated
# Updated game file: 21301177_updated
# Updated game file: 21301176_updated
# Updated game file: 21301185_updated
# Updated game file: 21301179_updated
# Updated game file: 21301188
# Updated game file: 21301181
# Updated game file: 21301176
# Updated game file: 21301177
# Updated game file: 21301178
# Updated game file: 21301185
# Updated game file: 21301184
# Updated game file: 21301179
# Updated game file: 21301178_updated
# Updated game file: 21301183_updated
# Updated game file: 21301183
# Updated game file: 21301187_updated
# Processing date: 20140412
# Successfully pulled Overall defense data for 20140412
# Successfully pulled 3PT defense data for 20140412
# Successfully pulled 2PT defense data for 20140412
# Successfully pulled <6ft defense data for 20140412
# Successfully pulled <10ft defense data for 20140412
# Successfully pulled >15ft defense data for 20140412
# Successfully pulled post touch stats for 20140412
# Successfully pulled speed distance stats for 20140412
# Saved additional data for date 20140412
# Updated game file: 21301192
# Updated game file: 21301192_updated
# Updated game file: 21301191
# Updated game file: 21301191_updated
# Updated game file: 21301189_updated
# Updated game file: 21301190_updated
# Updated game file: 21301195
# Updated game file: 21301189
# Updated game file: 21301193
# Updated game file: 21301193_updated
# Updated game file: 21301196_updated
# Updated game file: 21301196
# Updated game file: 21301195_updated
# Updated game file: 21301190
# Updated game file: 21301194_updated
# Updated game file: 21301194
# Processing date: 20140413
# Successfully pulled Overall defense data for 20140413
# Successfully pulled 3PT defense data for 20140413
# Successfully pulled 2PT defense data for 20140413
# Successfully pulled <6ft defense data for 20140413
# Successfully pulled <10ft defense data for 20140413
# Successfully pulled >15ft defense data for 20140413
# Successfully pulled post touch stats for 20140413
# Successfully pulled speed distance stats for 20140413
# Saved additional data for date 20140413
# Updated game file: 21301202
# Updated game file: 21301203_updated
# Updated game file: 21301197
# Updated game file: 21301197_updated
# Updated game file: 21301201
# Updated game file: 21301200
# Updated game file: 21301200_updated
# Updated game file: 21301203
# Updated game file: 21301202_updated
# Updated game file: 21301198_updated
# Updated game file: 21301201_updated
# Updated game file: 21301199_updated
# Updated game file: 21301199
# Updated game file: 21301198
# Processing date: 20140414
# Successfully pulled Overall defense data for 20140414
# Successfully pulled 3PT defense data for 20140414
# Successfully pulled 2PT defense data for 20140414
# Successfully pulled <6ft defense data for 20140414
# Successfully pulled <10ft defense data for 20140414
# Successfully pulled >15ft defense data for 20140414
# Successfully pulled post touch stats for 20140414
# Successfully pulled speed distance stats for 20140414
# Saved additional data for date 20140414
# Updated game file: 21301211
# Updated game file: 21301209_updated
# Updated game file: 21301205
# Updated game file: 21301206_updated
# Updated game file: 21301210
# Updated game file: 21301205_updated
# Updated game file: 21301204
# Updated game file: 21301211_updated
# Updated game file: 21301204_updated
# Updated game file: 21301212
# Updated game file: 21301208_updated
# Updated game file: 21301212_updated
# Updated game file: 21301208
# Updated game file: 21301213_updated
# Updated game file: 21301207_updated
# Updated game file: 21301206
# Updated game file: 21301207
# Updated game file: 21301213
# Updated game file: 21301210_updated
# Updated game file: 21301209
# Processing date: 20140415
# Successfully pulled Overall defense data for 20140415
# Successfully pulled 3PT defense data for 20140415
# Successfully pulled 2PT defense data for 20140415
# Successfully pulled <6ft defense data for 20140415
# Successfully pulled <10ft defense data for 20140415
# Successfully pulled >15ft defense data for 20140415
# Successfully pulled post touch stats for 20140415
# Successfully pulled speed distance stats for 20140415
# Saved additional data for date 20140415
# Updated game file: 21301215_updated
# Updated game file: 21301214
# Updated game file: 21301215
# Updated game file: 21301214_updated
# Processing date: 20140416
# Successfully pulled Overall defense data for 20140416
# Successfully pulled 3PT defense data for 20140416
# Successfully pulled 2PT defense data for 20140416
# Successfully pulled <6ft defense data for 20140416
# Successfully pulled <10ft defense data for 20140416
# Successfully pulled >15ft defense data for 20140416
# Successfully pulled post touch stats for 20140416
# Successfully pulled speed distance stats for 20140416
# Saved additional data for date 20140416
# Updated game file: 21301227
# Updated game file: 21301222_updated
# Updated game file: 21301222
# Updated game file: 21301221_updated
# Updated game file: 21301220
# Updated game file: 21301228
# Updated game file: 21301224_updated
# Updated game file: 21301219
# Updated game file: 21301219_updated
# Updated game file: 21301218
# Updated game file: 21301224
# Updated game file: 21301220_updated
# Updated game file: 21301227_updated
# Updated game file: 21301226
# Updated game file: 21301217_updated
# Updated game file: 21301216_updated
# Updated game file: 21301225_updated
# Updated game file: 21301230
# Updated game file: 21301228_updated
# Updated game file: 21301216
# Updated game file: 21301230_updated
# Updated game file: 21301223
# Updated game file: 21301218_updated
# Updated game file: 21301221
# Updated game file: 21301223_updated
# Updated game file: 21301229
# Updated game file: 21301226_updated
# Updated game file: 21301225
# Updated game file: 21301229_updated
# Updated game file: 21301217
# Processing date: 20140419
# Successfully pulled Overall defense data for 20140419
# Successfully pulled 3PT defense data for 20140419
# Successfully pulled 2PT defense data for 20140419
# Successfully pulled <6ft defense data for 20140419
# Successfully pulled <10ft defense data for 20140419
# Successfully pulled >15ft defense data for 20140419
# Successfully pulled post touch stats for 20140419
# Successfully pulled speed distance stats for 20140419
# Saved additional data for date 20140419
# Updated game file: 41300151_updated
# Updated game file: 41300101
# Updated game file: 41300161
# Updated game file: 41300121
# Updated game file: 41300121_updated
# Updated game file: 41300101_updated
# Updated game file: 41300161_updated
# Updated game file: 41300151
# Processing date: 20140420
# Successfully pulled Overall defense data for 20140420
# Successfully pulled 3PT defense data for 20140420
# Successfully pulled 2PT defense data for 20140420
# Successfully pulled <6ft defense data for 20140420
# Successfully pulled <10ft defense data for 20140420
# Successfully pulled >15ft defense data for 20140420
# Successfully pulled post touch stats for 20140420
# Successfully pulled speed distance stats for 20140420
# Saved additional data for date 20140420
# Updated game file: 41300111
# Updated game file: 41300141
# Updated game file: 41300171_updated
# Updated game file: 41300171
# Updated game file: 41300131
# Updated game file: 41300141_updated
# Updated game file: 41300111_updated
# Updated game file: 41300131_updated
# Processing date: 20140421
# Successfully pulled Overall defense data for 20140421
# Successfully pulled 3PT defense data for 20140421
# Successfully pulled 2PT defense data for 20140421
# Successfully pulled <6ft defense data for 20140421
# Successfully pulled <10ft defense data for 20140421
# Successfully pulled >15ft defense data for 20140421
# Successfully pulled post touch stats for 20140421
# Successfully pulled speed distance stats for 20140421
# Saved additional data for date 20140421
# Updated game file: 41300152
# Updated game file: 41300162
# Updated game file: 41300152_updated
# Updated game file: 41300162_updated
# Processing date: 20140422
# Successfully pulled Overall defense data for 20140422
# Successfully pulled 3PT defense data for 20140422
# Successfully pulled 2PT defense data for 20140422
# Successfully pulled <6ft defense data for 20140422
# Successfully pulled <10ft defense data for 20140422
# Successfully pulled >15ft defense data for 20140422
# Successfully pulled post touch stats for 20140422
# Successfully pulled speed distance stats for 20140422
# Saved additional data for date 20140422
# Updated game file: 41300102_updated
# Updated game file: 41300132_updated
# Updated game file: 41300132
# Updated game file: 41300122
# Updated game file: 41300102
# Updated game file: 41300122_updated
# Processing date: 20140423
# Successfully pulled Overall defense data for 20140423
# Successfully pulled 3PT defense data for 20140423
# Successfully pulled 2PT defense data for 20140423
# Successfully pulled <6ft defense data for 20140423
# Successfully pulled <10ft defense data for 20140423
# Successfully pulled >15ft defense data for 20140423
# Successfully pulled post touch stats for 20140423
# Successfully pulled speed distance stats for 20140423
# Saved additional data for date 20140423
# Updated game file: 41300172
# Updated game file: 41300172_updated
# Updated game file: 41300142_updated
# Updated game file: 41300112_updated
# Updated game file: 41300112
# Updated game file: 41300142
# Processing date: 20140424
# Successfully pulled Overall defense data for 20140424
# Successfully pulled 3PT defense data for 20140424
# Successfully pulled 2PT defense data for 20140424
# Successfully pulled <6ft defense data for 20140424
# Successfully pulled <10ft defense data for 20140424
# Successfully pulled >15ft defense data for 20140424
# Successfully pulled post touch stats for 20140424
# Successfully pulled speed distance stats for 20140424
# Saved additional data for date 20140424
# Updated game file: 41300153
# Updated game file: 41300103
# Updated game file: 41300163
# Updated game file: 41300153_updated
# Updated game file: 41300163_updated
# Updated game file: 41300103_updated
# Processing date: 20140425
# Successfully pulled Overall defense data for 20140425
# Successfully pulled 3PT defense data for 20140425
# Successfully pulled 2PT defense data for 20140425
# Successfully pulled <6ft defense data for 20140425
# Successfully pulled <10ft defense data for 20140425
# Successfully pulled >15ft defense data for 20140425
# Successfully pulled post touch stats for 20140425
# Successfully pulled speed distance stats for 20140425
# Saved additional data for date 20140425
# Updated game file: 41300173
# Updated game file: 41300123
# Updated game file: 41300173_updated
# Updated game file: 41300133
# Updated game file: 41300133_updated
# Updated game file: 41300123_updated
# Processing date: 20140426
# Successfully pulled Overall defense data for 20140426
# Successfully pulled 3PT defense data for 20140426
# Successfully pulled 2PT defense data for 20140426
# Successfully pulled <6ft defense data for 20140426
# Successfully pulled <10ft defense data for 20140426
# Successfully pulled >15ft defense data for 20140426
# Successfully pulled post touch stats for 20140426
# Successfully pulled speed distance stats for 20140426
# Saved additional data for date 20140426
# Updated game file: 41300143_updated
# Updated game file: 41300113_updated
# Updated game file: 41300154
# Updated game file: 41300113
# Updated game file: 41300154_updated
# Updated game file: 41300104
# Updated game file: 41300143
# Updated game file: 41300104_updated
# Processing date: 20140427
# Successfully pulled Overall defense data for 20140427
# Successfully pulled 3PT defense data for 20140427
# Successfully pulled 2PT defense data for 20140427
# Successfully pulled <6ft defense data for 20140427
# Successfully pulled <10ft defense data for 20140427
# Successfully pulled >15ft defense data for 20140427
# Successfully pulled post touch stats for 20140427
# Successfully pulled speed distance stats for 20140427
# Saved additional data for date 20140427
# Updated game file: 41300124_updated
# Updated game file: 41300164_updated
# Updated game file: 41300134_updated
# Updated game file: 41300174
# Updated game file: 41300174_updated
# Updated game file: 41300134
# Updated game file: 41300164
# Updated game file: 41300124
# Processing date: 20140428
# Successfully pulled Overall defense data for 20140428
# Successfully pulled 3PT defense data for 20140428
# Successfully pulled 2PT defense data for 20140428
# Successfully pulled <6ft defense data for 20140428
# Successfully pulled <10ft defense data for 20140428
# Successfully pulled >15ft defense data for 20140428
# Successfully pulled post touch stats for 20140428
# Successfully pulled speed distance stats for 20140428
# Saved additional data for date 20140428
# Updated game file: 41300114_updated
# Updated game file: 41300144_updated
# Updated game file: 41300144
# Updated game file: 41300105_updated
# Updated game file: 41300114
# Updated game file: 41300105
# Processing date: 20140429
# Successfully pulled Overall defense data for 20140429
# Successfully pulled 3PT defense data for 20140429
# Successfully pulled 2PT defense data for 20140429
# Successfully pulled <6ft defense data for 20140429
# Successfully pulled <10ft defense data for 20140429
# Successfully pulled >15ft defense data for 20140429
# Successfully pulled post touch stats for 20140429
# Successfully pulled speed distance stats for 20140429
# Saved additional data for date 20140429
# Updated game file: 41300165_updated
# Updated game file: 41300135
# Updated game file: 41300155_updated
# Updated game file: 41300155
# Updated game file: 41300165
# Updated game file: 41300135_updated
# Processing date: 20140430
# Successfully pulled Overall defense data for 20140430
# Successfully pulled 3PT defense data for 20140430
# Successfully pulled 2PT defense data for 20140430
# Successfully pulled <6ft defense data for 20140430
# Successfully pulled <10ft defense data for 20140430
# Successfully pulled >15ft defense data for 20140430
# Successfully pulled post touch stats for 20140430
# Successfully pulled speed distance stats for 20140430
# Saved additional data for date 20140430
# Updated game file: 41300145
# Updated game file: 41300175_updated
# Updated game file: 41300145_updated
# Updated game file: 41300125_updated
# Updated game file: 41300175
# Updated game file: 41300125
# Processing date: 20140501
# Successfully pulled Overall defense data for 20140501
# Successfully pulled 3PT defense data for 20140501
# Successfully pulled 2PT defense data for 20140501
# Successfully pulled <6ft defense data for 20140501
# Successfully pulled <10ft defense data for 20140501
# Successfully pulled >15ft defense data for 20140501
# Successfully pulled post touch stats for 20140501
# Successfully pulled speed distance stats for 20140501
# Saved additional data for date 20140501
# Updated game file: 41300156
# Updated game file: 41300166_updated
# Updated game file: 41300106
# Updated game file: 41300166
# Updated game file: 41300156_updated
# Updated game file: 41300106_updated
# Processing date: 20140502
# Successfully pulled Overall defense data for 20140502
# Successfully pulled 3PT defense data for 20140502
# Successfully pulled 2PT defense data for 20140502
# Successfully pulled <6ft defense data for 20140502
# Successfully pulled <10ft defense data for 20140502
# Successfully pulled >15ft defense data for 20140502
# Successfully pulled post touch stats for 20140502
# Successfully pulled speed distance stats for 20140502
# Saved additional data for date 20140502
# Updated game file: 41300146
# Updated game file: 41300126_updated
# Updated game file: 41300146_updated
# Updated game file: 41300176
# Updated game file: 41300126
# Updated game file: 41300176_updated
# Processing date: 20140503
# Successfully pulled Overall defense data for 20140503
# Successfully pulled 3PT defense data for 20140503
# Successfully pulled 2PT defense data for 20140503
# Successfully pulled <6ft defense data for 20140503
# Successfully pulled <10ft defense data for 20140503
# Successfully pulled >15ft defense data for 20140503
# Successfully pulled post touch stats for 20140503
# Successfully pulled speed distance stats for 20140503
# Saved additional data for date 20140503
# Updated game file: 41300167
# Updated game file: 41300157_updated
# Updated game file: 41300167_updated
# Updated game file: 41300107
# Updated game file: 41300157
# Updated game file: 41300107_updated
# Processing date: 20140504
# Successfully pulled Overall defense data for 20140504
# Successfully pulled 3PT defense data for 20140504
# Successfully pulled 2PT defense data for 20140504
# Successfully pulled <6ft defense data for 20140504
# Successfully pulled <10ft defense data for 20140504
# Successfully pulled >15ft defense data for 20140504
# Successfully pulled post touch stats for 20140504
# Successfully pulled speed distance stats for 20140504
# Saved additional data for date 20140504
# Updated game file: 41300147
# Updated game file: 41300147_updated
# Updated game file: 41300127_updated
# Updated game file: 41300127
# Processing date: 20140505
# Successfully pulled Overall defense data for 20140505
# Successfully pulled 3PT defense data for 20140505
# Successfully pulled 2PT defense data for 20140505
# Successfully pulled <6ft defense data for 20140505
# Successfully pulled <10ft defense data for 20140505
# Successfully pulled >15ft defense data for 20140505
# Successfully pulled post touch stats for 20140505
# Successfully pulled speed distance stats for 20140505
# Saved additional data for date 20140505
# Updated game file: 41300201
# Updated game file: 41300201_updated
# Updated game file: 41300231
# Updated game file: 41300231_updated
# Processing date: 20140506
# Successfully pulled Overall defense data for 20140506
# Successfully pulled 3PT defense data for 20140506
# Successfully pulled 2PT defense data for 20140506
# Successfully pulled <6ft defense data for 20140506
# Successfully pulled <10ft defense data for 20140506
# Successfully pulled >15ft defense data for 20140506
# Successfully pulled post touch stats for 20140506
# Successfully pulled speed distance stats for 20140506
# Saved additional data for date 20140506
# Updated game file: 41300221_updated
# Updated game file: 41300211
# Updated game file: 41300221
# Updated game file: 41300211_updated
# Processing date: 20140507
# Successfully pulled Overall defense data for 20140507
# Successfully pulled 3PT defense data for 20140507
# Successfully pulled 2PT defense data for 20140507
# Successfully pulled <6ft defense data for 20140507
# Successfully pulled <10ft defense data for 20140507
# Successfully pulled >15ft defense data for 20140507
# Successfully pulled post touch stats for 20140507
# Successfully pulled speed distance stats for 20140507
# Saved additional data for date 20140507
# Updated game file: 41300202_updated
# Updated game file: 41300202
# Updated game file: 41300232
# Updated game file: 41300232_updated
# Processing date: 20140508
# Successfully pulled Overall defense data for 20140508
# Successfully pulled 3PT defense data for 20140508
# Successfully pulled 2PT defense data for 20140508
# Successfully pulled <6ft defense data for 20140508
# Successfully pulled <10ft defense data for 20140508
# Successfully pulled >15ft defense data for 20140508
# Successfully pulled post touch stats for 20140508
# Successfully pulled speed distance stats for 20140508
# Saved additional data for date 20140508
# Updated game file: 41300212
# Updated game file: 41300212_updated
# Updated game file: 41300222_updated
# Updated game file: 41300222
# Processing date: 20140509
# Successfully pulled Overall defense data for 20140509
# Successfully pulled 3PT defense data for 20140509
# Successfully pulled 2PT defense data for 20140509
# Successfully pulled <6ft defense data for 20140509
# Successfully pulled <10ft defense data for 20140509
# Successfully pulled >15ft defense data for 20140509
# Successfully pulled post touch stats for 20140509
# Successfully pulled speed distance stats for 20140509
# Saved additional data for date 20140509
# Updated game file: 41300203
# Updated game file: 41300233_updated
# Updated game file: 41300203_updated
# Updated game file: 41300233
# Processing date: 20140510
# Successfully pulled Overall defense data for 20140510
# Successfully pulled 3PT defense data for 20140510
# Successfully pulled 2PT defense data for 20140510
# Successfully pulled <6ft defense data for 20140510
# Successfully pulled <10ft defense data for 20140510
# Successfully pulled >15ft defense data for 20140510
# Successfully pulled post touch stats for 20140510
# Successfully pulled speed distance stats for 20140510
# Saved additional data for date 20140510
# Updated game file: 41300213
# Updated game file: 41300223_updated
# Updated game file: 41300213_updated
# Updated game file: 41300223
# Processing date: 20140511
# Successfully pulled Overall defense data for 20140511
# Successfully pulled 3PT defense data for 20140511
# Successfully pulled 2PT defense data for 20140511
# Successfully pulled <6ft defense data for 20140511
# Successfully pulled <10ft defense data for 20140511
# Successfully pulled >15ft defense data for 20140511
# Successfully pulled post touch stats for 20140511
# Successfully pulled speed distance stats for 20140511
# Saved additional data for date 20140511
# Updated game file: 41300234_updated
# Updated game file: 41300204
# Updated game file: 41300234
# Updated game file: 41300204_updated
# Processing date: 20140512
# Successfully pulled Overall defense data for 20140512
# Successfully pulled 3PT defense data for 20140512
# Successfully pulled 2PT defense data for 20140512
# Successfully pulled <6ft defense data for 20140512
# Successfully pulled <10ft defense data for 20140512
# Successfully pulled >15ft defense data for 20140512
# Successfully pulled post touch stats for 20140512
# Successfully pulled speed distance stats for 20140512
# Saved additional data for date 20140512
# Updated game file: 41300214
# Updated game file: 41300214_updated
# Updated game file: 41300224
# Updated game file: 41300224_updated
# Processing date: 20140513
# Successfully pulled Overall defense data for 20140513
# Successfully pulled 3PT defense data for 20140513
# Successfully pulled 2PT defense data for 20140513
# Successfully pulled <6ft defense data for 20140513
# Successfully pulled <10ft defense data for 20140513
# Successfully pulled >15ft defense data for 20140513
# Successfully pulled post touch stats for 20140513
# Successfully pulled speed distance stats for 20140513
# Saved additional data for date 20140513
# Updated game file: 41300235_updated
# Updated game file: 41300205_updated
# Updated game file: 41300205
# Updated game file: 41300235
# Processing date: 20140514
# Successfully pulled Overall defense data for 20140514
# Successfully pulled 3PT defense data for 20140514
# Successfully pulled 2PT defense data for 20140514
# Successfully pulled <6ft defense data for 20140514
# Successfully pulled <10ft defense data for 20140514
# Successfully pulled >15ft defense data for 20140514
# Successfully pulled post touch stats for 20140514
# Successfully pulled speed distance stats for 20140514
# Saved additional data for date 20140514
# Updated game file: 41300215_updated
# Updated game file: 41300225_updated
# Updated game file: 41300215
# Updated game file: 41300225
# Processing date: 20140515
# Successfully pulled Overall defense data for 20140515
# Successfully pulled 3PT defense data for 20140515
# Successfully pulled 2PT defense data for 20140515
# Successfully pulled <6ft defense data for 20140515
# Successfully pulled <10ft defense data for 20140515
# Successfully pulled >15ft defense data for 20140515
# Successfully pulled post touch stats for 20140515
# Successfully pulled speed distance stats for 20140515
# Saved additional data for date 20140515
# Updated game file: 41300206
# Updated game file: 41300236_updated
# Updated game file: 41300206_updated
# Updated game file: 41300236
# Processing date: 20140518
# Successfully pulled Overall defense data for 20140518
# Successfully pulled 3PT defense data for 20140518
# Successfully pulled 2PT defense data for 20140518
# Successfully pulled <6ft defense data for 20140518
# Successfully pulled <10ft defense data for 20140518
# Successfully pulled >15ft defense data for 20140518
# Successfully pulled post touch stats for 20140518
# Successfully pulled speed distance stats for 20140518
# Saved additional data for date 20140518
# Updated game file: 41300301_updated
# Updated game file: 41300301
# Processing date: 20140519
# Successfully pulled Overall defense data for 20140519
# Successfully pulled 3PT defense data for 20140519
# Successfully pulled 2PT defense data for 20140519
# Successfully pulled <6ft defense data for 20140519
# Successfully pulled <10ft defense data for 20140519
# Successfully pulled >15ft defense data for 20140519
# Successfully pulled post touch stats for 20140519
# Successfully pulled speed distance stats for 20140519
# Saved additional data for date 20140519
# Updated game file: 41300311
# Updated game file: 41300311_updated
# Processing date: 20140520
# Successfully pulled Overall defense data for 20140520
# Successfully pulled 3PT defense data for 20140520
# Successfully pulled 2PT defense data for 20140520
# Successfully pulled <6ft defense data for 20140520
# Successfully pulled <10ft defense data for 20140520
# Successfully pulled >15ft defense data for 20140520
# Successfully pulled post touch stats for 20140520
# Successfully pulled speed distance stats for 20140520
# Saved additional data for date 20140520
# Updated game file: 41300302_updated
# Updated game file: 41300302
# Processing date: 20140521
# Successfully pulled Overall defense data for 20140521
# Successfully pulled 3PT defense data for 20140521
# Successfully pulled 2PT defense data for 20140521
# Successfully pulled <6ft defense data for 20140521
# Successfully pulled <10ft defense data for 20140521
# Successfully pulled >15ft defense data for 20140521
# Successfully pulled post touch stats for 20140521
# Successfully pulled speed distance stats for 20140521
# Saved additional data for date 20140521
# Updated game file: 41300312
# Updated game file: 41300312_updated
# Processing date: 20140524
# Successfully pulled Overall defense data for 20140524
# Successfully pulled 3PT defense data for 20140524
# Successfully pulled 2PT defense data for 20140524
# Successfully pulled <6ft defense data for 20140524
# Successfully pulled <10ft defense data for 20140524
# Successfully pulled >15ft defense data for 20140524
# Successfully pulled post touch stats for 20140524
# Successfully pulled speed distance stats for 20140524
# Saved additional data for date 20140524
# Updated game file: 41300303_updated
# Updated game file: 41300303
# Processing date: 20140525
# Successfully pulled Overall defense data for 20140525
# Successfully pulled 3PT defense data for 20140525
# Successfully pulled 2PT defense data for 20140525
# Successfully pulled <6ft defense data for 20140525
# Successfully pulled <10ft defense data for 20140525
# Successfully pulled >15ft defense data for 20140525
# Successfully pulled post touch stats for 20140525
# Successfully pulled speed distance stats for 20140525
# Saved additional data for date 20140525
# Updated game file: 41300313
# Updated game file: 41300313_updated
# Processing date: 20140526
# Successfully pulled Overall defense data for 20140526
# Successfully pulled 3PT defense data for 20140526
# Successfully pulled 2PT defense data for 20140526
# Successfully pulled <6ft defense data for 20140526
# Successfully pulled <10ft defense data for 20140526
# Successfully pulled >15ft defense data for 20140526
# Successfully pulled post touch stats for 20140526
# Successfully pulled speed distance stats for 20140526
# Saved additional data for date 20140526
# Updated game file: 41300304
# Processing date: 20140527
# Successfully pulled Overall defense data for 20140527
# Successfully pulled 3PT defense data for 20140527
# Successfully pulled 2PT defense data for 20140527
# Successfully pulled <6ft defense data for 20140527
# Successfully pulled <10ft defense data for 20140527
# Successfully pulled >15ft defense data for 20140527
# Successfully pulled post touch stats for 20140527
# Successfully pulled speed distance stats for 20140527
# Saved additional data for date 20140527
# Updated game file: 41300314
# Processing date: 20140528
# Successfully pulled Overall defense data for 20140528
# Successfully pulled 3PT defense data for 20140528
# Successfully pulled 2PT defense data for 20140528
# Successfully pulled <6ft defense data for 20140528
# Successfully pulled <10ft defense data for 20140528
# Successfully pulled >15ft defense data for 20140528
# Successfully pulled post touch stats for 20140528
# Successfully pulled speed distance stats for 20140528
# Saved additional data for date 20140528
# Updated game file: 41300305
# Processing date: 20140529
# Successfully pulled Overall defense data for 20140529
# Successfully pulled 3PT defense data for 20140529
# Successfully pulled 2PT defense data for 20140529
# Successfully pulled <6ft defense data for 20140529
# Successfully pulled <10ft defense data for 20140529
# Successfully pulled >15ft defense data for 20140529
# Successfully pulled post touch stats for 20140529
# Successfully pulled speed distance stats for 20140529
# Saved additional data for date 20140529
# Updated game file: 41300315
# Processing date: 20140530
# Successfully pulled Overall defense data for 20140530
# Successfully pulled 3PT defense data for 20140530
# Successfully pulled 2PT defense data for 20140530
# Successfully pulled <6ft defense data for 20140530
# Successfully pulled <10ft defense data for 20140530
# Successfully pulled >15ft defense data for 20140530
# Successfully pulled post touch stats for 20140530
# Successfully pulled speed distance stats for 20140530
# Saved additional data for date 20140530
# Updated game file: 41300306
# Processing date: 20140531
# ...
# Successfully pulled post touch stats for 20160223
# Successfully pulled speed distance stats for 20160223
# Saved additional data for date 20160223
# Updated game file: 21500840
# Updated game file: 21500844
# Updated game file: 21500843
# Updated game file: 21500842
# Updated game file: 21500841
# Processing date: 20160224
# Successfully pulled Overall defense data for 20160224
# Successfully pulled 3PT defense data for 20160224
# Successfully pulled 2PT defense data for 20160224
# Successfully pulled <6ft defense data for 20160224
# Successfully pulled <10ft defense data for 20160224
# Successfully pulled >15ft defense data for 20160224
# Successfully pulled hustle stats for 20160224
# Successfully pulled post touch stats for 20160224
# Successfully pulled speed distance stats for 20160224
# Saved additional data for date 20160224
# Updated game file: 21500851
# Updated game file: 21500845
# Updated game file: 21500846
# Updated game file: 21500852
# Updated game file: 21500850
# Updated game file: 21500847
# Updated game file: 21500848
# Updated game file: 21500854
# Updated game file: 21500849
# Updated game file: 21500853
# Processing date: 20160225
# Successfully pulled Overall defense data for 20160225
# Successfully pulled 3PT defense data for 20160225
# Successfully pulled 2PT defense data for 20160225
# Successfully pulled <6ft defense data for 20160225
# Successfully pulled <10ft defense data for 20160225
# Successfully pulled >15ft defense data for 20160225
# Successfully pulled hustle stats for 20160225
# Successfully pulled post touch stats for 20160225
# Successfully pulled speed distance stats for 20160225
# Saved additional data for date 20160225
# Updated game file: 21500859
# Updated game file: 21500860
# Updated game file: 21500856
# Updated game file: 21500858
# Updated game file: 21500857
# Updated game file: 21500855
# Processing date: 20160226
# Successfully pulled Overall defense data for 20160226
# Successfully pulled 3PT defense data for 20160226
# Successfully pulled 2PT defense data for 20160226
# Successfully pulled <6ft defense data for 20160226
# Successfully pulled <10ft defense data for 20160226
# Successfully pulled >15ft defense data for 20160226
# Successfully pulled hustle stats for 20160226
# Successfully pulled post touch stats for 20160226
# Successfully pulled speed distance stats for 20160226
# Saved additional data for date 20160226
# Updated game file: 21500867
# Updated game file: 21500861
# Updated game file: 21500865
# Updated game file: 21500868
# Updated game file: 21500863
# Updated game file: 21500864
# Updated game file: 21500862
# Updated game file: 21500866
# Processing date: 20160227
# Successfully pulled Overall defense data for 20160227
# Successfully pulled 3PT defense data for 20160227
# Successfully pulled 2PT defense data for 20160227
# Successfully pulled <6ft defense data for 20160227
# Successfully pulled <10ft defense data for 20160227
# Successfully pulled >15ft defense data for 20160227
# Successfully pulled hustle stats for 20160227
# Successfully pulled post touch stats for 20160227
# Successfully pulled speed distance stats for 20160227
# Saved additional data for date 20160227
# Updated game file: 21500871
# Updated game file: 21500874
# Updated game file: 21500872
# Updated game file: 21500869
# Updated game file: 21500873
# Updated game file: 21500876
# Updated game file: 21500870
# Updated game file: 21500875
# Processing date: 20160228
# Successfully pulled Overall defense data for 20160228
# Successfully pulled 3PT defense data for 20160228
# Successfully pulled 2PT defense data for 20160228
# Successfully pulled <6ft defense data for 20160228
# Successfully pulled <10ft defense data for 20160228
# Successfully pulled >15ft defense data for 20160228
# Successfully pulled hustle stats for 20160228
# Successfully pulled post touch stats for 20160228
# Successfully pulled speed distance stats for 20160228
# Saved additional data for date 20160228
# Updated game file: 21500877
# Updated game file: 21500880
# Updated game file: 21500883
# Updated game file: 21500879
# Updated game file: 21500882
# Updated game file: 21500878
# Updated game file: 21500881
# Processing date: 20160229
# Successfully pulled Overall defense data for 20160229
# Successfully pulled 3PT defense data for 20160229
# Successfully pulled 2PT defense data for 20160229
# Successfully pulled <6ft defense data for 20160229
# Successfully pulled <10ft defense data for 20160229
# Successfully pulled >15ft defense data for 20160229
# Successfully pulled hustle stats for 20160229
# Successfully pulled post touch stats for 20160229
# Successfully pulled speed distance stats for 20160229
# Saved additional data for date 20160229
# Updated game file: 21500885
# Updated game file: 21500887
# Updated game file: 21500886
# Updated game file: 21500890
# Updated game file: 21500889
# Updated game file: 21500888
# Updated game file: 21500884
# Processing date: 20160301
# Successfully pulled Overall defense data for 20160301
# Successfully pulled 3PT defense data for 20160301
# Successfully pulled 2PT defense data for 20160301
# Successfully pulled <6ft defense data for 20160301
# Successfully pulled <10ft defense data for 20160301
# Successfully pulled >15ft defense data for 20160301
# Successfully pulled hustle stats for 20160301
# Successfully pulled post touch stats for 20160301
# Successfully pulled speed distance stats for 20160301
# Saved additional data for date 20160301
# Updated game file: 21500896
# Updated game file: 21500894
# Updated game file: 21500893
# Updated game file: 21500895
# Updated game file: 21500891
# Updated game file: 21500892
# Processing date: 20160302
# Successfully pulled Overall defense data for 20160302
# Successfully pulled 3PT defense data for 20160302
# Successfully pulled 2PT defense data for 20160302
# Successfully pulled <6ft defense data for 20160302
# Successfully pulled <10ft defense data for 20160302
# Successfully pulled >15ft defense data for 20160302
# Successfully pulled hustle stats for 20160302
# Successfully pulled post touch stats for 20160302
# Successfully pulled speed distance stats for 20160302
# Saved additional data for date 20160302
# Updated game file: 21500902
# Updated game file: 21500905
# Updated game file: 21500900
# Updated game file: 21500897
# Updated game file: 21500899
# Updated game file: 21500906
# Updated game file: 21500903
# Updated game file: 21500898
# Updated game file: 21500904
# Updated game file: 21500907
# Updated game file: 21500901
# Processing date: 20160303
# Successfully pulled Overall defense data for 20160303
# Successfully pulled 3PT defense data for 20160303
# Successfully pulled 2PT defense data for 20160303
# Successfully pulled <6ft defense data for 20160303
# Successfully pulled <10ft defense data for 20160303
# Successfully pulled >15ft defense data for 20160303
# Successfully pulled hustle stats for 20160303
# Successfully pulled post touch stats for 20160303
# Successfully pulled speed distance stats for 20160303
# Saved additional data for date 20160303
# Updated game file: 21500910
# Updated game file: 21500909
# Updated game file: 21500908
# Updated game file: 21500911
# Processing date: 20160304
# Successfully pulled Overall defense data for 20160304
# Successfully pulled 3PT defense data for 20160304
# Successfully pulled 2PT defense data for 20160304
# Successfully pulled <6ft defense data for 20160304
# Successfully pulled <10ft defense data for 20160304
# Successfully pulled >15ft defense data for 20160304
# Successfully pulled hustle stats for 20160304
# Successfully pulled post touch stats for 20160304
# Successfully pulled speed distance stats for 20160304
# Saved additional data for date 20160304
# Updated game file: 21500918
# Updated game file: 21500917
# Updated game file: 21500916
# Updated game file: 21500912
# Updated game file: 21500915
# Updated game file: 21500914
# Updated game file: 21500919
# Updated game file: 21500921
# Updated game file: 21500920
# Updated game file: 21500913
# Processing date: 20160305
# Successfully pulled Overall defense data for 20160305
# Successfully pulled 3PT defense data for 20160305
# Successfully pulled 2PT defense data for 20160305
# Successfully pulled <6ft defense data for 20160305
# Successfully pulled <10ft defense data for 20160305
# Successfully pulled >15ft defense data for 20160305
# Successfully pulled hustle stats for 20160305
# Successfully pulled post touch stats for 20160305
# Successfully pulled speed distance stats for 20160305
# Saved additional data for date 20160305
# Updated game file: 21500922
# Updated game file: 21500923
# Updated game file: 21500925
# Updated game file: 21500924
# Updated game file: 21500928
# Updated game file: 21500929
# Updated game file: 21500927
# Updated game file: 21500926
# Processing date: 20160306
# Successfully pulled Overall defense data for 20160306
# Successfully pulled 3PT defense data for 20160306
# Successfully pulled 2PT defense data for 20160306
# Successfully pulled <6ft defense data for 20160306
# Successfully pulled <10ft defense data for 20160306
# Successfully pulled >15ft defense data for 20160306
# Successfully pulled hustle stats for 20160306
# Successfully pulled post touch stats for 20160306
# Successfully pulled speed distance stats for 20160306
# Saved additional data for date 20160306
# Updated game file: 21500936
# Updated game file: 21500930
# Updated game file: 21500933
# Updated game file: 21500931
# Updated game file: 21500935
# Updated game file: 21500932
# Updated game file: 21500934
# Processing date: 20160307
# Successfully pulled Overall defense data for 20160307
# Successfully pulled 3PT defense data for 20160307
# Successfully pulled 2PT defense data for 20160307
# Successfully pulled <6ft defense data for 20160307
# Successfully pulled <10ft defense data for 20160307
# Successfully pulled >15ft defense data for 20160307
# Successfully pulled hustle stats for 20160307
# Successfully pulled post touch stats for 20160307
# Successfully pulled speed distance stats for 20160307
# Saved additional data for date 20160307
# Updated game file: 21500937
# Updated game file: 21500938
# Updated game file: 21500939
# Updated game file: 21500940
# Updated game file: 21500943
# Updated game file: 21500941
# Updated game file: 21500942
# Processing date: 20160308
# Successfully pulled Overall defense data for 20160308
# Successfully pulled 3PT defense data for 20160308
# Successfully pulled 2PT defense data for 20160308
# Successfully pulled <6ft defense data for 20160308
# Successfully pulled <10ft defense data for 20160308
# Successfully pulled >15ft defense data for 20160308
# Successfully pulled hustle stats for 20160308
# Successfully pulled post touch stats for 20160308
# Successfully pulled speed distance stats for 20160308
# Saved additional data for date 20160308
# Updated game file: 21500945
# Updated game file: 21500948
# Updated game file: 21500944
# Updated game file: 21500947
# Updated game file: 21500949
# Updated game file: 21500946
# Processing date: 20160309
# Successfully pulled Overall defense data for 20160309
# Successfully pulled 3PT defense data for 20160309
# Successfully pulled 2PT defense data for 20160309
# Successfully pulled <6ft defense data for 20160309
# Successfully pulled <10ft defense data for 20160309
# Successfully pulled >15ft defense data for 20160309
# Successfully pulled hustle stats for 20160309
# Successfully pulled post touch stats for 20160309
# Successfully pulled speed distance stats for 20160309
# Saved additional data for date 20160309
# Updated game file: 21500952
# Updated game file: 21500954
# Updated game file: 21500950
# Updated game file: 21500956
# Updated game file: 21500953
# Updated game file: 21500957
# Updated game file: 21500958
# Updated game file: 21500951
# Updated game file: 21500955
# Processing date: 20160310
# Successfully pulled Overall defense data for 20160310
# Successfully pulled 3PT defense data for 20160310
# Successfully pulled 2PT defense data for 20160310
# Successfully pulled <6ft defense data for 20160310
# Successfully pulled <10ft defense data for 20160310
# Successfully pulled >15ft defense data for 20160310
# Successfully pulled hustle stats for 20160310
# Successfully pulled post touch stats for 20160310
# Successfully pulled speed distance stats for 20160310
# Saved additional data for date 20160310
# Updated game file: 21500959
# Updated game file: 21500961
# Updated game file: 21500960
# Updated game file: 21500962
# Processing date: 20160311
# Successfully pulled Overall defense data for 20160311
# Successfully pulled 3PT defense data for 20160311
# Successfully pulled 2PT defense data for 20160311
# Successfully pulled <6ft defense data for 20160311
# Successfully pulled <10ft defense data for 20160311
# Successfully pulled >15ft defense data for 20160311
# Successfully pulled hustle stats for 20160311
# Successfully pulled post touch stats for 20160311
# Successfully pulled speed distance stats for 20160311
# Saved additional data for date 20160311
# Updated game file: 21500971
# Updated game file: 21500966
# Updated game file: 21500963
# Updated game file: 21500968
# Updated game file: 21500964
# Updated game file: 21500967
# Updated game file: 21500970
# Updated game file: 21500965
# Updated game file: 21500969
# Updated game file: 21500972
# Processing date: 20160312
# Successfully pulled Overall defense data for 20160312
# Successfully pulled 3PT defense data for 20160312
# Successfully pulled 2PT defense data for 20160312
# Successfully pulled <6ft defense data for 20160312
# Successfully pulled <10ft defense data for 20160312
# Successfully pulled >15ft defense data for 20160312
# Successfully pulled hustle stats for 20160312
# Successfully pulled post touch stats for 20160312
# Successfully pulled speed distance stats for 20160312
# Saved additional data for date 20160312
# Updated game file: 21500978
# Updated game file: 21500982
# Updated game file: 21500976
# Updated game file: 21500973
# Updated game file: 21500974
# Updated game file: 21500980
# Updated game file: 21500975
# Updated game file: 21500979
# Updated game file: 21500977
# Updated game file: 21500981
# Processing date: 20160313
# Successfully pulled Overall defense data for 20160313
# Successfully pulled 3PT defense data for 20160313
# Successfully pulled 2PT defense data for 20160313
# Successfully pulled <6ft defense data for 20160313
# Successfully pulled <10ft defense data for 20160313
# Successfully pulled >15ft defense data for 20160313
# Successfully pulled hustle stats for 20160313
# Successfully pulled post touch stats for 20160313
# Successfully pulled speed distance stats for 20160313
# Saved additional data for date 20160313
# Updated game file: 21500985
# Updated game file: 21500987
# Updated game file: 21500984
# Updated game file: 21500983
# Updated game file: 21500986
# Processing date: 20160314
# Successfully pulled Overall defense data for 20160314
# Successfully pulled 3PT defense data for 20160314
# Successfully pulled 2PT defense data for 20160314
# Successfully pulled <6ft defense data for 20160314
# Successfully pulled <10ft defense data for 20160314
# Successfully pulled >15ft defense data for 20160314
# Successfully pulled hustle stats for 20160314
# Successfully pulled post touch stats for 20160314
# Successfully pulled speed distance stats for 20160314
# Saved additional data for date 20160314
# Updated game file: 21500993
# Updated game file: 21500991
# Updated game file: 21500990
# Updated game file: 21500988
# Updated game file: 21500996
# Updated game file: 21500995
# Updated game file: 21500994
# Updated game file: 21500989
# Updated game file: 21500992
# Processing date: 20160315
# Successfully pulled Overall defense data for 20160315
# Successfully pulled 3PT defense data for 20160315
# Successfully pulled 2PT defense data for 20160315
# Successfully pulled <6ft defense data for 20160315
# Successfully pulled <10ft defense data for 20160315
# Successfully pulled >15ft defense data for 20160315
# Successfully pulled hustle stats for 20160315
# Successfully pulled post touch stats for 20160315
# Successfully pulled speed distance stats for 20160315
# Saved additional data for date 20160315
# Updated game file: 21501002
# Updated game file: 21500998
# Updated game file: 21500999
# Updated game file: 21500997
# Updated game file: 21501000
# Updated game file: 21501001
# Processing date: 20160316
# Successfully pulled Overall defense data for 20160316
# Successfully pulled 3PT defense data for 20160316
# Successfully pulled 2PT defense data for 20160316
# Successfully pulled <6ft defense data for 20160316
