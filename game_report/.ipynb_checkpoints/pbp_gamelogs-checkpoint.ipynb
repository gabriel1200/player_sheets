# %%
import requests
import pandas as pd
from datetime import datetime
import time
from typing import List, Dict
import logging

class PBPStatsAPI:
    def __init__(self, start_year: int = 2013, end_year: int = 2024):
        self.base_url = "https://api.pbpstats.com/get-game-logs/nba?"
        self.season_types = ["Regular Season", "Playoffs"]
        self.start_year = start_year
        self.end_year = end_year

    def get_season_years(self) -> List[str]:
        """Generate season strings from start_year to end_year."""
        return [f"{year-1}-{str(year)[2:]}" for year in range(self.start_year, self.end_year + 1)]
    
    def get_team_game_logs(self, team_id: str,entity_type: str ="Team") -> pd.DataFrame:
        """
        Fetch all game logs for a specific team within the specified year range.
        
        Args:
            team_id (str): The team ID in PBP Stats format
            
        Returns:
            pd.DataFrame: DataFrame containing all game logs
        """
        all_games = []
        seasons = self.get_season_years()
        #print(seasons)
        current_season="2024-25"
        for season in seasons:
            for season_type in self.season_types:
                if season_type !='Playoffs' or season!=current_season:
        
                    try:
                        params = {
                            "Season": season,
                            "SeasonType": season_type,
                            "EntityId": team_id,
                            "EntityType": entity_type
                        }
                        
                        response = requests.get(self.base_url, params=params)
                        data_response = response.json()
                        raw_data = data_response["multi_row_table_data"]
                        games_data = pd.DataFrame(raw_data)
                        
                        games_data['Season'] = season
                        games_data['year'] = int(season.split('-')[0]) + 1
                        games_data['SeasonType'] = season_type
                        all_games.append(games_data)
                                
                        # Respect API rate limits
                        time.sleep(3)
                        
                    except requests.exceptions.RequestException as e:
                        logging.error(f"Error fetching data for {team_id} in {season} {season_type}: {str(e)}")
                        continue
                    
        return pd.concat(all_games) if all_games else pd.DataFrame()

def fetch_all_teams_game_logs(team_ids: List[str], start_year: int, end_year: int,entity_type:str ="Team") -> Dict[str, pd.DataFrame]:
    """
    Fetch game logs for multiple teams within the specified year range.
    
    Args:
        team_ids (List[str]): List of team IDs
        start_year (int): Starting year for data collection
        end_year (int): Ending year for data collection
        
    Returns:
        Dict[str, pd.DataFrame]: Dictionary with team IDs as keys and their game logs as values
    """
    api = PBPStatsAPI(start_year=start_year, end_year=end_year)
    team_games = {}
    
    for team_id in team_ids:
        logging.info(f"Fetching game logs for team {team_id}")
        team_games[team_id] = api.get_team_game_logs(team_id,entity_type)
        
    return team_games

# Example usage
if __name__ == "__main__":
    # Example team IDs (you'll need to use the correct IDs from PBP Stats)
    start_year = 2011
    end_year =2013

    
    df = pd.read_csv('index_master.csv')
    df = df[df.year > start_year]
    df = df[df.team != 'TOT']
    team_ids = df['team_id'].unique().tolist()

    # Input start and end years

    # Configure logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    # Fetch game logs
    team_game_logs = fetch_all_teams_game_logs(team_ids, start_year, end_year)
    #frames=[]
    frames=[]
    # Example: Save to CSV files
    
    for team_id, games_df in team_game_logs.items():
        if not games_df.empty:
            for year in range(start_year, end_year + 1):
                team_df = games_df[games_df.year == year]
                
                if len(team_df)!=0:
                    team_df.to_csv(f"team/{year}/{team_id}.csv", index=False)
                    #frames.append(team_df)
            logging.info(f"Saved game logs for {team_id}")
    
    entity_type="Opponent"
    team_game_logs = fetch_all_teams_game_logs(team_ids, start_year, end_year,entity_type)
    for team_id, games_df in team_game_logs.items():
        if not games_df.empty:
            for year in range(start_year, end_year + 1):
                team_df = games_df[games_df.year == year]
                
                if len(team_df)!=0:
                    team_df.to_csv(f"team/{year}/{team_id}vs.csv", index=False)
                    #frames.append(team_df)
            logging.info(f"Saved game logs for {team_id}")
# Out:
# 2024-12-21 17:14:19,839 - INFO - Fetching game logs for team 1610612758
# 2024-12-21 17:15:02,480 - INFO - Fetching game logs for team 1610612751
# 2024-12-21 17:15:46,631 - INFO - Fetching game logs for team 1610612742
# 2024-12-21 17:16:29,991 - INFO - Fetching game logs for team 1610612757
# 2024-12-21 17:17:11,679 - INFO - Fetching game logs for team 1610612741
# 2024-12-21 17:17:53,577 - INFO - Fetching game logs for team 1610612760
# 2024-12-21 17:18:35,461 - INFO - Fetching game logs for team 1610612738
# 2024-12-21 17:19:18,280 - INFO - Fetching game logs for team 1610612745
# 2024-12-21 17:20:00,992 - INFO - Fetching game logs for team 1610612762
# 2024-12-21 17:20:44,918 - INFO - Fetching game logs for team 1610612755
# 2024-12-21 17:21:25,746 - INFO - Fetching game logs for team 1610612766
# 2024-12-21 17:22:08,295 - INFO - Fetching game logs for team 1610612743
# 2024-12-21 17:22:51,763 - INFO - Fetching game logs for team 1610612764
# 2024-12-21 17:23:34,309 - INFO - Fetching game logs for team 1610612753
# 2024-12-21 17:24:20,144 - INFO - Fetching game logs for team 1610612754
# 2024-12-21 17:25:03,940 - INFO - Fetching game logs for team 1610612740
# 2024-12-21 17:25:48,148 - INFO - Fetching game logs for team 1610612763
# 2024-12-21 17:26:29,340 - INFO - Fetching game logs for team 1610612744
# 2024-12-21 17:27:10,099 - INFO - Fetching game logs for team 1610612752
# 2024-12-21 17:27:51,125 - INFO - Fetching game logs for team 1610612756
# 2024-12-21 17:28:33,648 - INFO - Fetching game logs for team 1610612761
# 2024-12-21 17:29:15,818 - INFO - Fetching game logs for team 1610612748
# 2024-12-21 17:29:58,149 - INFO - Fetching game logs for team 1610612759
# 2024-12-21 17:30:40,971 - INFO - Fetching game logs for team 1610612737
# 2024-12-21 17:31:23,765 - INFO - Fetching game logs for team 1610612749
# 2024-12-21 17:32:05,149 - INFO - Fetching game logs for team 1610612765
# 2024-12-21 17:32:49,781 - INFO - Fetching game logs for team 1610612750
# 2024-12-21 17:33:29,841 - INFO - Fetching game logs for team 1610612746
# 2024-12-21 17:34:11,482 - INFO - Fetching game logs for team 1610612747
# 2024-12-21 17:34:55,269 - INFO - Fetching game logs for team 1610612739
# 2024-12-21 17:35:38,170 - INFO - Saved game logs for 1610612758
# 2024-12-21 17:35:38,214 - INFO - Saved game logs for 1610612751
# 2024-12-21 17:35:38,255 - INFO - Saved game logs for 1610612742
# 2024-12-21 17:35:38,295 - INFO - Saved game logs for 1610612757
# 2024-12-21 17:35:38,337 - INFO - Saved game logs for 1610612741
# 2024-12-21 17:35:38,377 - INFO - Saved game logs for 1610612760
# 2024-12-21 17:35:38,423 - INFO - Saved game logs for 1610612738
# 2024-12-21 17:35:38,464 - INFO - Saved game logs for 1610612745
# 2024-12-21 17:35:38,508 - INFO - Saved game logs for 1610612762
# 2024-12-21 17:35:38,543 - INFO - Saved game logs for 1610612755
# 2024-12-21 17:35:38,580 - INFO - Saved game logs for 1610612766
# 2024-12-21 17:35:38,614 - INFO - Saved game logs for 1610612743
# 2024-12-21 17:35:38,651 - INFO - Saved game logs for 1610612764
# 2024-12-21 17:35:38,690 - INFO - Saved game logs for 1610612753
# 2024-12-21 17:35:38,726 - INFO - Saved game logs for 1610612754
# 2024-12-21 17:35:38,766 - INFO - Saved game logs for 1610612740
# 2024-12-21 17:35:38,802 - INFO - Saved game logs for 1610612763
# 2024-12-21 17:35:38,843 - INFO - Saved game logs for 1610612744
# 2024-12-21 17:35:38,884 - INFO - Saved game logs for 1610612752
# 2024-12-21 17:35:38,929 - INFO - Saved game logs for 1610612756
# 2024-12-21 17:35:38,972 - INFO - Saved game logs for 1610612761
# 2024-12-21 17:35:39,014 - INFO - Saved game logs for 1610612748
# 2024-12-21 17:35:39,055 - INFO - Saved game logs for 1610612759
# 2024-12-21 17:35:39,094 - INFO - Saved game logs for 1610612737
# 2024-12-21 17:35:39,133 - INFO - Saved game logs for 1610612749
# 2024-12-21 17:35:39,175 - INFO - Saved game logs for 1610612765
# 2024-12-21 17:35:39,221 - INFO - Saved game logs for 1610612750
# 2024-12-21 17:35:39,270 - INFO - Saved game logs for 1610612746
# 2024-12-21 17:35:39,312 - INFO - Saved game logs for 1610612747
# 2024-12-21 17:35:39,352 - INFO - Saved game logs for 1610612739
# 2024-12-21 17:35:39,353 - INFO - Fetching game logs for team 1610612758
# 2024-12-21 17:36:22,478 - INFO - Fetching game logs for team 1610612751
# 2024-12-21 17:37:04,416 - INFO - Fetching game logs for team 1610612742
# 2024-12-21 17:37:48,092 - INFO - Fetching game logs for team 1610612757
# 2024-12-21 17:38:28,989 - INFO - Fetching game logs for team 1610612741
# 2024-12-21 17:39:14,677 - INFO - Fetching game logs for team 1610612760
# 2024-12-21 17:39:58,512 - INFO - Fetching game logs for team 1610612738
# 2024-12-21 17:40:42,316 - INFO - Fetching game logs for team 1610612745
# 2024-12-21 17:41:24,568 - INFO - Fetching game logs for team 1610612762
# 2024-12-21 17:42:08,366 - INFO - Fetching game logs for team 1610612755
# 2024-12-21 17:42:53,104 - INFO - Fetching game logs for team 1610612766
# 2024-12-21 17:43:33,710 - INFO - Fetching game logs for team 1610612743
# 2024-12-21 17:44:15,826 - INFO - Fetching game logs for team 1610612764
# 2024-12-21 17:45:02,459 - INFO - Fetching game logs for team 1610612753
# 2024-12-21 17:45:48,255 - INFO - Fetching game logs for team 1610612754
# 2024-12-21 17:46:28,125 - INFO - Fetching game logs for team 1610612740
# 2024-12-21 17:47:09,116 - INFO - Fetching game logs for team 1610612763
# 2024-12-21 17:47:55,976 - INFO - Fetching game logs for team 1610612744
# 2024-12-21 17:48:37,501 - INFO - Fetching game logs for team 1610612752
# 2024-12-21 17:49:17,643 - INFO - Fetching game logs for team 1610612756
# 2024-12-21 17:49:59,325 - INFO - Fetching game logs for team 1610612761
# 2024-12-21 17:50:41,161 - INFO - Fetching game logs for team 1610612748
# 2024-12-21 17:51:23,175 - INFO - Fetching game logs for team 1610612759
# 2024-12-21 17:52:05,561 - INFO - Fetching game logs for team 1610612737
# 2024-12-21 17:52:47,017 - INFO - Fetching game logs for team 1610612749
# 2024-12-21 17:53:28,982 - INFO - Fetching game logs for team 1610612765
# 2024-12-21 17:54:10,326 - INFO - Fetching game logs for team 1610612750
# 2024-12-21 17:54:50,375 - INFO - Fetching game logs for team 1610612746
# 2024-12-21 17:55:31,245 - INFO - Fetching game logs for team 1610612747
# 2024-12-21 17:56:13,046 - INFO - Fetching game logs for team 1610612739
# 2024-12-21 17:56:54,733 - INFO - Saved game logs for 1610612758
# 2024-12-21 17:56:54,784 - INFO - Saved game logs for 1610612751
# 2024-12-21 17:56:54,837 - INFO - Saved game logs for 1610612742
# 2024-12-21 17:56:54,884 - INFO - Saved game logs for 1610612757
# 2024-12-21 17:56:54,935 - INFO - Saved game logs for 1610612741
# 2024-12-21 17:56:54,977 - INFO - Saved game logs for 1610612760
# 2024-12-21 17:56:55,030 - INFO - Saved game logs for 1610612738
# 2024-12-21 17:56:55,074 - INFO - Saved game logs for 1610612745
# 2024-12-21 17:56:55,121 - INFO - Saved game logs for 1610612762
# 2024-12-21 17:56:55,174 - INFO - Saved game logs for 1610612755
# 2024-12-21 17:56:55,216 - INFO - Saved game logs for 1610612766
# 2024-12-21 17:56:55,265 - INFO - Saved game logs for 1610612743
# 2024-12-21 17:56:55,312 - INFO - Saved game logs for 1610612764
# 2024-12-21 17:56:55,365 - INFO - Saved game logs for 1610612753
# 2024-12-21 17:56:55,421 - INFO - Saved game logs for 1610612754
# 2024-12-21 17:56:55,481 - INFO - Saved game logs for 1610612740
# 2024-12-21 17:56:55,533 - INFO - Saved game logs for 1610612763
# 2024-12-21 17:56:55,580 - INFO - Saved game logs for 1610612744
# 2024-12-21 17:56:55,620 - INFO - Saved game logs for 1610612752
# 2024-12-21 17:56:55,666 - INFO - Saved game logs for 1610612756
# 2024-12-21 17:56:55,708 - INFO - Saved game logs for 1610612761
# 2024-12-21 17:56:55,751 - INFO - Saved game logs for 1610612748
# 2024-12-21 17:56:55,797 - INFO - Saved game logs for 1610612759
# 2024-12-21 17:56:55,840 - INFO - Saved game logs for 1610612737
# 2024-12-21 17:56:55,885 - INFO - Saved game logs for 1610612749
# 2024-12-21 17:56:55,930 - INFO - Saved game logs for 1610612765
# 2024-12-21 17:56:55,969 - INFO - Saved game logs for 1610612750
# 2024-12-21 17:56:56,012 - INFO - Saved game logs for 1610612746
# 2024-12-21 17:56:56,057 - INFO - Saved game logs for 1610612747
# 2024-12-21 17:56:56,109 - INFO - Saved game logs for 1610612739

# %%
import os

'''
for year in range(2014,2026):
    directory = "team/"+str(year)
    files = os.listdir(directory)
    files =[file for file in files if 'game_logs' not in file and '.csv' in file and 'vs' not in file]
    
    totals=[]
    for file in files:
        df=pd.read_csv(directory+'/'+file)
        totals.append(df)
    master= pd.concat(totals)

    team_dict={'OKC': '1610612760',
            'MIL': '1610612749',
            'SAC': '1610612758',
            'LAL': '1610612747',
            'BOS': '1610612738',
            'DEN': '1610612743',
            'MIN': '1610612750',
            'NYK': '1610612752',
            'PHO': '1610612756',
            'PHX': '1610612756',
            'ORL': '1610612753',
            'CHA': '1610612766',
            'CHO': '1610612766',
            'CLE': '1610612739',
            'LAC': '1610612746',
            'ATL': '1610612737',
            'MIA': '1610612748',
            'DAL': '1610612742',
            'DET': '1610612765',
            'MEM': '1610612763',
            'TOR': '1610612761',
            'CHI': '1610612741',
            'IND': '1610612754',
            'SAS': '1610612759',
            'HOU': '1610612745',
            'BRK': '1610612751',
            'BKN': '1610612751',
            'WAS': '1610612764',
            'GSW': '1610612744',
            'PHI': '1610612755',
            'UTA': '1610612762',
            'POR': '1610612757',
            'NOP': '1610612740'}
    master.dropna(subset='Opponent',inplace=True)
    for opp in master.Opponent.unique():
        teamframe=master[master.Opponent==opp].reset_index()

 
        teamframe.to_csv(directory+'/'+team_id+'vs.csv',index=False)
        print(len(teamframe))
        
    
    print(year)
'''
# Out:
# '\nfor year in range(2014,2026):\n    directory = "team/"+str(year)\n    files = os.listdir(directory)\n    files =[file for file in files if \'game_logs\' not in file and \'.csv\' in file and \'vs\' not in file]\n    \n    totals=[]\n    for file in files:\n        df=pd.read_csv(directory+\'/\'+file)\n        totals.append(df)\n    master= pd.concat(totals)\n\n    team_dict={\'OKC\': \'1610612760\',\n            \'MIL\': \'1610612749\',\n            \'SAC\': \'1610612758\',\n            \'LAL\': \'1610612747\',\n            \'BOS\': \'1610612738\',\n            \'DEN\': \'1610612743\',\n            \'MIN\': \'1610612750\',\n            \'NYK\': \'1610612752\',\n            \'PHO\': \'1610612756\',\n            \'PHX\': \'1610612756\',\n            \'ORL\': \'1610612753\',\n            \'CHA\': \'1610612766\',\n            \'CHO\': \'1610612766\',\n            \'CLE\': \'1610612739\',\n            \'LAC\': \'1610612746\',\n            \'ATL\': \'1610612737\',\n            \'MIA\': \'1610612748\',\n            \'DAL\': \'1610612742\',\n            \'DET\': \'1610612765\',\n            \'MEM\': \'1610612763\',\n            \'TOR\': \'1610612761\',\n            \'CHI\': \'1610612741\',\n            \'IND\': \'1610612754\',\n            \'SAS\': \'1610612759\',\n            \'HOU\': \'1610612745\',\n            \'BRK\': \'1610612751\',\n            \'BKN\': \'1610612751\',\n            \'WAS\': \'1610612764\',\n            \'GSW\': \'1610612744\',\n            \'PHI\': \'1610612755\',\n            \'UTA\': \'1610612762\',\n            \'POR\': \'1610612757\',\n            \'NOP\': \'1610612740\'}\n    master.dropna(subset=\'Opponent\',inplace=True)\n    for opp in master.Opponent.unique():\n        teamframe=master[master.Opponent==opp].reset_index()\n\n \n        teamframe.to_csv(directory+\'/\'+team_id+\'vs.csv\',index=False)\n        print(len(teamframe))\n        \n    \n    print(year)\n'
