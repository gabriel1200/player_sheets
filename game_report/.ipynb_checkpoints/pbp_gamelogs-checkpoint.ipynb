# %%
import requests
import pandas as pd
from datetime import datetime
import time
from typing import List, Dict
import logging

class PBPStatsAPI:
    def __init__(self):
        self.base_url = "https://api.pbpstats.com/get-game-logs/nba?"
        self.season_types = ["Regular Season", "Playoffs"]
        
    def get_season_years(self, start_year: int = 2013) -> List[str]:
        """Generate season strings from start_year to current year."""
        current_year = 2024
        return [f"{year}-{str(year + 1)[2:]}" for year in range(start_year, current_year+1)]
    
    def get_team_game_logs(self, team_id: str, start_year: int = 2013) -> pd.DataFrame:
        """
        Fetch all game logs for a specific team since start_year.
        
        Args:
            team_id (str): The team ID in PBP Stats format
            start_year (int): Starting year (default: 2001)
            
        Returns:
            pd.DataFrame: DataFrame containing all game logs
        """
        all_games = []
        seasons = self.get_season_years(start_year)
        
        for season in seasons:
            for season_type in self.season_types:
                if season_type!='Playoffs':
                    try:
                        params = {
                            "Season": season,
                            "SeasonType": season_type,
                            "EntityId": team_id,
                            "EntityType": "Team"
                        }
                        
                        response = requests.get(self.base_url, params=params)
             
                        
                        data_response = response.json()
                            
                        raw_data= data_response["multi_row_table_data"]
                        games_data=pd.DataFrame(raw_data)
         
                        games_data['Season'] = season
                        games_data['year']=int(season.split('-')[0])+1
                        games_data['SeasonType'] = season_type
                        all_games.append(games_data)
                                
                        # Respect API rate limits
                        time.sleep(2)
                        
                    except requests.exceptions.RequestException as e:
                        logging.error(f"Error fetching data for {team_id} in {season} {season_type}: {str(e)}")
                        continue
                    
        return pd.concat(all_games) if all_games else pd.DataFrame()

def fetch_all_teams_game_logs(team_ids: List[str], start_year: int = 2013) -> Dict[str, pd.DataFrame]:
    """
    Fetch game logs for multiple teams.
    
    Args:
        team_ids (List[str]): List of team IDs
        start_year (int): Starting year for data collection
        
    Returns:
        Dict[str, pd.DataFrame]: Dictionary with team IDs as keys and their game logs as values
    """
    api = PBPStatsAPI()
    team_games = {}
    
    for team_id in team_ids:
        logging.info(f"Fetching game logs for team {team_id}")
        team_games[team_id] = api.get_team_game_logs(team_id, start_year)
        
    return team_games

# Example usage
if __name__ == "__main__":
    # Example team IDs (you'll need to use the correct IDs from PBP Stats)
    team_ids = ["LAL", "BOS", "GSW"]  # Replace with actual team IDs
    df =pd.read_csv('index_master.csv')
    df=df[df.year>2013]
    df=df[df.team!='TOT']
    team_ids=df['team_id'].unique().tolist()

    # Configure logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    # Fetch game logs
    team_game_logs = fetch_all_teams_game_logs(team_ids,start_year=2024)
    
    # Example: Save to CSV files
    for team_id, games_df in team_game_logs.items():
        
        if not games_df.empty:
            for year in range(2024,2026):
                team_df=games_df[games_df.year==year]
                team_df.to_csv(f"team/{year}/{team_id}.csv", index=False)
            logging.info(f"Saved game logs for {team_id}")
# Out:
# 2024-10-28 02:22:54,956 - INFO - Fetching game logs for team 1610612761
# 2024-10-28 02:22:54,957 - INFO - Fetching game logs for team 1610612758
# 2024-10-28 02:22:54,958 - INFO - Fetching game logs for team 1610612760
# 2024-10-28 02:22:54,960 - INFO - Fetching game logs for team 1610612766
# 2024-10-28 02:22:54,962 - INFO - Fetching game logs for team 1610612749
# 2024-10-28 02:22:54,963 - INFO - Fetching game logs for team 1610612753
# 2024-10-28 02:22:54,964 - INFO - Fetching game logs for team 1610612740
# 2024-10-28 02:22:54,966 - INFO - Fetching game logs for team 1610612752
# 2024-10-28 02:22:54,967 - INFO - Fetching game logs for team 1610612757
# 2024-10-28 02:22:54,970 - INFO - Fetching game logs for team 1610612755
# 2024-10-28 02:22:54,971 - INFO - Fetching game logs for team 1610612754
# 2024-10-28 02:22:54,972 - INFO - Fetching game logs for team 1610612748
# 2024-10-28 02:22:54,973 - INFO - Fetching game logs for team 1610612763
# 2024-10-28 02:22:54,975 - INFO - Fetching game logs for team 1610612741
# 2024-10-28 02:22:54,976 - INFO - Fetching game logs for team 1610612751
# 2024-10-28 02:22:54,977 - INFO - Fetching game logs for team 1610612738
# 2024-10-28 02:22:54,979 - INFO - Fetching game logs for team 1610612737
# 2024-10-28 02:22:54,980 - INFO - Fetching game logs for team 1610612764
# 2024-10-28 02:22:54,981 - INFO - Fetching game logs for team 1610612744
# 2024-10-28 02:22:54,982 - INFO - Fetching game logs for team 1610612743
# 2024-10-28 02:22:54,982 - INFO - Fetching game logs for team 1610612745
# 2024-10-28 02:22:54,984 - INFO - Fetching game logs for team 1610612759
# 2024-10-28 02:22:54,985 - INFO - Fetching game logs for team 1610612756
# 2024-10-28 02:22:54,986 - INFO - Fetching game logs for team 1610612750
# 2024-10-28 02:22:54,987 - INFO - Fetching game logs for team 1610612746
# 2024-10-28 02:22:54,990 - INFO - Fetching game logs for team 1610612747
# 2024-10-28 02:22:54,991 - INFO - Fetching game logs for team 1610612739
# 2024-10-28 02:22:54,992 - INFO - Fetching game logs for team 1610612762
# 2024-10-28 02:22:54,994 - INFO - Fetching game logs for team 1610612765
# 2024-10-28 02:22:54,995 - INFO - Fetching game logs for team 1610612742

# %%
team_game_logs
# Out:
# {'1610612761': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612758': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612760': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612766': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612749': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612753': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612740': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612752': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612757': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612755': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612754': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612748': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612763': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612741': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612751': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612738': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612737': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612764': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612744': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612743': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612745': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612759': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612756': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612750': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612746': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612747': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612739': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612762': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612765': Empty DataFrame
#  Columns: []
#  Index: [],
#  '1610612742': Empty DataFrame
#  Columns: []
#  Index: []}
