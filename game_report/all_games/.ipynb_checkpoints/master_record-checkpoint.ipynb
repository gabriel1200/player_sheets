# %%
import os
import pandas as pd

# Define the directory containing the CSV files
csv_dir = '.'  # or provide a full path like '/Users/yourname/data/'

# Get all CSV file names in the directory
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Initialize a list to hold DataFrames
dfs = []

# Loop through and read each file
for filename in csv_files:
    file_path = os.path.join(csv_dir, filename)
    try:
        df = pd.read_csv(file_path)
        dfs.append(df)
    except Exception as e:
        print(f"Could not read {filename}: {e}")

# Concatenate all DataFrames into one

combined_df = pd.concat(dfs, ignore_index=True)
combined_df.sort_values(by='date',inplace=True)
print(combined_df)
# Out:
# /tmp/ipykernel_194457/2185053630.py:17: DtypeWarning: Columns (381,395,414) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#         PLAYER_ID        PLAYER_NAME   NICKNAME       TEAM_ID  \
# 0          201143         Al Horford         Al  1.610613e+09
# 1          101161       Amir Johnson       Amir  1.610613e+09
# 2         1626171       Bobby Portis      Bobby  1.610613e+09
# 3         1626245  Cristiano Felicio  Cristiano  1.610613e+09
# 4         1627756   Denzel Valentine     Denzel  1.610613e+09
# ...           ...                ...        ...           ...
# 982045     201564          O.J. Mayo       O.J.  1.610613e+09
# 982046     200782        P.J. Tucker       P.J.  1.610613e+09
# 982047       2585      Zaza Pachulia       Zaza  1.610613e+09
# 982048     201609       Goran Dragic      Goran  1.610613e+09
# 982049     202738      Isaiah Thomas     Isaiah  1.610613e+09
#
#        TEAM_ABBREVIATION   AGE   GP    W    L  W_PCT  ...  DIST_MILES_DEF  \
# 0                    BOS  31.0  1.0  0.0  1.0    0.0  ...             NaN
# 1                    BOS  30.0  1.0  0.0  1.0    0.0  ...             NaN
# 2                    CHI  22.0  1.0  1.0  0.0    1.0  ...             NaN
# 3                    CHI  24.0  1.0  1.0  0.0    1.0  ...             NaN
# 4                    CHI  23.0  1.0  1.0  0.0    1.0  ...             NaN
# ...                  ...   ...  ...  ...  ...    ...  ...             ...
# 982045               MIL  27.0  1.0  0.0  1.0    0.0  ...             NaN
# 982046               PHX  30.0  1.0  1.0  0.0    1.0  ...             NaN
# 982047               MIL  31.0  1.0  0.0  1.0    0.0  ...             NaN
# 982048               PHX  29.0  1.0  1.0  0.0    1.0  ...             NaN
# 982049               PHX  26.0  1.0  1.0  0.0    1.0  ...             NaN
#
#         DIST_MILES_OFF  AVG_SPEED  MIN1  AVG_SPEED_OFF  PLAYER_LAST_TEAM_ID  \
# 0                  NaN        NaN   NaN            NaN                  NaN
# 1                  NaN        NaN   NaN            NaN                  NaN
# 2                  NaN        NaN   NaN            NaN                  NaN
# 3                  NaN        NaN   NaN            NaN                  NaN
# 4                  NaN        NaN   NaN            NaN                  NaN
# ...                ...        ...   ...            ...                  ...
# 982045             NaN        NaN   NaN            NaN                  NaN
# 982046             NaN        NaN   NaN            NaN                  NaN
# 982047             NaN        NaN   NaN            NaN                  NaN
# 982048             NaN        NaN   NaN            NaN                  NaN
# 982049             NaN        NaN   NaN            NaN                  NaN
#
#         more_15ft_def_TEAM_ID  hustle_TEAM_ID  post_touch_TEAM_ID  Unnamed: 0
# 0                         NaN             NaN                 NaN         NaN
# 1                         NaN             NaN                 NaN         NaN
# 2                         NaN             NaN                 NaN         NaN
# 3                         NaN             NaN                 NaN         NaN
# 4                         NaN             NaN                 NaN         NaN
# ...                       ...             ...                 ...         ...
# 982045                    NaN             NaN                 NaN         NaN
# 982046                    NaN             NaN                 NaN         NaN
# 982047                    NaN             NaN                 NaN         NaN
# 982048                    NaN             NaN                 NaN         NaN
# 982049                    NaN             NaN                 NaN         NaN
#
# [982050 rows x 465 columns]

# %%
for col in combined_df.columns:
    if 'opp' in col.lower():
        print(col)
# Out:
# opp_team
# opp_id

# %%
index_col=['PLAYER_ID', 'PLAYER_NAME','TEAM_ABBREVIATION','TEAM_ID','GAME_ID']

game_record=combined_df[index_col]
game_record.drop_duplicates(inplace=True)
game_record.to_csv('master_record.csv',index=False)
# Out:
#         PLAYER_ID        PLAYER_NAME TEAM_ABBREVIATION       TEAM_ID  \
# 0          201143         Al Horford               BOS  1.610613e+09
# 1          101161       Amir Johnson               BOS  1.610613e+09
# 2         1626171       Bobby Portis               CHI  1.610613e+09
# 3         1626245  Cristiano Felicio               CHI  1.610613e+09
# 4         1627756   Denzel Valentine               CHI  1.610613e+09
# ...           ...                ...               ...           ...
# 654695     201564          O.J. Mayo               MIL  1.610613e+09
# 654696     200782        P.J. Tucker               PHX  1.610613e+09
# 654697       2585      Zaza Pachulia               MIL  1.610613e+09
# 654698     201609       Goran Dragic               PHX  1.610613e+09
# 654699     202738      Isaiah Thomas               PHX  1.610613e+09
#
#            GAME_ID
# 0       21600849.0
# 1       21600849.0
# 2       21600849.0
# 3       21600849.0
# 4       21600849.0
# ...            ...
# 654695  21400520.0
# 654696  21400520.0
# 654697  21400520.0
# 654698  21400520.0
# 654699  21400520.0
#
# [331399 rows x 5 columns]
