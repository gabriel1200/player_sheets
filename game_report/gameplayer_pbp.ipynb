# %%
import requests
import pandas as pd
import logging
import time

def fetch_player_game_logs(player_ids):
    """Fetches player game logs for the current NBA season using NBA ID."""
    base_url = "https://api.pbpstats.com/get-game-logs/nba?"
    current_season = "2024-25"
    season_type = "Regular Season"
    all_games = []
    count=0
    for player_id in player_ids:
        try:
            params = {"Season": current_season, "SeasonType": season_type, "EntityId": player_id, "EntityType": "Player"}
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json().get("multi_row_table_data", [])
            
            if data:
                count +=1
                df = pd.DataFrame(data)
                df['Season'] = current_season
                all_games.append(df)
                if count %10 ==0:
                    print(count)
            
            time.sleep(1)  # Avoid rate limits
        except requests.exceptions.RequestException as e:
            logging.error(f"Error fetching data for player {player_id}: {e}")
            continue
    
    return pd.concat(all_games, ignore_index=True) if all_games else pd.DataFrame()

if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    
    df = pd.read_csv('index_master.csv')
    player_ids = df.loc[(df.year == 2025) & df.nba_id.notna(), 'nba_id'].unique().tolist()
    player_ids=[int(player_id) for player_id in player_ids]
    
    game_logs = fetch_player_game_logs(player_ids)
    print(game_logs)
# Out:
# 10
# 2025-03-11 16:01:37,697 - ERROR - Error fetching data for player 1626157: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1626157&EntityType=Player
# 2025-03-11 16:01:37,895 - ERROR - Error fetching data for player 202681: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=202681&EntityType=Player
# 2025-03-11 16:01:38,136 - ERROR - Error fetching data for player 1626164: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1626164&EntityType=Player
# 2025-03-11 16:01:38,359 - ERROR - Error fetching data for player 2544: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=2544&EntityType=Player
# 2025-03-11 16:01:38,592 - ERROR - Error fetching data for player 202696: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=202696&EntityType=Player
# 2025-03-11 16:01:38,798 - ERROR - Error fetching data for player 1629639: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629639&EntityType=Player
# 2025-03-11 16:01:38,991 - ERROR - Error fetching data for player 203999: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=203999&EntityType=Player
# 2025-03-11 16:01:39,197 - ERROR - Error fetching data for player 1629027: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629027&EntityType=Player
# 2025-03-11 16:01:42,388 - ERROR - Error fetching data for player 1631114: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1631114&EntityType=Player
# 2025-03-11 16:01:42,572 - ERROR - Error fetching data for player 1629029: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629029&EntityType=Player
# 2025-03-11 16:01:42,766 - ERROR - Error fetching data for player 1629628: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629628&EntityType=Player
# 2025-03-11 16:01:42,960 - ERROR - Error fetching data for player 1628991: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1628991&EntityType=Player
# 2025-03-11 16:01:43,151 - ERROR - Error fetching data for player 1630595: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630595&EntityType=Player
# 2025-03-11 16:01:43,353 - ERROR - Error fetching data for player 1630552: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630552&EntityType=Player
# 2025-03-11 16:01:43,565 - ERROR - Error fetching data for player 203944: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=203944&EntityType=Player
# 2025-03-11 16:01:43,765 - ERROR - Error fetching data for player 1630560: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630560&EntityType=Player

# %%
game_logs
# Out:
#      Season
# 0   2024-25
# 1   2024-25
# 2   2024-25
# 3   2024-25
# 4   2024-25
# 5   2024-25
# 6   2024-25
# 7   2024-25
# 8   2024-25
# 9   2024-25
# 10  2024-25
# 11  2024-25
# 12  2024-25
# 13  2024-25
# 14  2024-25
# 15  2024-25
# 16  2024-25
# 17  2024-25
# 18  2024-25
# 19  2024-25
# 20  2024-25
# 21  2024-25
# 22  2024-25
# 23  2024-25
# 24  2024-25
# 25  2024-25
# 26  2024-25
# 27  2024-25
# 28  2024-25
# 29  2024-25
