# %%
import requests
import pandas as pd
import logging
import time

def fetch_player_game_logs(player_ids):
    """Fetches player game logs for the current NBA season using NBA ID."""
    base_url = "https://api.pbpstats.com/get-game-logs/nba?"
    current_season = "2024-25"
    season_type = "Regular Season"
    all_games = []
    count=0
    for player_id in player_ids:
        try:
            params = {"Season": current_season, "SeasonType": season_type, "EntityId": player_id, "EntityType": "Player"}
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json().get("multi_row_table_data", [])
            
            if data:
                count +=1
                df = pd.DataFrame(data)
                df['Season'] = current_season
                all_games.append(df)
                if count %10 ==0:
                    print(count)
            
            time.sleep(1)  # Avoid rate limits
        except requests.exceptions.RequestException as e:
            logging.error(f"Error fetching data for player {player_id}: {e}")
            continue
    
    return pd.concat(all_games, ignore_index=True) if all_games else pd.DataFrame()

if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    
    df = pd.read_csv('index_master.csv')
    player_ids = df.loc[(df.year == 2025) & df.nba_id.notna(), 'nba_id'].unique().tolist()
    player_ids=[int(player_id) for player_id in player_ids]
    
    game_logs = fetch_player_game_logs(player_ids)
    print(game_logs)
# Out:
# 2025-03-11 16:00:33,476 - ERROR - Error fetching data for player 1630532.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630532.0&EntityType=Player
# 2025-03-11 16:00:33,692 - ERROR - Error fetching data for player 1628973.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1628973.0&EntityType=Player
# 2025-03-11 16:00:35,154 - ERROR - Error fetching data for player 201935.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=201935.0&EntityType=Player
# 2025-03-11 16:00:35,395 - ERROR - Error fetching data for player 1626157.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1626157.0&EntityType=Player
# 2025-03-11 16:00:35,617 - ERROR - Error fetching data for player 202681.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=202681.0&EntityType=Player
# 2025-03-11 16:00:35,811 - ERROR - Error fetching data for player 1626164.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1626164.0&EntityType=Player
# 2025-03-11 16:00:35,997 - ERROR - Error fetching data for player 2544.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=2544.0&EntityType=Player
# 2025-03-11 16:00:36,195 - ERROR - Error fetching data for player 202696.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=202696.0&EntityType=Player
# 2025-03-11 16:00:36,409 - ERROR - Error fetching data for player 1629639.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629639.0&EntityType=Player
# 2025-03-11 16:00:36,606 - ERROR - Error fetching data for player 203999.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=203999.0&EntityType=Player
# 2025-03-11 16:00:36,798 - ERROR - Error fetching data for player 1629027.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629027.0&EntityType=Player
# 2025-03-11 16:00:36,988 - ERROR - Error fetching data for player 1627783.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1627783.0&EntityType=Player
# 2025-03-11 16:00:37,173 - ERROR - Error fetching data for player 1631114.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1631114.0&EntityType=Player
# 2025-03-11 16:00:37,369 - ERROR - Error fetching data for player 1629029.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629029.0&EntityType=Player
# 2025-03-11 16:00:37,566 - ERROR - Error fetching data for player 1629628.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1629628.0&EntityType=Player
# 2025-03-11 16:00:37,799 - ERROR - Error fetching data for player 1628991.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1628991.0&EntityType=Player
# 2025-03-11 16:00:38,004 - ERROR - Error fetching data for player 1630595.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630595.0&EntityType=Player
# 2025-03-11 16:00:38,196 - ERROR - Error fetching data for player 1630552.0: 503 Server Error: Service Temporarily Unavailable for url: https://api.pbpstats.com/get-game-logs/nba?Season=2024-25&SeasonType=Regular+Season&EntityId=1630552.0&EntityType=Player

# %%
game_logs
# Out:
#      Season
# 0   2024-25
# 1   2024-25
# 2   2024-25
# 3   2024-25
# 4   2024-25
# 5   2024-25
# 6   2024-25
# 7   2024-25
# 8   2024-25
# 9   2024-25
# 10  2024-25
# 11  2024-25
# 12  2024-25
# 13  2024-25
# 14  2024-25
# 15  2024-25
# 16  2024-25
# 17  2024-25
# 18  2024-25
# 19  2024-25
# 20  2024-25
# 21  2024-25
# 22  2024-25
# 23  2024-25
# 24  2024-25
# 25  2024-25
# 26  2024-25
# 27  2024-25
# 28  2024-25
# 29  2024-25
