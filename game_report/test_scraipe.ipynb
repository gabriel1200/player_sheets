# %%
import pandas as pd

df2=pd.read_csv('2014/41300311_updated.csv')
df3=pd.read_csv('2014/41300311.csv')

set(df2.columns)-set(df3.columns)
# Out:
# {'less_10ft_def_AGE',
#  'less_10ft_def_FGA_LT_10',
#  'less_10ft_def_FGM_LT_10',
#  'less_10ft_def_FREQ',
#  'less_10ft_def_G',
#  'less_10ft_def_GP',
#  'less_10ft_def_LT_10_PCT',
#  'less_10ft_def_NS_LT_10_PCT',
#  'less_10ft_def_PLAYER_LAST_TEAM_ABBREVIATION',
#  'less_10ft_def_PLAYER_LAST_TEAM_ID',
#  'less_10ft_def_PLAYER_NAME',
#  'less_10ft_def_PLAYER_POSITION',
#  'less_10ft_def_PLUSMINUS',
#  'less_6ft_def_AGE',
#  'less_6ft_def_FGA_LT_06',
#  'less_6ft_def_FGM_LT_06',
#  'less_6ft_def_FREQ',
#  'less_6ft_def_G',
#  'less_6ft_def_GP',
#  'less_6ft_def_LT_06_PCT',
#  'less_6ft_def_NS_LT_06_PCT',
#  'less_6ft_def_PLAYER_LAST_TEAM_ABBREVIATION',
#  'less_6ft_def_PLAYER_LAST_TEAM_ID',
#  'less_6ft_def_PLAYER_NAME',
#  'less_6ft_def_PLAYER_POSITION',
#  'less_6ft_def_PLUSMINUS',
#  'more_15ft_def_AGE',
#  'more_15ft_def_FGA_GT_15',
#  'more_15ft_def_FGM_GT_15',
#  'more_15ft_def_FREQ',
#  'more_15ft_def_G',
#  'more_15ft_def_GP',
#  'more_15ft_def_GT_15_PCT',
# ...
