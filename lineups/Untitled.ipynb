# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/year_totals/2025.csv')
df.sort_values(by='NET_RATING',inplace=True)
df=df[df.GP>=10]
print(df.columns)
# Out:
# Index(['PLAYER_ID', 'PLAYER_NAME', 'W', 'GP', 'year', 'POSS',
#        'TEAM_ABBREVIATION', 'TEAM_ID', 'AGE', 'PF',
#        ...
#        'PAINT_TOUCHES', 'HeaveMakes', 'LongMidRangeFGA', 'open_FGA_FREQUENCY',
#        'BadPassTurnovers', 'RIGHT_CORNER_3_FGM', 'LEFT_CORNER_3_FG_PCT',
#        'very_tight_FG2_PCT', 'BACKCOURT_FGM', 'AtRimOffReboundedPct'],
#       dtype='object', length=498)

# %%
for col in df.columns:
    print(col)
# Out:
# PLAYER_ID
# PLAYER_NAME
# W
# GP
# year
# POSS
# TEAM_ABBREVIATION
# TEAM_ID
# AGE
# PF
# OREB_CHANCE_PCT_ADJ
# FTM
# PenaltyTurnovers
# DefRebounds
# Loose Ball Fouls Drawn
# RA_FG_PCT
# OffShortMidRangeReboundPct
# DeadBallTurnovers
# PenaltyFG3A
# REB_CHANCES
# AVG_OREB_DIST
# 2pt And 1 Free Throw Trips
# Steals
# FGM_35_39
# wide_open_FG3A
# FGP_25_29
# PenaltyAtRimFrequency
# tight_FGA_FREQUENCY
# PenaltyArc3FGM
# PenaltyShotQualityAvg
# CATCH_SHOOT_FGA
# AtRimFrequency
# AST_RATIO
# NET_RATING
# BlockedArc3
# BlockedShortMidRange
# open_FG_PCT
# AssistPoints
# DREB_CHANCE_PCT_ADJ
# RIGHT_CORNER_3_FG_PCT
# NonShootingFoulsDrawn
# Fg3Pct
# PULL_UP_FGM
# PenaltyCorner3FGA
# Arc3PctAssisted
# Defensive 3 Seconds Violations
# PULL_UP_FG3M
# ShootingFouls
# FirstChancePoints
# FG2APctBlocked
# OffLongMidRangeReboundPct
# CORNER_3_FG_PCT
# PFD
# very_tight_FG2A_FREQUENCY
# open_FGA
# Fg3aBlocked
# ShortMidRangeFrequency
# E_DEF_RATING
# OffTwoPtRebounds
# TwoPtAssists
# FTOffRebounds
# ...
