# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/year_totals/2025.csv')
df.sort_values(by='NET_RATING',inplace=True)
df=df[df.GP>=10]
df[['PLAYER_NAME','NET_RATING']].tail(40)
# Out:
#                  PLAYER_NAME  NET_RATING
# 162    Sandro Mamukelashvili         9.8
# 285              Sam Merrill         9.8
# 389            Cason Wallace         9.9
# 150               Kevin Love         9.9
# 360             Jake LaRavia        10.1
# 237       Wendell Carter Jr.        10.3
# 304            Miles McBride        10.3
# 396        Jaren Jackson Jr.        10.5
# 330            Aaron Wiggins        10.6
# 448           Alperen Sengun        10.9
# 332            Georges Niang        11.0
# 314             Goga Bitadze        11.5
# 239              Gary Harris        11.5
# 234             Luke Kennard        11.5
# 307               Sam Hauser        11.6
# 414             Nikola Jokić        11.6
# 446            Dillon Brooks        11.9
# 348            Stephen Curry        12.2
# 257                Dean Wade        12.4
# 298         Dereck Lively II        12.6
# 471            Derrick White        12.7
# 421            Luguentz Dort        12.7
# 268            Neemias Queta        13.1
# 481             Jayson Tatum        13.4
# 424             Jaylen Brown        13.8
# 273                Ja Morant        13.9
# 439              Evan Mobley        13.9
# 306           Quentin Grimes        14.5
# 188               Alec Burks        14.7
# 472  Shai Gilgeous-Alexander        15.5
# 315               Isaiah Joe        15.7
# 95              Jevon Carter        16.2
# 290           Brandon Clarke        16.2
# 229            Chet Holmgren        16.6
# 293             Caris LeVert        17.2
# 129            Aaron Holiday        22.2
# 80          MarJon Beauchamp        22.2
# 77               Tyler Smith        22.2
# 97       Patrick Baldwin Jr.        22.6
# 111             Ryan Rollins        26.3
