# %%
import requests
import pandas as pd
import time

# Define the base URL for the SWAR API
def scrape_teams(ps=False):
    base_url = "https://api.pbpstats.com/get-totals/nba"
    stype="Regular Season"
    carry=""
    if ps == True:
        stype="Playoffs"
        carry="ps"
    
    # Set up parameters
    params = {
        "SeasonType": stype,
        "Season": "",  # This will be dynamically filled for each season
        "Type": "Team",
    }
    
    # Define the range of seasons you want data for
    start_season = 2024  # Example start season
    end_season = 2024  # Example end season
    
    # Empty list to collect all data
    all_data = []
    
    # Loop through each season to fetch possessions data
    for season in range(start_season, end_season + 1):
        params["Season"] = f"{season}-{str(season + 1)[-2:]}"
        
        
        # Make a request to the API
        response = requests.get(base_url, params=params)
        data = response.json()
        
        # Process each team in the season
        df=pd.DataFrame(data['multi_row_table_data'])
        df['season']=season
        df['year']=season+1
        print(season+1)
        time.sleep(2)
        all_data.append(df)
    
    # Convert collected data into a DataFrame
    df = pd.concat(all_data)

    for team_id in df['TeamId'].unique().tolist():
        teamdf=df[df['TeamId']==team_id]
        olddf=pd.read_csv(team_id+carry+'.csv')

        new_years = teamdf['year'].unique().tolist()
        olddf=olddf[~olddf.year.isin(new_years)]
        teamdf=pd.concat([olddf,teamdf])
        teamdf.to_csv(team_id+carry+".csv",index=False)

# Display a sample of the data
scrape_teams(ps=False)
# Out:
# 2025
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 0  1610612750  1610612750  MIN       MIN  1610612750              MIN
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 0        25920.0            9         55      882  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 0                         NaN                     NaN             NaN
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 0          NaN                    NaN                 NaN         NaN    2024
#
#    year
# 0  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 1  1610612747  1610612747  LAL       LAL  1610612747              LAL
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 1        25920.0            9        -23      897  ...               1.0
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 1                         1.0                0.018868        0.004149
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 1          NaN                    NaN                 NaN         NaN    2024
#
#    year
# 1  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 2  1610612748  1610612748  MIA       MIA  1610612748              MIA
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 2        23040.0            8         -9      773  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 2                         2.0                     NaN        0.004717
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 2          1.0                    NaN                 NaN         NaN    2024
#
#    year
# 2  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 3  1610612744  1610612744  GSW       GSW  1610612744              GSW
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 3        26220.0            9        107      911  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 3                         1.0                0.044444        0.014706
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 3          7.0                    NaN                 NaN         NaN    2024
#
#    year
# 3  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 4  1610612763  1610612763  MEM       MEM  1610612763              MEM
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 4        28800.0           10         58     1017  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 4                         NaN                 0.02439             NaN
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 4          1.0                    1.0                 1.0         NaN    2024
#
#    year
# 4  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 5  1610612754  1610612754  IND       IND  1610612754              IND
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 5        26520.0            9        -37      905  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 5                         NaN                     NaN        0.009709
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 5          2.0                    NaN                 NaN         NaN    2024
#
#    year
# 5  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 6  1610612757  1610612757  POR       POR  1610612757              POR
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 6        28800.0           10        -76      983  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 6                         2.0                     NaN        0.004444
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 6          6.0                    NaN                 NaN         NaN    2024
#
#    year
# 6  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 7  1610612737  1610612737  ATL       ATL  1610612737              ATL
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 7        28800.0           10        -49     1021  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 7                         NaN                     NaN             NaN
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 7          2.0                    1.0                 1.0         NaN    2024
#
#    year
# 7  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 8  1610612761  1610612761  TOR       TOR  1610612761              TOR
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 8        26520.0            9        -60      923  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 8                         NaN                0.023256        0.013699
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 8          3.0                    NaN                 NaN         NaN    2024
#
#    year
# 8  2025
#
# [1 rows x 237 columns]
#      EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 9  1610612746  1610612746  LAC       LAC  1610612746              LAC
#
#    SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 9        26220.0            9         20      880  ...               NaN
#
#    3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 9                         3.0                0.028986        0.008658
#
#    BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  season  \
# 9          3.0                    1.0                 NaN         NaN    2024
#
#    year
# 9  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 10  1610612766  1610612766  CHA       CHA  1610612766              CHA
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 10        25920.0            9        -28      877  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 10                         1.0                0.022727        0.006369
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 10          2.0                    1.0                 1.0         NaN
#
#     season  year
# 10    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 11  1610612765  1610612765  DET       DET  1610612765              DET
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 11        28800.0           10        -26      972  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 11                         NaN                     NaN             NaN
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 11          2.0                    NaN                 NaN         NaN
#
#     season  year
# 11    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 12  1610612749  1610612749  MIL       MIL  1610612749              MIL
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 12        25920.0            9        -45      890  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 12                         1.0                     NaN        0.019841
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 12          1.0                    NaN                 1.0         1.0
#
#     season  year
# 12    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 13  1610612755  1610612755  PHI       PHI  1610612755              PHI
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 13        23340.0            8        -70      784  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 13                         NaN                0.019608        0.012821
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 13          1.0                    NaN                 NaN         NaN
#
#     season  year
# 13    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 14  1610612751  1610612751  BKN       BKN  1610612751              BKN
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 14        26520.0            9         -6      887  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 14                         NaN                0.022222        0.003846
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 14          1.0                    NaN                 NaN         NaN
#
#     season  year
# 14    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 15  1610612739  1610612739  CLE       CLE  1610612739              CLE
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 15        28800.0           10        133     1006  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 15                         NaN                0.015385        0.019157
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 15          1.0                    1.0                 NaN         NaN
#
#     season  year
# 15    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 16  1610612762  1610612762  UTA       UTA  1610612762              UTA
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 16        23040.0            8       -126      801  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 16                         NaN                0.023256        0.013514
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 16          1.0                    NaN                 1.0         NaN
#
#     season  year
# 16    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 17  1610612756  1610612756  PHX       PHX  1610612756              PHX
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 17        26220.0            9         30      893  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 17                         1.0                0.057143        0.007605
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 17          NaN                    1.0                 NaN         NaN
#
#     season  year
# 17    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 18  1610612745  1610612745  HOU       HOU  1610612745              HOU
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 18        26220.0            9         37      885  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 18                         NaN                0.027397        0.007491
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 18          1.0                    2.0                 1.0         NaN
#
#     season  year
# 18    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 19  1610612753  1610612753  ORL       ORL  1610612753              ORL
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 19        28800.0           10         -8      989  ...               1.0
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 19                         NaN                     NaN        0.003937
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 19          1.0                    NaN                 2.0         NaN
#
#     season  year
# 19    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 20  1610612740  1610612740  NOP       NOP  1610612740              NOP
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 20        28800.0           10       -103      973  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 20                         1.0                0.036364        0.023622
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 20          4.0                    NaN                 1.0         NaN
#
#     season  year
# 20    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 21  1610612738  1610612738  BOS       BOS  1610612738              BOS
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 21        29400.0           10        110      998  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 21                         NaN                     NaN        0.007371
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 21          5.0                    1.0                 NaN         NaN
#
#     season  year
# 21    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 22  1610612742  1610612742  DAL       DAL  1610612742              DAL
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 22        25920.0            9         42      893  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 22                         NaN                     NaN           0.004
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 22          2.0                    NaN                 NaN         NaN
#
#     season  year
# 22    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 23  1610612759  1610612759  SAS       SAS  1610612759              SAS
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 23        25920.0            9        -20      866  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 23                         1.0                     NaN        0.003984
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 23          3.0                    NaN                 NaN         NaN
#
#     season  year
# 23    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 24  1610612752  1610612752  NYK       NYK  1610612752              NYK
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 24        23040.0            8         40      755  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 24                         1.0                    0.02         0.00995
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 24          NaN                    1.0                 NaN         NaN
#
#     season  year
# 24    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 25  1610612758  1610612758  SAC       SAC  1610612758              SAC
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 25        26220.0            9         36      899  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 25                         1.0                0.017241             NaN
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 25          3.0                    1.0                 NaN         NaN
#
#     season  year
# 25    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 26  1610612741  1610612741  CHI       CHI  1610612741              CHI
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 26        25920.0            9        -67      933  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 26                         NaN                     NaN        0.007067
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 26          1.0                    NaN                 NaN         NaN
#
#     season  year
# 26    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 27  1610612743  1610612743  DEN       DEN  1610612743              DEN
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 27        26520.0            9         27      917  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 27                         NaN                     NaN        0.004255
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 27          1.0                    NaN                 1.0         NaN
#
#     season  year
# 27    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 28  1610612760  1610612760  OKC       OKC  1610612760              OKC
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 28        25920.0            9        139      923  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 28                         NaN                0.039216        0.010753
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 28          1.0                    NaN                 NaN         NaN
#
#     season  year
# 28    2024  2025
#
# [1 rows x 237 columns]
#       EntityId      TeamId Name ShortName       RowId TeamAbbreviation  \
# 29  1610612764  1610612764  WAS       WAS  1610612764              WAS
#
#     SecondsPlayed  GamesPlayed  PlusMinus  OffPoss  ...  Clear Path Fouls  \
# 29        20160.0            7        -81      722  ...               NaN
#
#     3pt And 1 Free Throw Trips  LongMidRangePctBlocked  Arc3PctBlocked  \
# 29                         NaN                 0.02439        0.012931
#
#     BlockedArc3  Transition Take Fouls  OffensiveGoaltends  HeaveMakes  \
# 29          4.0                    NaN                 NaN         NaN
#
#     season  year
# 29    2024  2025
#
# [1 rows x 237 columns]
