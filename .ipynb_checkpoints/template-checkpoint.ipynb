# %%
import pandas as pd

def year_data(year,ps=False):
    trail = 'ps' if ps else ''
    url= f'https://raw.githubusercontent.com/gabriel1200/player_sheets/refs/heads/master/year_totals/{year}{trail}.csv'
    return pd.read_csv(url)

df=year_data(2025)
# Out:
#      PLAYER_ID       PLAYER_NAME  W  GP  year  POSS TEAM_ABBREVIATION  \
# 0      1641803    Tristen Newton  1   6  2025    27               MIN
# 1      1642385        Cui Yongxi  2   5  2025    26               BKN
# 2      1642358        AJ Johnson  3   5  2025    28               MIL
# 3      1631197      Jared Rhoden  1   4  2025    26               CHA
# 4      1631306       Cole Swider  0   2  2025    27               DET
# ..         ...               ... ..  ..   ...   ...               ...
# 515    1631243    Mouhamed Gueye  0   2  2025    25               ATL
# 516    1642439    Quincy Olivari  1   2  2025    22               LAL
# 517    1642484       RayJ Dennis  1   2  2025     6               IND
# 518    1642434       Riley Minix  0   1  2025    15               SAS
# 519    1641774  Tristan Vukcevic  1   3  2025    15               WAS
#
#         TEAM_ID   AGE  Corner3Assists  ...  CATCH_SHOOT_FG_PCT  DefRebounds  \
# 0    1610612750  23.0             NaN  ...                0.00          1.0
# 1    1610612751  21.0             NaN  ...                0.00          2.0
# 2    1610612749  20.0             NaN  ...                1.00          2.0
# 3    1610612766  25.0             NaN  ...                0.00          2.0
# 4    1610612765  25.0             NaN  ...                0.00          2.0
# ..          ...   ...             ...  ...                 ...          ...
# 515  1610612737  22.0             NaN  ...                0.00          NaN
# 516  1610612747  23.0             NaN  ...                0.25          NaN
# 517  1610612754  23.0             NaN  ...                0.00          NaN
# 518  1610612759  24.0             NaN  ...                0.00          NaN
# 519  1610612764  21.0             NaN  ...                0.00          NaN
#
#      POST_TOUCHES  POST_TOUCH_PTS  Avg3ptShotDistance  open_FG3_PCT  \
# 0             0.0             0.0           27.366667           0.0
# 1             0.0             0.0           24.266667           0.0
# 2             0.0             0.0           24.100000           NaN
# 3             0.0             0.0           24.550000           NaN
# 4             0.0             0.0           25.420000           0.0
# ..            ...             ...                 ...           ...
# 515           0.0             0.0                 NaN           NaN
# 516           0.0             0.0                 NaN           0.0
# 517           0.0             0.0                 NaN           0.0
# 518           0.0             0.0                 NaN           NaN
# 519           0.0             0.0                 NaN           NaN
#
#      PeriodOTFouls4Minutes        TeamId  on-ball-time%  ON_BALL_TIME_PCT
# 0                      NaN  1.610613e+09      51.111111         51.111111
# 1                      NaN  1.610613e+09      10.000000         10.000000
# 2                      NaN  1.610613e+09      32.727273         32.727273
# 3                      NaN  1.610613e+09      13.333333         13.333333
# 4                      NaN  1.610613e+09       6.153846          6.153846
# ..                     ...           ...            ...               ...
# 515                    NaN           NaN            NaN               NaN
# 516                    NaN           NaN            NaN               NaN
# 517                    NaN           NaN            NaN               NaN
# 518                    NaN           NaN            NaN               NaN
# 519                    NaN           NaN            NaN               NaN
#
# [520 rows x 500 columns]
